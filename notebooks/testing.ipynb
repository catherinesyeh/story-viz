# %% [markdown]
# ## format txt file

# %%
def split_long_lines(filename, folder="scripts", max_length=80):
    # Open the file for reading
    with open(folder + "/" + filename, 'r') as file:
        lines = file.readlines()

    new_lines = []
    
    # Iterate through each line
    for line in lines:
        while len(line) > max_length:
            # Find the last space before the max_length
            split_index = line[:max_length].rfind(' ')
            if split_index == -1:
                split_index = max_length  # No space found, split at max_length
                
            # Append the portion of the line up to the split point
            new_lines.append(line[:split_index].strip() + '\n')
            
            # Continue processing the rest of the line
            line = line[split_index:].strip()
        
        new_lines.append(line + '\n')  # Add the rest of the line (if any) or short lines directly

    # remove any lines that are 'XXX'
    new_lines = [line for line in new_lines if line.strip() != 'XXX']
    
    # Write the modified lines back to the file or a new file
    with open(folder + '/split_' + filename, 'w') as file:
        file.writelines(new_lines)

# %%
split_long_lines('time.txt')

# %%
import re 

def remove_extra_newlines(filename, folder):
    # Open the file for reading
    with open(folder + "/" + filename, 'r') as file:
        lines = file.read()
    
    # Replace 3+ newlines with just 2 newlines
    cleaned_lines = re.sub(r'\n{3,}', '\n\n', lines)

    # Write the cleaned content back to the file (or a new file)
    with open(folder + "/" + filename, 'w') as file:
        file.write(cleaned_lines)

# %%
remove_extra_newlines('split_time.txt', 'scripts')

# %% [markdown]
# ## character/location counting

# %%
# read in json
import json

with open('json/time/story_outline.json', 'r') as file:
    story_outline = json.load(file)

scenes = story_outline['scenes']
chapters = story_outline['chapters']
characters = story_outline['characters']
locations = story_outline['locations']

# %%
# count how many scenes each character is in per chapter
character_scene_count = {}

for scene in scenes:
    chapter = scene['chapter']  # Ensure this is a string or integer
    if chapter not in character_scene_count:
        character_scene_count[chapter] = {}
        
    for character in scene['characters']:
        character_name = character['name']  # Extract a unique identifier from the character dictionary
        if character_name not in character_scene_count[chapter]:
            character_scene_count[chapter][character_name] = 1
        else:
            character_scene_count[chapter][character_name] += 1

character_scene_count
# Out:
# {'Chapter 1: The Case Begins': {'Alex Harper': 4,
#   'Sam Torres': 1,
#   'Officer Davis': 2,
#   'Chief Anderson': 2,
#   'Captain Morgan': 1,
#   'Emily Rivers': 1},
#  'Chapter 2: A Day Like Any Other': {'Alex Harper': 5,
#   'Sam Torres': 2,
#   'Officer Evans': 2,
#   'Victor Chen': 1,
#   'Laura Patel': 1,
#   'Detective Lisa Young': 1,
#   'Sophia Tran': 1},
#  'Chapter 3: Realization of the Loop': {'Alex Harper': 5,
#   'Sam Torres': 1,
#   'Angela Price': 1,
#   'Detective Sarah Black': 1},
#  'Chapter 4: The Investigation Deepens': {'Alex Harper': 6,
#   'Sam Torres': 1,
#   'Victor Chen': 1,
#   'Officer Evans': 1,
#   'Laura Patel': 1,
#   'Tommy Rivera': 1,
#   'Marcus Lee': 1},
#  'Chapter 5: Breaking the Cycle': {'Alex Harper': 5,
#   'Sam Torres': 1,
#   'Brenda White': 1},
#  'Chapter 6: Personal Stakes': {'Alex Harper': 5,
#   'Jordan Harper': 1,
#   'Sam Torres': 1,
#   'Emily Rivers': 1,
#   'David Martin': 1},
#  "Chapter 7: The Mentor's Advice": {'Alex Harper': 5,
#   'Detective Richard Kane': 2,
#   'Sam Torres': 2,
#   'Detective Lisa Young': 2},
#  'Chapter 8: Closer to the Truth': {'Alex Harper': 5,
#   'Sam Torres': 2,
#   'Laura Patel': 1,
#   'Detective Sarah Black': 1,
#   'Sophia Tran': 1},
#  'Chapter 9: Consequences of Choices': {'Alex Harper': 5,
#   'Sam Torres': 1,
#   'Emily Rivers': 1,
#   'Angela Price': 1},
#  'Chapter 10: The Final Loop': {'Alex Harper': 5,
#   'The Killer': 2,
#   'Sam Torres': 2,
#   'David Martin': 1},
#  'Chapter 11: Breaking the Loop': {'Alex Harper': 5,
#   'Chief Anderson': 2,
#   'Detective Sarah Black': 1,
#   'The Killer': 1,
#   'Sam Torres': 1},
#  'Chapter 12: Moving Forward': {'Alex Harper': 4,
#   'Sam Torres': 2,
#   'Emily Rivers': 1,
#   'Jordan Harper': 1,
#   'Brenda White': 1,
#   'Marcus Lee': 1}}

# %%
# repeat for locations
location_scene_count = {}

for scene in scenes:
    chapter = scene['chapter']
    if chapter not in location_scene_count:
        location_scene_count[chapter] = {}
        
    location_name = scene['location']
    if location_name not in location_scene_count[chapter]:
        location_scene_count[chapter][location_name] = 1
    else:
        location_scene_count[chapter][location_name] += 1

location_scene_count
# Out:
# {'Chapter 1: The Case Begins': {'Crime scene': 3, 'Police precinct': 1},
#  'Chapter 2: A Day Like Any Other': {'Crime scene': 1,
#   "Victim's workplace": 2,
#   'Police precinct': 1,
#   "Coroner's office": 1},
#  'Chapter 3: Realization of the Loop': {"Alex's apartment": 3,
#   'Police precinct': 2},
#  'Chapter 4: The Investigation Deepens': {'Crime scene': 2,
#   "Victim's workplace": 2,
#   'Forensics lab': 1,
#   'Local bar': 1},
#  'Chapter 5: Breaking the Cycle': {"Alex's apartment": 3, 'Local diner': 2},
#  'Chapter 6: Personal Stakes': {"Alex's childhood home": 1,
#   "Alex's apartment": 2,
#   'Local café': 2},
#  "Chapter 7: The Mentor's Advice": {'Local bar': 2,
#   'Police precinct': 2,
#   "Alex's apartment": 1},
#  'Chapter 8: Closer to the Truth': {'Police precinct': 2,
#   "Victim's workplace": 1,
#   'Crime scene': 1,
#   "Alex's apartment": 1},
#  'Chapter 9: Consequences of Choices': {"Alex's apartment": 3,
#   'Local diner': 1,
#   'Local café': 1},
#  'Chapter 10: The Final Loop': {'Abandoned warehouse': 3,
#   'Crime scene': 1,
#   'Police precinct': 1},
#  'Chapter 11: Breaking the Loop': {'Abandoned warehouse': 1,
#   'Police precinct': 3,
#   "Alex's apartment": 1},
#  'Chapter 12: Moving Forward': {"Alex's apartment": 2,
#   'Police precinct': 1,
#   'Memorial for the victim': 1}}

# %%
for chapter in chapters:
    print(chapter['chapter'])
# Out:
# Chapter 1: The Case Begins
# Chapter 2: A Day Like Any Other
# Chapter 3: Realization of the Loop
# Chapter 4: The Investigation Deepens
# Chapter 5: Breaking the Cycle
# Chapter 6: Personal Stakes
# Chapter 7: The Mentor's Advice
# Chapter 8: Closer to the Truth
# Chapter 9: Consequences of Choices
# Chapter 10: The Final Loop
# Chapter 11: Breaking the Loop
# Chapter 12: Moving Forward

# %%
for chapter in character_scene_count:
    print(chapter)
# Out:
# Chapter 1: The Case Begins
# Chapter 2: A Day Like Any Other
# Chapter 3: Realization of the Loop
# Chapter 4: The Investigation Deepens
# Chapter 5: Breaking the Cycle
# Chapter 6: Personal Stakes
# Chapter 7: The Mentor's Advice
# Chapter 8: Closer to the Truth
# Chapter 9: Consequences of Choices
# Chapter 10: The Final Loop
# Chapter 11: Breaking the Loop
# Chapter 12: Moving Forward

# %%
# update counts in chapter json object
for chapter in chapters:
    chap_characters = chapter['characters']
    chap_locations = chapter['locations']
    # chap_name = chapter['chapter'].split(':')[0]
    chap_name = chapter['chapter']

    for character in chap_characters:
        new_dict = {"role": chap_characters[character], "count": character_scene_count[chap_name][character]}
        chap_characters[character] = new_dict
    
    for location in chap_locations:
        new_dict = {"role": chap_locations[location], "count": location_scene_count[chap_name][location]}
        chap_locations[location] = new_dict
# Out:
# Chapter 1: The Case Begins
# {'Alex Harper': 'Protagonist detective.', 'Sam Torres': "Alex's partner.", 'Captain Morgan': 'Supervisor overseeing the case.', 'Officer Davis': 'First responder at the crime scene.', 'Emily Rivers': "Victim's friend.", 'Chief Anderson': 'Oversees the investigation.'}
# Chapter 2: A Day Like Any Other
# {'Alex Harper': 'Protagonist detective navigating a complex murder case while dealing with personal challenges.', 'Sam Torres': "Alex's partner, supportive yet skeptical of Alex's unusual behavior during the investigation.", 'Victor Chen': "Victim's colleague with a complicated relationship to the victim, holding key information.", 'Laura Patel': "Victim's neighbor who witnessed suspicious activities, contributing to the investigation.", 'Officer Evans': 'Forensics officer responsible for analyzing evidence from the crime scene.', 'Detective Lisa Young': 'Assists in the investigation.', 'Sophia Tran': 'Journalist covering the case.'}
# Chapter 3: Realization of the Loop
# {'Alex Harper': 'Protagonist detective navigating a complex murder case while dealing with personal challenges.', 'Sam Torres': "Alex's partner, supportive yet skeptical of Alex's unusual behavior during the investigation.", 'Detective Sarah Black': "Rival investigator who expresses suspicion about Alex's behavior.", 'Angela Price': 'Psychiatrist consulted by the police.'}
# Chapter 4: The Investigation Deepens
# {'Alex Harper': 'Protagonist detective.', 'Sam Torres': "Alex's partner.", 'Victor Chen': "Victim's colleague.", 'Laura Patel': "Victim's neighbor.", 'Officer Evans': 'Forensics officer.', 'Marcus Lee': "Victim's ex-partner.", 'Tommy Rivera': 'Local informant who offers critical leads.'}
# Chapter 5: Breaking the Cycle
# {'Alex Harper': 'Protagonist detective.', 'Sam Torres': "Alex's partner.", 'Brenda White': "Victim's sister"}
# Chapter 6: Personal Stakes
# {'Alex Harper': 'Protagonist detective navigating a complex murder case while dealing with personal challenges.', 'Sam Torres': "Alex's partner, who becomes concerned about Alex's obsession with the case.", 'Emily Rivers': "Victim's friend, providing critical emotional context about the victim.", 'Jordan Harper': "Alex's estranged sibling, representing unresolved family issues.", 'David Martin': "Lawyer for victim's family."}
# Chapter 7: The Mentor's Advice
# {'Alex Harper': 'Protagonist detective.', 'Sam Torres': "Alex's partner.", 'Detective Richard Kane': 'Mentor figure.', 'Detective Lisa Young': 'Returns to provide a recap of the case.'}
# Chapter 8: Closer to the Truth
# {'Alex Harper': 'Protagonist detective navigating a complex murder case while dealing with personal challenges.', 'Sam Torres': "Alex's partner, supportive and engaged in the investigation.", 'Laura Patel': "Victim's neighbor, providing insights that hint at a conspiracy.", 'Detective Sarah Black': 'Rival investigator who is also pursuing leads related to the case.', 'Sophia Tran': 'Interacts with Alex to cover the evolving investigation.'}
# Chapter 9: Consequences of Choices
# {'Alex Harper': 'Protagonist detective.', 'Sam Torres': "Alex's partner.", 'Emily Rivers': "Victim's friend.", 'Angela Price': "Reflects on the victim's mental state."}
# Chapter 10: The Final Loop
# {'Alex Harper': 'Protagonist detective.', 'Sam Torres': "Alex's partner.", 'The Killer': 'Antagonist revealed in this chapter.', 'David Martin': 'Consulted to ensure that legal protocols are followed.'}
# Chapter 11: Breaking the Loop
# {'Alex Harper': 'Protagonist detective who navigates the resolution of the time loop.', 'Sam Torres': "Alex's partner who provides support and understanding during the aftermath.", 'The Killer': 'Antagonist from the climax, brought to justice.', 'Detective Sarah Black': 'Rival investigator who plays a role in the final processing of the case.', 'Chief Anderson': 'Provides a wrap-up on the investigation and its impact on the department.'}
# Chapter 12: Moving Forward
# {'Alex Harper': 'Protagonist detective.', 'Sam Torres': "Alex's partner.", 'Emily Rivers': "Victim's friend.", 'Jordan Harper': "Alex's sibling.", 'Brenda White': "Victim's sister. Attends the memorial.", 'Marcus Lee': "Victim's ex-partner. Shows up at the memorial."}

# %%
chapters
# Out:
# [{'chapter': 'Chapter 1: The Case Begins',
#   'summary': 'Detective Alex Harper arrives at the crime scene of a high-profile murder.',
#   'description': "Introduce the protagonist, Detective Alex Harper, as they respond to a high-profile murder scene. Introduce key characters: the victim, suspects, and the detective's partner. Establish the detective's motivation and personal challenges, hinting at a troubled past.",
#   'importance': 0.4,
#   'conflict': 0.2,
#   'locations': {'Crime scene': {'role': 'Luxury apartment where the murder took place.',
#     'count': 3},
#    'Police precinct': {'role': 'Main hub for the investigation.', 'count': 1}},
#   'characters': {'Alex Harper': {'role': 'Protagonist detective.', 'count': 4},
#    'Sam Torres': {'role': "Alex's partner.", 'count': 1},
#    'Captain Morgan': {'role': 'Supervisor overseeing the case.', 'count': 1},
#    'Officer Davis': {'role': 'First responder at the crime scene.',
#     'count': 2},
#    'Emily Rivers': {'role': "Victim's friend.", 'count': 1},
#    'Chief Anderson': {'role': 'Oversees the investigation.', 'count': 2}}},
#  {'chapter': 'Chapter 2: A Day Like Any Other',
#   'summary': "Alex gathers evidence and interviews suspects, revealing the victim's connections.",
#   'description': "Alex goes through the motions of the investigation, gathering evidence and interviewing suspects. Introduce the victim's backstory and relationships. A significant clue is discovered, but the day abruptly resets as Alex goes to sleep.",
#   'importance': 0.5,
#   'conflict': 0.3,
#   'locations': {'Crime scene': {'role': 'Luxury apartment where the murder took place.',
#     'count': 1},
#    "Victim's workplace": {'role': 'Corporate office where the victim worked, offering insights into their professional relationships.',
#     'count': 2},
#    "Coroner's office": {'role': 'Location where the body is examined, providing critical forensic insights.',
#     'count': 1},
#    'Police precinct': {'role': 'Main hub for the investigation, where detectives and officers collaborate on the case.',
#     'count': 1}},
#   'characters': {'Alex Harper': {'role': 'Protagonist detective navigating a complex murder case while dealing with personal challenges.',
#     'count': 5},
#    'Sam Torres': {'role': "Alex's partner, supportive yet skeptical of Alex's unusual behavior during the investigation.",
#     'count': 2},
#    'Victor Chen': {'role': "Victim's colleague with a complicated relationship to the victim, holding key information.",
#     'count': 1},
#    'Laura Patel': {'role': "Victim's neighbor who witnessed suspicious activities, contributing to the investigation.",
#     'count': 1},
#    'Officer Evans': {'role': 'Forensics officer responsible for analyzing evidence from the crime scene.',
#     'count': 2},
#    'Detective Lisa Young': {'role': 'Assists in the investigation.',
#     'count': 1},
#    'Sophia Tran': {'role': 'Journalist covering the case.', 'count': 1}}},
#  {'chapter': 'Chapter 3: Realization of the Loop',
#   'summary': 'Alex wakes up to find they are reliving the same day.',
#   'description': "Alex wakes up in their own bed, realizing they're back at the beginning of the day. Confusion ensues as they struggle to understand what is happening. Experimentation begins: Alex tests the loop by making different choices and observing outcomes.",
#   'importance': 0.7,
#   'conflict': 0.5,
#   'locations': {"Alex's apartment": {'role': 'Where Alex wakes up, filled with personal belongings and memories.',
#     'count': 3},
#    'Police precinct': {'role': 'Main hub for the investigation, where detectives and officers collaborate on the case.',
#     'count': 2}},
#   'characters': {'Alex Harper': {'role': 'Protagonist detective navigating a complex murder case while dealing with personal challenges.',
#     'count': 5},
#    'Sam Torres': {'role': "Alex's partner, supportive yet skeptical of Alex's unusual behavior during the investigation.",
#     'count': 1},
#    'Detective Sarah Black': {'role': "Rival investigator who expresses suspicion about Alex's behavior.",
#     'count': 1},
#    'Angela Price': {'role': 'Psychiatrist consulted by the police.',
#     'count': 1}}},
#  {'chapter': 'Chapter 4: The Investigation Deepens',
#   'summary': 'Alex gathers more clues, revealing hidden motives among the suspects.',
#   'description': "As Alex relives the day, they gather more information, discovering hidden motives among suspects. A key witness shares a critical piece of evidence that wasn't mentioned before, hinting at deeper connections.",
#   'importance': 0.6,
#   'conflict': 0.6,
#   'locations': {'Crime scene': {'role': 'Luxury apartment.', 'count': 2},
#    'Forensics lab': {'role': 'Where evidence is processed.', 'count': 1},
#    "Victim's workplace": {'role': 'Corporate office where the victim worked.',
#     'count': 2}},
#   'characters': {'Alex Harper': {'role': 'Protagonist detective.', 'count': 6},
#    'Sam Torres': {'role': "Alex's partner.", 'count': 1},
#    'Victor Chen': {'role': "Victim's colleague.", 'count': 1},
#    'Laura Patel': {'role': "Victim's neighbor.", 'count': 1},
#    'Officer Evans': {'role': 'Forensics officer.', 'count': 1},
#    'Marcus Lee': {'role': "Victim's ex-partner.", 'count': 1},
#    'Tommy Rivera': {'role': 'Local informant who offers critical leads.',
#     'count': 1}}},
#  {'chapter': 'Chapter 5: Breaking the Cycle',
#   'summary': 'Alex develops strategies to gather evidence and solve the case.',
#   'description': 'With each iteration, Alex starts to form strategies and uncover secrets about the suspects and their relationships with the victim. Personal struggles begin to surface, affecting their ability to focus on the case.',
#   'importance': 0.5,
#   'conflict': 0.4,
#   'locations': {"Alex's apartment": {'role': 'Where Alex reflects on the case.',
#     'count': 3},
#    'Local diner': {'role': 'Where Alex conducts informal interviews.',
#     'count': 2}},
#   'characters': {'Alex Harper': {'role': 'Protagonist detective.', 'count': 5},
#    'Sam Torres': {'role': "Alex's partner.", 'count': 1},
#    'Brenda White': {'role': "Victim's sister", 'count': 1}}},
#  {'chapter': 'Chapter 6: Personal Stakes',
#   'summary': 'Alex discovers personal connections to the victim, heightening the emotional stakes.',
#   'description': "Alex discovers that the victim had connections to their own past, introducing emotional stakes. A confrontation with their partner reveals tensions and suspicions about Alex's behavior during the investigation.",
#   'importance': 0.8,
#   'conflict': 0.7,
#   'locations': {"Alex's childhood home": {'role': 'Where Alex confronts personal memories and discovers connections to the victim.',
#     'count': 1},
#    'Local café': {'role': "Where Alex meets with Emily to discuss the victim's relationships.",
#     'count': 2},
#    "Alex's apartment": {'role': 'Where Alex reflects on the emotional implications of the case.',
#     'count': 2}},
#   'characters': {'Alex Harper': {'role': 'Protagonist detective navigating a complex murder case while dealing with personal challenges.',
#     'count': 5},
#    'Sam Torres': {'role': "Alex's partner, who becomes concerned about Alex's obsession with the case.",
#     'count': 1},
#    'Emily Rivers': {'role': "Victim's friend, providing critical emotional context about the victim.",
#     'count': 1},
#    'Jordan Harper': {'role': "Alex's estranged sibling, representing unresolved family issues.",
#     'count': 1},
#    'David Martin': {'role': "Lawyer for victim's family.", 'count': 1}}},
#  {'chapter': "Chapter 7: The Mentor's Advice",
#   'summary': 'Alex seeks guidance from an old mentor, gaining new perspectives.',
#   'description': 'An old mentor reappears, giving Alex cryptic advice about time and fate, encouraging them to embrace the chaos. Alex uses this advice to change their approach, exploring more personal connections with suspects.',
#   'importance': 0.4,
#   'conflict': 0.4,
#   'locations': {'Local bar': {'role': 'Where Alex meets their mentor.',
#     'count': 2},
#    'Police precinct': {'role': 'Main hub for the investigation.', 'count': 2},
#    "Alex's apartment": {'role': "Where Alex reflects on the mentor's advice and formulates a new strategy.",
#     'count': 1}},
#   'characters': {'Alex Harper': {'role': 'Protagonist detective.', 'count': 5},
#    'Sam Torres': {'role': "Alex's partner.", 'count': 2},
#    'Detective Richard Kane': {'role': 'Mentor figure.', 'count': 2},
#    'Detective Lisa Young': {'role': 'Returns to provide a recap of the case.',
#     'count': 2}}},
#  {'chapter': 'Chapter 8: Closer to the Truth',
#   'summary': 'Alex uncovers a conspiracy that ties suspects together.',
#   'description': "With newfound insights, Alex discovers a hidden conspiracy that ties several suspects together. Tensions rise as a close call with one of the suspects reveals a threat to Alex's life.",
#   'importance': 0.7,
#   'conflict': 0.8,
#   'locations': {'Police precinct': {'role': 'Main hub for the investigation, where Alex collaborates with Sam and analyzes evidence.',
#     'count': 2},
#    "Victim's workplace": {'role': "Corporate office where Alex confronts Laura and gathers information about the victim's relationships.",
#     'count': 1},
#    'Crime scene': {'role': 'Luxury apartment where Alex encounters danger from one of the suspects.',
#     'count': 1},
#    "Alex's apartment": {'role': 'Where Alex reflects on the evidence and makes connections.',
#     'count': 1}},
#   'characters': {'Alex Harper': {'role': 'Protagonist detective navigating a complex murder case while dealing with personal challenges.',
#     'count': 5},
#    'Sam Torres': {'role': "Alex's partner, supportive and engaged in the investigation.",
#     'count': 2},
#    'Laura Patel': {'role': "Victim's neighbor, providing insights that hint at a conspiracy.",
#     'count': 1},
#    'Detective Sarah Black': {'role': 'Rival investigator who is also pursuing leads related to the case.',
#     'count': 1},
#    'Sophia Tran': {'role': 'Interacts with Alex to cover the evolving investigation.',
#     'count': 1}}},
#  {'chapter': 'Chapter 9: Consequences of Choices',
#   'summary': 'Alex reflects on the emotional toll of the loop and their choices.',
#   'description': 'After a particularly harrowing loop, Alex realizes their choices have consequences not just for the investigation but also for their personal relationships. They start to reflect on what they truly value, shifting focus from solving the case to understanding the motivations behind the crime.',
#   'importance': 0.6,
#   'conflict': 0.6,
#   'locations': {"Alex's apartment": {'role': 'Where Alex reflects on their experiences.',
#     'count': 3},
#    'Local diner': {'role': 'Where they meet and discuss choices.', 'count': 1},
#    'Local café': {'role': "Where Alex reconnects with Emily to discuss the victim's story and emotional aspects.",
#     'count': 1}},
#   'characters': {'Alex Harper': {'role': 'Protagonist detective.', 'count': 5},
#    'Sam Torres': {'role': "Alex's partner.", 'count': 1},
#    'Emily Rivers': {'role': "Victim's friend.", 'count': 1},
#    'Angela Price': {'role': "Reflects on the victim's mental state.",
#     'count': 1}}},
#  {'chapter': 'Chapter 10: The Final Loop',
#   'summary': 'Alex faces the ultimate challenge and confronts the true killer.',
#   'description': 'The climax occurs as Alex finally confronts the killer and navigates a tense showdown. Utilizing all the knowledge gathered from previous loops, Alex manages to turn the tables and unearth the truth.',
#   'importance': 1.0,
#   'conflict': 1.0,
#   'locations': {'Abandoned warehouse': {'role': 'Location of the climactic showdown.',
#     'count': 3},
#    'Crime scene': {'role': 'Luxury apartment - flashback elements.',
#     'count': 1},
#    'Police precinct': {'role': 'Main hub for the investigation, where Alex and Sam regroup and process their findings.',
#     'count': 1}},
#   'characters': {'Alex Harper': {'role': 'Protagonist detective.', 'count': 5},
#    'Sam Torres': {'role': "Alex's partner.", 'count': 2},
#    'The Killer': {'role': 'Antagonist revealed in this chapter.', 'count': 2},
#    'David Martin': {'role': 'Consulted to ensure that legal protocols are followed.',
#     'count': 1}}},
#  {'chapter': 'Chapter 11: Breaking the Loop',
#   'summary': 'Alex breaks the cycle and wakes up to a new day.',
#   'description': "The resolution of the time loop and its implications for the protagonist's growth and future. Alex processes the impact of the events and reconciles with their partner.",
#   'importance': 0.9,
#   'conflict': 0.5,
#   'locations': {'Abandoned warehouse': {'role': 'Final confrontation site where the loop is broken.',
#     'count': 1},
#    'Police precinct': {'role': 'Main hub for post-case discussions and processing of events.',
#     'count': 3},
#    "Alex's apartment": {'role': 'Where Alex reflects on the journey and personal growth.',
#     'count': 1}},
#   'characters': {'Alex Harper': {'role': 'Protagonist detective who navigates the resolution of the time loop.',
#     'count': 5},
#    'Sam Torres': {'role': "Alex's partner who provides support and understanding during the aftermath.",
#     'count': 1},
#    'The Killer': {'role': 'Antagonist from the climax, brought to justice.',
#     'count': 1},
#    'Detective Sarah Black': {'role': 'Rival investigator who plays a role in the final processing of the case.',
#     'count': 1},
#    'Chief Anderson': {'role': 'Provides a wrap-up on the investigation and its impact on the department.',
#     'count': 2}}},
#  {'chapter': 'Chapter 12: Moving Forward',
#   'summary': 'Alex reflects on the case and finds a new purpose.',
#   'description': "The resolution sees Alex finding peace and a new purpose, vowing to approach future cases with a deeper understanding of human motives. The chapter highlights Alex's growth and closure.",
#   'importance': 0.5,
#   'conflict': 0.3,
#   'locations': {"Alex's apartment": {'role': 'Where Alex reflects on personal growth.',
#     'count': 2},
#    'Police precinct': {'role': 'Main hub for closure discussions.',
#     'count': 1},
#    'Memorial for the victim': {'role': 'Community gathering for remembrance.',
#     'count': 1}},
#   'characters': {'Alex Harper': {'role': 'Protagonist detective.', 'count': 4},
#    'Sam Torres': {'role': "Alex's partner.", 'count': 2},
#    'Emily Rivers': {'role': "Victim's friend.", 'count': 1},
#    'Jordan Harper': {'role': "Alex's sibling.", 'count': 1},
#    'Brenda White': {'role': "Victim's sister. Attends the memorial.",
#     'count': 1},
#    'Marcus Lee': {'role': "Victim's ex-partner. Shows up at the memorial.",
#     'count': 1}}}]

# %%
# update json file
with open('json/time/story_outline.json', 'w') as file:
    new_outline = {}
    new_outline['chapters'] = chapters
    new_outline['scenes'] = scenes
    new_outline['characters'] = characters
    new_outline['locations'] = locations
    json.dump(new_outline, file, indent=4)

# %%
print(len(scenes))
print(len(characters))
print(len(locations))
print(len(chapters))
# Out:
# 59
# 20
# 11
# 12

# %% [markdown]
# ## rank by importance and conflict

# %%
# read in json
import json

with open('json/time/story_outline.json', 'r') as file:
    story_outline = json.load(file)

scenes = story_outline['scenes']
chapters = story_outline['chapters']
characters = story_outline['characters']
locations = story_outline['locations']

# %%
# rank each scene by importance
# and within each scene, the characters

for i, chapter in enumerate(chapters):
    importances = []
    conflicts = []

    # chap_name = chapter["chapter"].split(":")[0]
    chap_name = chapter["chapter"]
    
    # extract importance from each scene
    for j, scene in enumerate(scenes):
        if scene["chapter"] != chap_name:
            continue
        importances.append((j, scene["importance"]))
        conflicts.append((j, scene["conflict"]))
        # now extract character importances
        character_importances = []
        for k, character in enumerate(scene["characters"]):
            character_importances.append((k, character["importance"]))
        # sort character importances
        sorted_character_importances = sorted(character_importances, key=lambda x: x[1], reverse=True)
        # add importance_rank to each character
        for k, (l, _) in enumerate(sorted_character_importances):
            scenes[j]["characters"][l]["importance_rank"] = k+1
        # add number of each scene
        scenes[j]["number"] = j+1
    # sort importances
    sorted_importances = sorted(importances, key=lambda x: x[1], reverse=True)
    # add importance_rank to each scene
    for k, (j, _) in enumerate(sorted_importances):
        scenes[j]["importance_rank"] = k+1
    # sort conflicts
    sorted_conflicts = sorted(conflicts, key=lambda x: x[1], reverse=True)
    # add conflict_rank to each scene
    for k, (j, _) in enumerate(sorted_conflicts):
        scenes[j]["conflict_rank"] = k+1
    
    # print results
    # for j, scene in enumerate(scenes):
    #     print(scenes[j]["title"], scenes[j]["importance_rank"])
    #     print("--------------------------------")
    #     for k, character in enumerate(scene["characters"]):
    #         print(character["name"], character["importance_rank"])
    #     print()

# %%
scenes
# Out:
# [{'title': 'Arrival at the Crime Scene',
#   'number': 1,
#   'first_line': 1,
#   'last_line': 29,
#   'summary': 'Detective Alex Harper arrives at the luxury apartment where the murder took place.',
#   'chapter': 'Chapter 1: The Case Begins',
#   'location': 'Crime scene',
#   'importance': 1,
#   'conflict': 0.2,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 1,
#     'emotion': 'Focused and determined',
#     'sentiment': 0.5,
#     'importance_rank': 1},
#    {'name': 'Sam Torres',
#     'role': "Alex's partner",
#     'importance': 0.7,
#     'emotion': 'Skeptical yet supportive',
#     'sentiment': 0.4,
#     'importance_rank': 3},
#    {'name': 'Officer Davis',
#     'role': 'First responder',
#     'importance': 0.6,
#     'emotion': 'Nervous',
#     'sentiment': 0.2,
#     'importance_rank': 4},
#    {'name': 'Chief Anderson',
#     'role': 'Police chief overseeing the department and pressuring the investigation.',
#     'importance': 0.8,
#     'emotion': 'Impatient and authoritative',
#     'sentiment': -0.1,
#     'importance_rank': 2}],
#   'importance_rank': 1,
#   'conflict_rank': 4},
#  {'title': 'Initial Observations',
#   'number': 2,
#   'first_line': 30,
#   'last_line': 52,
#   'summary': 'Alex examines the crime scene for clues while interacting with Officer Davis.',
#   'chapter': 'Chapter 1: The Case Begins',
#   'location': 'Crime scene',
#   'importance': 0.8,
#   'conflict': 0.3,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 1,
#     'emotion': 'Analytical and probing',
#     'sentiment': 0.5,
#     'importance_rank': 1},
#    {'name': 'Officer Davis',
#     'role': 'First responder',
#     'importance': 0.5,
#     'emotion': 'Helpful',
#     'sentiment': 0.3,
#     'importance_rank': 2}],
#   'importance_rank': 2,
#   'conflict_rank': 3},
#  {'title': 'Meeting the Captain',
#   'number': 3,
#   'first_line': 53,
#   'last_line': 79,
#   'summary': 'Alex discusses the case with Captain Morgan, who emphasizes the pressure to solve the murder.',
#   'chapter': 'Chapter 1: The Case Begins',
#   'location': 'Police precinct',
#   'importance': 0.7,
#   'conflict': 0.5,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 1,
#     'emotion': 'Stressed yet committed',
#     'sentiment': 0.4,
#     'importance_rank': 1},
#    {'name': 'Captain Morgan',
#     'role': 'Supervisor',
#     'importance': 0.8,
#     'emotion': 'Impatient',
#     'sentiment': -0.1,
#     'importance_rank': 2},
#    {'name': 'Chief Anderson',
#     'role': 'Police chief overseeing the department and pressuring the investigation.',
#     'importance': 0.8,
#     'emotion': 'Impatient and authoritative',
#     'sentiment': -0.1,
#     'importance_rank': 3}],
#   'importance_rank': 3,
#   'conflict_rank': 1},
#  {'title': "Emily's Testimony",
#   'number': 4,
#   'first_line': 80,
#   'last_line': 101,
#   'summary': "Alex interviews Emily Rivers, the victim's friend, to gather emotional insights.",
#   'chapter': 'Chapter 1: The Case Begins',
#   'location': 'Crime scene',
#   'importance': 0.6,
#   'conflict': 0.4,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 0.7,
#     'emotion': 'Sympathetic',
#     'sentiment': 0.5,
#     'importance_rank': 2},
#    {'name': 'Emily Rivers',
#     'role': "Victim's friend",
#     'importance': 1,
#     'emotion': 'Distraught',
#     'sentiment': -0.7,
#     'importance_rank': 1}],
#   'importance_rank': 4,
#   'conflict_rank': 2},
#  {'title': 'Evidence Collection',
#   'number': 5,
#   'first_line': 1,
#   'last_line': 36,
#   'summary': 'Alex returns to the luxury apartment to gather more clues and insights.',
#   'chapter': 'Chapter 2: A Day Like Any Other',
#   'location': 'Crime scene',
#   'importance': 0.8,
#   'conflict': 0.3,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 1,
#     'emotion': 'Determined',
#     'sentiment': 0.5,
#     'importance_rank': 1},
#    {'name': 'Sam Torres',
#     'role': "Alex's partner",
#     'importance': 0.7,
#     'emotion': 'Cautious',
#     'sentiment': 0.4,
#     'importance_rank': 2},
#    {'name': 'Officer Evans',
#     'role': 'Forensics officer',
#     'importance': 0.6,
#     'emotion': 'Focused',
#     'sentiment': 0.3,
#     'importance_rank': 3}],
#   'importance_rank': 2,
#   'conflict_rank': 5},
#  {'title': 'Interviewing Victor Chen',
#   'number': 6,
#   'first_line': 37,
#   'last_line': 68,
#   'summary': "Alex interviews Victor Chen, the victim's colleague, to uncover professional dynamics.",
#   'chapter': 'Chapter 2: A Day Like Any Other',
#   'location': "Victim's workplace",
#   'importance': 0.7,
#   'conflict': 0.5,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 0.8,
#     'emotion': 'Inquisitive',
#     'sentiment': 0.3,
#     'importance_rank': 2},
#    {'name': 'Victor Chen',
#     'role': "Victim's colleague",
#     'importance': 1,
#     'emotion': 'Concerned',
#     'sentiment': 0.1,
#     'importance_rank': 1}],
#   'importance_rank': 3,
#   'conflict_rank': 3},
#  {'title': 'Discussing Findings with Sam',
#   'number': 7,
#   'first_line': 69,
#   'last_line': 98,
#   'summary': 'Alex shares evidence with Sam, brainstorming possible motives.',
#   'chapter': 'Chapter 2: A Day Like Any Other',
#   'location': 'Police precinct',
#   'importance': 0.6,
#   'conflict': 0.4,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 0.8,
#     'emotion': 'Collaborative',
#     'sentiment': 0.5,
#     'importance_rank': 1},
#    {'name': 'Sam Torres',
#     'role': "Alex's partner",
#     'importance': 0.7,
#     'emotion': 'Engaged',
#     'sentiment': 0.4,
#     'importance_rank': 2}],
#   'importance_rank': 4,
#   'conflict_rank': 4},
#  {'title': 'Confronting Laura Patel',
#   'number': 8,
#   'first_line': 99,
#   'last_line': 129,
#   'summary': 'Alex confronts Laura Patel about inconsistencies in her previous statements.',
#   'chapter': 'Chapter 2: A Day Like Any Other',
#   'location': "Victim's workplace",
#   'importance': 0.5,
#   'conflict': 0.6,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 0.9,
#     'emotion': 'Aggressive',
#     'sentiment': 0.1,
#     'importance_rank': 2},
#    {'name': 'Laura Patel',
#     'role': "Victim's neighbor",
#     'importance': 1,
#     'emotion': 'Defensive',
#     'sentiment': -0.4,
#     'importance_rank': 1}],
#   'importance_rank': 5,
#   'conflict_rank': 2},
#  {'title': 'The Discovery',
#   'number': 9,
#   'first_line': 130,
#   'last_line': 158,
#   'summary': "A significant clue is found, revealing a connection to the victim's secret life.",
#   'chapter': 'Chapter 2: A Day Like Any Other',
#   'location': "Coroner's office",
#   'importance': 1.0,
#   'conflict': 0.7,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 1,
#     'emotion': 'Excited',
#     'sentiment': 0.6,
#     'importance_rank': 1},
#    {'name': 'Officer Evans',
#     'role': 'Forensics officer',
#     'importance': 0.8,
#     'emotion': 'Surprised',
#     'sentiment': 0.5,
#     'importance_rank': 2},
#    {'name': 'Detective Lisa Young',
#     'role': 'Supporting detective offering additional insights.',
#     'importance': 0.6,
#     'emotion': 'Curious',
#     'sentiment': 0.4,
#     'importance_rank': 3},
#    {'name': 'Sophia Tran',
#     'role': 'Journalist covering the case, seeking to uncover the truth.',
#     'importance': 0.5,
#     'emotion': 'Determined',
#     'sentiment': 0.3,
#     'importance_rank': 4}],
#   'importance_rank': 1,
#   'conflict_rank': 1},
#  {'title': 'Waking Up in Confusion',
#   'number': 10,
#   'first_line': 1,
#   'last_line': 29,
#   'summary': 'Alex wakes up in their bed, realizing they are back at the beginning of the day.',
#   'chapter': 'Chapter 3: Realization of the Loop',
#   'location': "Alex's apartment",
#   'importance': 1,
#   'conflict': 0.4,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 1,
#     'emotion': 'Confused and alarmed',
#     'sentiment': -0.2,
#     'importance_rank': 1}],
#   'importance_rank': 1,
#   'conflict_rank': 3},
#  {'title': 'Testing the Loop',
#   'number': 11,
#   'first_line': 30,
#   'last_line': 51,
#   'summary': 'Alex experiments with their actions to test the boundaries of the time loop.',
#   'chapter': 'Chapter 3: Realization of the Loop',
#   'location': "Alex's apartment",
#   'importance': 0.8,
#   'conflict': 0.5,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 1,
#     'emotion': 'Intrigued and determined',
#     'sentiment': 0.3,
#     'importance_rank': 1}],
#   'importance_rank': 3,
#   'conflict_rank': 1},
#  {'title': 'Back at the Police Precinct',
#   'number': 12,
#   'first_line': 52,
#   'last_line': 79,
#   'summary': 'Alex returns to the precinct, trying to gather clues while feeling disoriented.',
#   'chapter': 'Chapter 3: Realization of the Loop',
#   'location': 'Police precinct',
#   'importance': 0.7,
#   'conflict': 0.3,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 1,
#     'emotion': 'Frustrated and anxious',
#     'sentiment': -0.1,
#     'importance_rank': 1},
#    {'name': 'Sam Torres',
#     'role': "Alex's partner",
#     'importance': 0.7,
#     'emotion': 'Concerned',
#     'sentiment': 0.2,
#     'importance_rank': 2},
#    {'name': 'Angela Price',
#     'role': "Psychiatrist providing insights into the victim's mental state.",
#     'importance': 0.6,
#     'emotion': 'Empathetic',
#     'sentiment': 0.4,
#     'importance_rank': 3}],
#   'importance_rank': 4,
#   'conflict_rank': 4},
#  {'title': 'Unexpected Encounter with Detective Black',
#   'number': 13,
#   'first_line': 80,
#   'last_line': 117,
#   'summary': "Alex runs into Detective Sarah Black, who expresses suspicion about Alex's behavior.",
#   'chapter': 'Chapter 3: Realization of the Loop',
#   'location': 'Police precinct',
#   'importance': 0.6,
#   'conflict': 0.5,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 0.8,
#     'emotion': 'Defensive',
#     'sentiment': -0.2,
#     'importance_rank': 2},
#    {'name': 'Detective Sarah Black',
#     'role': 'Rival investigator',
#     'importance': 1,
#     'emotion': 'Skeptical',
#     'sentiment': 0.1,
#     'importance_rank': 1}],
#   'importance_rank': 5,
#   'conflict_rank': 2},
#  {'title': 'Planning the Day',
#   'number': 14,
#   'first_line': 118,
#   'last_line': 143,
#   'summary': 'Alex makes a strategic plan for how to approach the investigation with their newfound knowledge.',
#   'chapter': 'Chapter 3: Realization of the Loop',
#   'location': "Alex's apartment",
#   'importance': 0.9,
#   'conflict': 0.3,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 1,
#     'emotion': 'Hopeful and focused',
#     'sentiment': 0.4,
#     'importance_rank': 1}],
#   'importance_rank': 2,
#   'conflict_rank': 5},
#  {'title': 'Revisiting the Crime Scene',
#   'number': 15,
#   'first_line': 1,
#   'last_line': 29,
#   'summary': 'Alex returns to the luxury apartment to gather more clues and insights.',
#   'chapter': 'Chapter 4: The Investigation Deepens',
#   'location': 'Crime scene',
#   'importance': 0.8,
#   'conflict': 0.4,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 1,
#     'emotion': 'Determined',
#     'sentiment': 0.5,
#     'importance_rank': 1},
#    {'name': 'Sam Torres',
#     'role': "Alex's partner",
#     'importance': 0.7,
#     'emotion': 'Supportive',
#     'sentiment': 0.4,
#     'importance_rank': 2}],
#   'importance_rank': 2,
#   'conflict_rank': 5},
#  {'title': 'Interview with the Key Witness',
#   'number': 16,
#   'first_line': 30,
#   'last_line': 65,
#   'summary': "Alex interviews a key witness who provides crucial information about the victim's last hours.",
#   'chapter': 'Chapter 4: The Investigation Deepens',
#   'location': "Victim's workplace",
#   'importance': 0.9,
#   'conflict': 0.6,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 1,
#     'emotion': 'Intrigued',
#     'sentiment': 0.4,
#     'importance_rank': 1},
#    {'name': 'Victor Chen',
#     'role': "Victim's colleague",
#     'importance': 1,
#     'emotion': 'Concerned',
#     'sentiment': 0.1,
#     'importance_rank': 2}],
#   'importance_rank': 1,
#   'conflict_rank': 2},
#  {'title': 'Gathering Evidence at the Forensics Lab',
#   'number': 17,
#   'first_line': 66,
#   'last_line': 90,
#   'summary': 'Alex and Sam analyze evidence collected from the crime scene, revealing hidden clues.',
#   'chapter': 'Chapter 4: The Investigation Deepens',
#   'location': 'Forensics lab',
#   'importance': 0.8,
#   'conflict': 0.5,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 0.9,
#     'emotion': 'Focused',
#     'sentiment': 0.5,
#     'importance_rank': 2},
#    {'name': 'Officer Evans',
#     'role': 'Forensics officer',
#     'importance': 1,
#     'emotion': 'Professional',
#     'sentiment': 0.3,
#     'importance_rank': 1}],
#   'importance_rank': 3,
#   'conflict_rank': 3},
#  {'title': 'Confronting Laura Patel Again',
#   'number': 18,
#   'first_line': 91,
#   'last_line': 114,
#   'summary': 'Alex confronts Laura Patel about inconsistencies in her previous statements.',
#   'chapter': 'Chapter 4: The Investigation Deepens',
#   'location': 'Crime scene',
#   'importance': 0.6,
#   'conflict': 0.7,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 1,
#     'emotion': 'Assertive',
#     'sentiment': 0.2,
#     'importance_rank': 1},
#    {'name': 'Laura Patel',
#     'role': "Victim's neighbor",
#     'importance': 1,
#     'emotion': 'Defensive',
#     'sentiment': -0.4,
#     'importance_rank': 2}],
#   'importance_rank': 5,
#   'conflict_rank': 1},
#  {'title': 'Meeting Tommy Rivera',
#   'number': 19,
#   'first_line': 115,
#   'last_line': 140,
#   'summary': 'Alex meets Tommy Rivera, a local informant who provides critical leads.',
#   'chapter': 'Chapter 4: The Investigation Deepens',
#   'location': 'Local bar',
#   'importance': 0.7,
#   'conflict': 0.5,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 0.8,
#     'emotion': 'Cautious',
#     'sentiment': 0.3,
#     'importance_rank': 2},
#    {'name': 'Tommy Rivera',
#     'role': 'Local informant with ties to the criminal underworld.',
#     'importance': 1,
#     'emotion': 'Nervous yet eager to help',
#     'sentiment': 0.1,
#     'importance_rank': 1}],
#   'importance_rank': 4,
#   'conflict_rank': 4},
#  {'title': 'Reflecting on Past Loops',
#   'number': 20,
#   'summary': 'Alex reflects on previous loops and starts developing strategies for the investigation.',
#   'chapter': 'Chapter 5: Breaking the Cycle',
#   'location': "Alex's apartment",
#   'importance': 0.8,
#   'conflict': 0.4,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 1,
#     'emotion': 'Thoughtful',
#     'sentiment': 0.5,
#     'importance_rank': 1}],
#   'importance_rank': 2,
#   'conflict_rank': 4},
#  {'title': 'Casual Meeting at the Diner',
#   'number': 21,
#   'summary': 'Alex meets Sam at a local diner to discuss informal leads and gather insights.',
#   'chapter': 'Chapter 5: Breaking the Cycle',
#   'location': 'Local diner',
#   'importance': 0.7,
#   'conflict': 0.3,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 0.8,
#     'emotion': 'Relaxed yet focused',
#     'sentiment': 0.4,
#     'importance_rank': 1},
#    {'name': 'Sam Torres',
#     'role': "Alex's partner",
#     'importance': 0.7,
#     'emotion': 'Engaged',
#     'sentiment': 0.5,
#     'importance_rank': 2}],
#   'importance_rank': 4,
#   'conflict_rank': 5},
#  {'title': 'Strategizing with Evidence',
#   'number': 22,
#   'summary': 'Alex lays out the evidence and begins to form a clearer picture of the case.',
#   'chapter': 'Chapter 5: Breaking the Cycle',
#   'location': "Alex's apartment",
#   'importance': 0.9,
#   'conflict': 0.5,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 1,
#     'emotion': 'Determined',
#     'sentiment': 0.6,
#     'importance_rank': 1}],
#   'importance_rank': 1,
#   'conflict_rank': 2},
#  {'title': 'Personal Struggles Resurface',
#   'number': 23,
#   'summary': "As the investigation deepens, Alex's personal struggles start to affect their focus.",
#   'chapter': 'Chapter 5: Breaking the Cycle',
#   'location': "Alex's apartment",
#   'importance': 0.6,
#   'conflict': 0.7,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 1,
#     'emotion': 'Frustrated',
#     'sentiment': -0.3,
#     'importance_rank': 1}],
#   'importance_rank': 5,
#   'conflict_rank': 1},
#  {'title': "Brenda's Testimony",
#   'number': 24,
#   'summary': "Alex meets with Brenda White, the victim's sister, to gather emotional insights about the victim's life.",
#   'chapter': 'Chapter 5: Breaking the Cycle',
#   'location': 'Local diner',
#   'importance': 0.8,
#   'conflict': 0.5,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 0.9,
#     'emotion': 'Empathetic',
#     'sentiment': 0.4,
#     'importance_rank': 2},
#    {'name': 'Brenda White',
#     'role': "Victim's sister, revealing family dynamics and emotional context about the victim.",
#     'importance': 1,
#     'emotion': 'Struggling with loss',
#     'sentiment': -0.6,
#     'importance_rank': 1}],
#   'importance_rank': 3,
#   'conflict_rank': 3},
#  {'title': 'Uncovering Personal Connections',
#   'number': 25,
#   'summary': 'Alex discovers a personal connection to the victim that heightens the emotional stakes.',
#   'chapter': 'Chapter 6: Personal Stakes',
#   'location': "Alex's childhood home",
#   'importance': 0.8,
#   'conflict': 0.6,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 1,
#     'emotion': 'Shocked',
#     'sentiment': -0.4,
#     'importance_rank': 1},
#    {'name': 'Jordan Harper',
#     'role': "Alex's estranged sibling",
#     'importance': 1,
#     'emotion': 'Angry',
#     'sentiment': -0.5,
#     'importance_rank': 2}],
#   'importance_rank': 2,
#   'conflict_rank': 3},
#  {'title': 'Confrontation with Sam',
#   'number': 26,
#   'summary': 'Alex has a heated confrontation with Sam about their obsession with the case.',
#   'chapter': 'Chapter 6: Personal Stakes',
#   'location': "Alex's apartment",
#   'importance': 0.7,
#   'conflict': 0.8,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 1,
#     'emotion': 'Frustrated',
#     'sentiment': -0.3,
#     'importance_rank': 1},
#    {'name': 'Sam Torres',
#     'role': "Alex's partner",
#     'importance': 0.8,
#     'emotion': 'Concerned',
#     'sentiment': 0.2,
#     'importance_rank': 2}],
#   'importance_rank': 4,
#   'conflict_rank': 1},
#  {'title': 'Finding Emily',
#   'number': 27,
#   'summary': "Alex reaches out to Emily Rivers to gain more context about the victim's relationships.",
#   'chapter': 'Chapter 6: Personal Stakes',
#   'location': 'Local café',
#   'importance': 0.6,
#   'conflict': 0.4,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 0.8,
#     'emotion': 'Hopeful',
#     'sentiment': 0.5,
#     'importance_rank': 2},
#    {'name': 'Emily Rivers',
#     'role': "Victim's friend",
#     'importance': 1,
#     'emotion': 'Emotional',
#     'sentiment': -0.6,
#     'importance_rank': 1}],
#   'importance_rank': 5,
#   'conflict_rank': 5},
#  {'title': 'Digging Into the Past',
#   'number': 28,
#   'summary': "Alex digs deeper into the victim's past, uncovering troubling secrets.",
#   'chapter': 'Chapter 6: Personal Stakes',
#   'location': "Alex's apartment",
#   'importance': 0.9,
#   'conflict': 0.7,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 1,
#     'emotion': 'Determined',
#     'sentiment': 0.4,
#     'importance_rank': 1}],
#   'importance_rank': 1,
#   'conflict_rank': 2},
#  {'title': 'Consulting David Martin',
#   'number': 29,
#   'summary': "Alex meets with David Martin, the lawyer for the victim's family, to discuss legal implications.",
#   'chapter': 'Chapter 6: Personal Stakes',
#   'location': 'Local café',
#   'importance': 0.8,
#   'conflict': 0.5,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 0.9,
#     'emotion': 'Inquisitive',
#     'sentiment': 0.3,
#     'importance_rank': 2},
#    {'name': 'David Martin',
#     'role': "Lawyer for the victim's family, adding legal perspectives to the investigation.",
#     'importance': 1,
#     'emotion': 'Serious',
#     'sentiment': 0.2,
#     'importance_rank': 1}],
#   'importance_rank': 3,
#   'conflict_rank': 4},
#  {'title': 'Seeking Guidance',
#   'number': 30,
#   'summary': 'Alex seeks out their old mentor, Detective Richard Kane, for advice on the investigation.',
#   'chapter': "Chapter 7: The Mentor's Advice",
#   'location': 'Local bar',
#   'importance': 0.7,
#   'conflict': 0.4,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 1,
#     'emotion': 'Hopeful',
#     'sentiment': 0.5,
#     'importance_rank': 1},
#    {'name': 'Detective Richard Kane',
#     'role': 'Mentor figure',
#     'importance': 1,
#     'emotion': 'Wise and cryptic',
#     'sentiment': 0.4,
#     'importance_rank': 2}],
#   'importance_rank': 4,
#   'conflict_rank': 3},
#  {'title': 'Cryptic Advice',
#   'number': 31,
#   'summary': 'Richard gives Alex cryptic advice about embracing chaos and finding the truth.',
#   'chapter': "Chapter 7: The Mentor's Advice",
#   'location': 'Local bar',
#   'importance': 0.8,
#   'conflict': 0.5,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 0.9,
#     'emotion': 'Intrigued',
#     'sentiment': 0.6,
#     'importance_rank': 2},
#    {'name': 'Detective Richard Kane',
#     'role': 'Mentor figure',
#     'importance': 1,
#     'emotion': 'Philosophical',
#     'sentiment': 0.5,
#     'importance_rank': 1}],
#   'importance_rank': 2,
#   'conflict_rank': 1},
#  {'title': 'Returning to the Precinct',
#   'number': 32,
#   'summary': "Inspired by the mentor's words, Alex returns to the precinct to share insights with Sam.",
#   'chapter': "Chapter 7: The Mentor's Advice",
#   'location': 'Police precinct',
#   'importance': 0.7,
#   'conflict': 0.3,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 1,
#     'emotion': 'Motivated',
#     'sentiment': 0.5,
#     'importance_rank': 1},
#    {'name': 'Sam Torres',
#     'role': "Alex's partner",
#     'importance': 0.8,
#     'emotion': 'Curious',
#     'sentiment': 0.4,
#     'importance_rank': 2},
#    {'name': 'Detective Lisa Young',
#     'role': 'Supporting detective offering additional insights.',
#     'importance': 0.6,
#     'emotion': 'Helpful',
#     'sentiment': 0.3,
#     'importance_rank': 3}],
#   'importance_rank': 5,
#   'conflict_rank': 5},
#  {'title': 'Collaboration with Sam',
#   'number': 33,
#   'summary': "Alex collaborates with Sam to re-evaluate evidence based on the mentor's advice.",
#   'chapter': "Chapter 7: The Mentor's Advice",
#   'location': 'Police precinct',
#   'importance': 0.8,
#   'conflict': 0.4,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 0.9,
#     'emotion': 'Focused',
#     'sentiment': 0.6,
#     'importance_rank': 1},
#    {'name': 'Sam Torres',
#     'role': "Alex's partner",
#     'importance': 0.8,
#     'emotion': 'Engaged',
#     'sentiment': 0.5,
#     'importance_rank': 2},
#    {'name': 'Detective Lisa Young',
#     'role': 'Supporting detective offering insights on the investigation.',
#     'importance': 0.7,
#     'emotion': 'Analytical',
#     'sentiment': 0.4,
#     'importance_rank': 3}],
#   'importance_rank': 3,
#   'conflict_rank': 4},
#  {'title': 'Embracing Chaos',
#   'number': 34,
#   'summary': 'Alex resolves to embrace the chaos in their investigation, exploring new leads.',
#   'chapter': "Chapter 7: The Mentor's Advice",
#   'location': "Alex's apartment",
#   'importance': 0.9,
#   'conflict': 0.5,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 1,
#     'emotion': 'Determined',
#     'sentiment': 0.7,
#     'importance_rank': 1}],
#   'importance_rank': 1,
#   'conflict_rank': 2},
#  {'title': 'Uncovering the Conspiracy',
#   'number': 35,
#   'summary': 'Alex pieces together evidence to uncover a conspiracy that ties several suspects together.',
#   'chapter': 'Chapter 8: Closer to the Truth',
#   'location': 'Police precinct',
#   'importance': 0.8,
#   'conflict': 0.7,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 1,
#     'emotion': 'Determined',
#     'sentiment': 0.6,
#     'importance_rank': 1},
#    {'name': 'Sam Torres',
#     'role': "Alex's partner",
#     'importance': 0.9,
#     'emotion': 'Engaged',
#     'sentiment': 0.5,
#     'importance_rank': 2}],
#   'importance_rank': 3,
#   'conflict_rank': 3},
#  {'title': 'Confronting a Suspect',
#   'number': 36,
#   'summary': 'Alex confronts one of the suspects, demanding answers about their involvement.',
#   'chapter': 'Chapter 8: Closer to the Truth',
#   'location': "Victim's workplace",
#   'importance': 0.9,
#   'conflict': 0.8,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 1,
#     'emotion': 'Aggressive',
#     'sentiment': 0.1,
#     'importance_rank': 1},
#    {'name': 'Laura Patel',
#     'role': "Victim's neighbor",
#     'importance': 1,
#     'emotion': 'Nervous',
#     'sentiment': -0.3,
#     'importance_rank': 2}],
#   'importance_rank': 1,
#   'conflict_rank': 2},
#  {'title': 'Close Call with Danger',
#   'number': 37,
#   'summary': "A close call with one of the suspects reveals a threat to Alex's safety.",
#   'chapter': 'Chapter 8: Closer to the Truth',
#   'location': 'Crime scene',
#   'importance': 0.8,
#   'conflict': 0.9,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 1,
#     'emotion': 'Frightened',
#     'sentiment': -0.5,
#     'importance_rank': 1},
#    {'name': 'Detective Sarah Black',
#     'role': 'Rival investigator',
#     'importance': 0.7,
#     'emotion': 'Concerned',
#     'sentiment': 0.2,
#     'importance_rank': 2}],
#   'importance_rank': 4,
#   'conflict_rank': 1},
#  {'title': 'Connecting the Dots',
#   'number': 38,
#   'summary': 'Alex gathers all the evidence, connecting the dots between the suspects and the victim.',
#   'chapter': 'Chapter 8: Closer to the Truth',
#   'location': "Alex's apartment",
#   'importance': 0.9,
#   'conflict': 0.5,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 1,
#     'emotion': 'Relieved',
#     'sentiment': 0.4,
#     'importance_rank': 1}],
#   'importance_rank': 2,
#   'conflict_rank': 4},
#  {'title': 'Planning the Next Move',
#   'number': 39,
#   'summary': 'Alex and Sam discuss their next steps in the investigation based on the new findings.',
#   'chapter': 'Chapter 8: Closer to the Truth',
#   'location': 'Police precinct',
#   'importance': 0.7,
#   'conflict': 0.4,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 0.9,
#     'emotion': 'Focused',
#     'sentiment': 0.5,
#     'importance_rank': 1},
#    {'name': 'Sam Torres',
#     'role': "Alex's partner",
#     'importance': 0.8,
#     'emotion': 'Determined',
#     'sentiment': 0.6,
#     'importance_rank': 2},
#    {'name': 'Sophia Tran',
#     'role': 'Journalist covering the case, seeking to uncover the truth.',
#     'importance': 0.6,
#     'emotion': 'Inquisitive',
#     'sentiment': 0.3,
#     'importance_rank': 3}],
#   'importance_rank': 5,
#   'conflict_rank': 5},
#  {'title': 'Aftermath of the Confrontation',
#   'number': 40,
#   'summary': 'Alex reflects on the emotional toll of the recent confrontation with a suspect.',
#   'chapter': 'Chapter 9: Consequences of Choices',
#   'location': "Alex's apartment",
#   'importance': 0.8,
#   'conflict': 0.6,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 1,
#     'emotion': 'Haunted',
#     'sentiment': -0.4,
#     'importance_rank': 1}],
#   'importance_rank': 2,
#   'conflict_rank': 1},
#  {'title': 'Meeting with Sam',
#   'number': 41,
#   'summary': 'Alex meets Sam to discuss the recent events and the impact on their investigation.',
#   'chapter': 'Chapter 9: Consequences of Choices',
#   'location': 'Local diner',
#   'importance': 0.7,
#   'conflict': 0.4,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 0.9,
#     'emotion': 'Concerned',
#     'sentiment': 0.3,
#     'importance_rank': 1},
#    {'name': 'Sam Torres',
#     'role': "Alex's partner",
#     'importance': 0.8,
#     'emotion': 'Supportive',
#     'sentiment': 0.5,
#     'importance_rank': 2}],
#   'importance_rank': 3,
#   'conflict_rank': 3},
#  {'title': 'Reflecting on Choices',
#   'number': 42,
#   'summary': 'Alex contemplates the consequences of their choices throughout the investigation.',
#   'chapter': 'Chapter 9: Consequences of Choices',
#   'location': "Alex's apartment",
#   'importance': 0.9,
#   'conflict': 0.5,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 1,
#     'emotion': 'Pensive',
#     'sentiment': -0.1,
#     'importance_rank': 1}],
#   'importance_rank': 1,
#   'conflict_rank': 2},
#  {'title': 'Reconnecting with Emily',
#   'number': 43,
#   'summary': 'Alex reaches out to Emily to discuss the emotional aspects of the case.',
#   'chapter': 'Chapter 9: Consequences of Choices',
#   'location': 'Local café',
#   'importance': 0.6,
#   'conflict': 0.3,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 0.8,
#     'emotion': 'Sympathetic',
#     'sentiment': 0.4,
#     'importance_rank': 2},
#    {'name': 'Emily Rivers',
#     'role': "Victim's friend",
#     'importance': 1,
#     'emotion': 'Vulnerable',
#     'sentiment': -0.6,
#     'importance_rank': 1}],
#   'importance_rank': 5,
#   'conflict_rank': 5},
#  {'title': 'Consulting Angela Price',
#   'number': 44,
#   'summary': "Alex consults Angela Price to gain insights into the victim's mental state and emotional struggles.",
#   'chapter': 'Chapter 9: Consequences of Choices',
#   'location': "Alex's apartment",
#   'importance': 0.7,
#   'conflict': 0.4,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 0.9,
#     'emotion': 'Inquisitive',
#     'sentiment': 0.3,
#     'importance_rank': 2},
#    {'name': 'Angela Price',
#     'role': "Psychiatrist providing insights into the victim's mental state.",
#     'importance': 1,
#     'emotion': 'Insightful',
#     'sentiment': 0.5,
#     'importance_rank': 1}],
#   'importance_rank': 4,
#   'conflict_rank': 4},
#  {'title': 'The Final Showdown',
#   'number': 45,
#   'summary': 'Alex confronts the true killer in a tense showdown at the abandoned warehouse.',
#   'chapter': 'Chapter 10: The Final Loop',
#   'location': 'Abandoned warehouse',
#   'importance': 1.0,
#   'conflict': 1.0,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 1,
#     'emotion': 'Determined',
#     'sentiment': 0.7,
#     'importance_rank': 1},
#    {'name': 'The Killer',
#     'role': 'Antagonist revealed in this chapter',
#     'importance': 1,
#     'emotion': 'Defiant',
#     'sentiment': -0.8,
#     'importance_rank': 2}],
#   'importance_rank': 1,
#   'conflict_rank': 1},
#  {'title': 'Uncovering the Truth',
#   'number': 46,
#   'summary': 'During the confrontation, Alex uncovers the motive behind the murder and the conspiracy.',
#   'chapter': 'Chapter 10: The Final Loop',
#   'location': 'Abandoned warehouse',
#   'importance': 0.9,
#   'conflict': 0.8,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 1,
#     'emotion': 'Insightful',
#     'sentiment': 0.5,
#     'importance_rank': 1},
#    {'name': 'The Killer',
#     'role': 'Antagonist revealed in this chapter',
#     'importance': 1,
#     'emotion': 'Maniacal',
#     'sentiment': -0.9,
#     'importance_rank': 2}],
#   'importance_rank': 2,
#   'conflict_rank': 3},
#  {'title': 'Flashbacks to the Crime Scene',
#   'number': 47,
#   'summary': 'Alex experiences flashbacks to the crime scene, piecing together the final clues.',
#   'chapter': 'Chapter 10: The Final Loop',
#   'location': 'Crime scene',
#   'importance': 0.8,
#   'conflict': 0.6,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 1,
#     'emotion': 'Nostalgic',
#     'sentiment': -0.2,
#     'importance_rank': 1}],
#   'importance_rank': 4,
#   'conflict_rank': 4},
#  {'title': 'Rescue from Danger',
#   'number': 48,
#   'summary': 'Sam arrives just in time to help Alex confront the killer and escape danger.',
#   'chapter': 'Chapter 10: The Final Loop',
#   'location': 'Abandoned warehouse',
#   'importance': 0.9,
#   'conflict': 0.9,
#   'characters': [{'name': 'Sam Torres',
#     'role': "Alex's partner",
#     'importance': 1,
#     'emotion': 'Brave',
#     'sentiment': 0.6,
#     'importance_rank': 1},
#    {'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 0.9,
#     'emotion': 'Relieved',
#     'sentiment': 0.8,
#     'importance_rank': 2}],
#   'importance_rank': 3,
#   'conflict_rank': 2},
#  {'title': 'The Aftermath',
#   'number': 49,
#   'summary': 'In the aftermath, Alex and Sam process the events and what it means for the case.',
#   'chapter': 'Chapter 10: The Final Loop',
#   'location': 'Police precinct',
#   'importance': 0.8,
#   'conflict': 0.4,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 1,
#     'emotion': 'Reflective',
#     'sentiment': 0.5,
#     'importance_rank': 1},
#    {'name': 'Sam Torres',
#     'role': "Alex's partner",
#     'importance': 0.9,
#     'emotion': 'Supportive',
#     'sentiment': 0.6,
#     'importance_rank': 2},
#    {'name': 'David Martin',
#     'role': "Lawyer for the victim's family, discussing legal perspectives on the case.",
#     'importance': 0.6,
#     'emotion': 'Serious',
#     'sentiment': 0.2,
#     'importance_rank': 3}],
#   'importance_rank': 5,
#   'conflict_rank': 5},
#  {'title': 'Breaking the Cycle',
#   'number': 50,
#   'summary': 'Alex wakes up after the confrontation, realizing the loop has been broken.',
#   'chapter': 'Chapter 11: Breaking the Loop',
#   'location': 'Abandoned warehouse',
#   'importance': 1.0,
#   'conflict': 0.5,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 1,
#     'emotion': 'Relieved',
#     'sentiment': 0.6,
#     'importance_rank': 1}],
#   'importance_rank': 1,
#   'conflict_rank': 2},
#  {'title': 'Processing the Events',
#   'number': 51,
#   'summary': 'Alex processes the implications of the events that transpired and their impact on their life.',
#   'chapter': 'Chapter 11: Breaking the Loop',
#   'location': 'Police precinct',
#   'importance': 0.8,
#   'conflict': 0.4,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 1,
#     'emotion': 'Contemplative',
#     'sentiment': 0.5,
#     'importance_rank': 1},
#    {'name': 'Chief Anderson',
#     'role': 'Police chief overseeing the department and evaluating the case outcome.',
#     'importance': 0.8,
#     'emotion': 'Proud yet demanding',
#     'sentiment': 0.3,
#     'importance_rank': 2}],
#   'importance_rank': 3,
#   'conflict_rank': 3},
#  {'title': 'Confronting the Killer',
#   'number': 52,
#   'summary': 'Alex confronts the killer one last time, ensuring they are brought to justice.',
#   'chapter': 'Chapter 11: Breaking the Loop',
#   'location': 'Police precinct',
#   'importance': 0.9,
#   'conflict': 0.7,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 1,
#     'emotion': 'Determined',
#     'sentiment': 0.8,
#     'importance_rank': 1},
#    {'name': 'Detective Sarah Black',
#     'role': 'Rival investigator',
#     'importance': 0.6,
#     'emotion': 'Cautious',
#     'sentiment': 0.2,
#     'importance_rank': 3},
#    {'name': 'The Killer',
#     'role': 'Antagonist revealed in this chapter',
#     'importance': 1,
#     'emotion': 'Defeated',
#     'sentiment': -0.9,
#     'importance_rank': 2}],
#   'importance_rank': 2,
#   'conflict_rank': 1},
#  {'title': 'Reflecting on the Journey',
#   'number': 53,
#   'summary': 'Alex reflects on the journey through the loops and the personal growth experienced.',
#   'chapter': 'Chapter 11: Breaking the Loop',
#   'location': "Alex's apartment",
#   'importance': 0.7,
#   'conflict': 0.3,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 1,
#     'emotion': 'Grateful',
#     'sentiment': 0.6,
#     'importance_rank': 1}],
#   'importance_rank': 5,
#   'conflict_rank': 5},
#  {'title': 'Reconciliation with Sam',
#   'number': 54,
#   'summary': 'Alex reconciles with Sam, acknowledging the toll the investigation took on their partnership.',
#   'chapter': 'Chapter 11: Breaking the Loop',
#   'location': 'Police precinct',
#   'importance': 0.8,
#   'conflict': 0.4,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 0.9,
#     'emotion': 'Reflective',
#     'sentiment': 0.5,
#     'importance_rank': 1},
#    {'name': 'Sam Torres',
#     'role': "Alex's partner",
#     'importance': 0.9,
#     'emotion': 'Understanding',
#     'sentiment': 0.7,
#     'importance_rank': 2},
#    {'name': 'Chief Anderson',
#     'role': "Police chief providing wrap-up on the investigation's outcome.",
#     'importance': 0.5,
#     'emotion': 'Satisfactory',
#     'sentiment': 0.4,
#     'importance_rank': 3}],
#   'importance_rank': 4,
#   'conflict_rank': 4},
#  {'title': 'Reflecting on the Case',
#   'number': 55,
#   'summary': 'Alex reflects on the entire investigation and the lessons learned from the time loop.',
#   'chapter': 'Chapter 12: Moving Forward',
#   'location': "Alex's apartment",
#   'importance': 0.8,
#   'conflict': 0.2,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 1,
#     'emotion': 'Contemplative',
#     'sentiment': 0.5,
#     'importance_rank': 1}],
#   'importance_rank': 2,
#   'conflict_rank': 3},
#  {'title': 'Sharing Insights with Sam',
#   'number': 56,
#   'summary': 'Alex shares newfound insights about human motives and relationships with Sam.',
#   'chapter': 'Chapter 12: Moving Forward',
#   'location': 'Police precinct',
#   'importance': 0.7,
#   'conflict': 0.3,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 0.9,
#     'emotion': 'Enlightened',
#     'sentiment': 0.6,
#     'importance_rank': 1},
#    {'name': 'Sam Torres',
#     'role': "Alex's partner",
#     'importance': 0.8,
#     'emotion': 'Supportive',
#     'sentiment': 0.7,
#     'importance_rank': 2}],
#   'importance_rank': 4,
#   'conflict_rank': 2},
#  {'title': 'Community Gathering for Remembrance',
#   'number': 57,
#   'summary': 'Alex attends a memorial for the victim, reflecting on the impact of the case.',
#   'chapter': 'Chapter 12: Moving Forward',
#   'location': 'Memorial for the victim',
#   'importance': 0.9,
#   'conflict': 0.4,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 1,
#     'emotion': 'Solemn',
#     'sentiment': 0.4,
#     'importance_rank': 1},
#    {'name': 'Emily Rivers',
#     'role': "Victim's friend",
#     'importance': 0.8,
#     'emotion': 'Emotional',
#     'sentiment': -0.5,
#     'importance_rank': 2},
#    {'name': 'Jordan Harper',
#     'role': "Alex's sibling",
#     'importance': 0.6,
#     'emotion': 'Reconciliatory',
#     'sentiment': 0.3,
#     'importance_rank': 4},
#    {'name': 'Brenda White',
#     'role': "Victim's sister, sharing her grief and memories.",
#     'importance': 0.7,
#     'emotion': 'Heartbroken',
#     'sentiment': -0.6,
#     'importance_rank': 3},
#    {'name': 'Marcus Lee',
#     'role': "Victim's ex-partner, reflecting on their relationship.",
#     'importance': 0.6,
#     'emotion': 'Regretful',
#     'sentiment': -0.4,
#     'importance_rank': 5}],
#   'importance_rank': 1,
#   'conflict_rank': 1},
#  {'title': 'New Beginnings',
#   'number': 58,
#   'summary': 'Alex finds a renewed sense of purpose in their work and relationships.',
#   'chapter': 'Chapter 12: Moving Forward',
#   'location': "Alex's apartment",
#   'importance': 0.8,
#   'conflict': 0.2,
#   'characters': [{'name': 'Alex Harper',
#     'role': 'Protagonist detective',
#     'importance': 1,
#     'emotion': 'Hopeful',
#     'sentiment': 0.7,
#     'importance_rank': 1},
#    {'name': 'Sam Torres',
#     'role': "Alex's partner",
#     'importance': 0.8,
#     'emotion': 'Supportive',
#     'sentiment': 0.7,
#     'importance_rank': 2}],
#   'importance_rank': 3,
#   'conflict_rank': 4}]

# %%
# update json file
with open('json/time/story_outline.json', 'w') as file:
    new_outline = {
        "title": "Time-Looped Detective",
        "type": "Book",
        "author": "ChatGPT",
        "year": 2024,
        "num_chapters": 12,
        "num_scenes": 59,
        "num_characters": 20,
        "num_locations": 11,
    }
    new_outline['chapters'] = chapters
    new_outline['scenes'] = scenes
    new_outline['characters'] = characters
    new_outline['locations'] = locations
    json.dump(new_outline, file, indent=4)
