# %% [markdown]
# ## format txt file

# %%
def split_long_lines(filename, folder="scripts", max_length=80):
    # Open the file for reading
    with open(folder + "/" + filename, 'r') as file:
        lines = file.readlines()

    new_lines = []
    
    # Iterate through each line
    for line in lines:
        while len(line) > max_length:
            # Find the last space before the max_length
            split_index = line[:max_length].rfind(' ')
            if split_index == -1:
                split_index = max_length  # No space found, split at max_length
                
            # Append the portion of the line up to the split point
            new_lines.append(line[:split_index].strip() + '\n')
            
            # Continue processing the rest of the line
            line = line[split_index:].strip()
        
        new_lines.append(line + '\n')  # Add the rest of the line (if any) or short lines directly

    # remove any lines that are 'XXX'
    new_lines = [line for line in new_lines if line.strip() != 'XXX']
    
    # Write the modified lines back to the file or a new file
    with open(folder + '/split_' + filename, 'w') as file:
        file.writelines(new_lines)

# %%
story = "whispers"

# %%
split_long_lines(f'{story}.txt')

# %%
import re 

def remove_extra_newlines(filename, folder):
    # Open the file for reading
    with open(folder + "/" + filename, 'r') as file:
        lines = file.read()
    
    # Replace 3+ newlines with just 2 newlines
    cleaned_lines = re.sub(r'\n{3,}', '\n\n', lines)

    # Write the cleaned content back to the file (or a new file)
    with open(folder + "/" + filename, 'w') as file:
        file.write(cleaned_lines)

# %%
remove_extra_newlines(f'split_{story}.txt', 'scripts')

# %% [markdown]
# ## check if any locations/characters are missing

# %%
import json 

# Load the JSON data from a file
with open(f"json/{story}/story_outline.json", "r") as file:
    data = json.load(file)

# Extract the locations from the locations object
all_locations = {location["name"] for location in data["locations"]}

# Extract the locations used in scenes
scene_locations = {scene["location"] for scene in data["scenes"]}

# Check if each location in "locations" is included in "scenes"
missing_locations = all_locations - scene_locations

# also other way around
extra_locations = scene_locations - all_locations

# Display the result
if missing_locations:
    print("The following locations are not included in any scene:")
    for location in missing_locations:
        print(f"- {location}")
else:
    print("All locations are included in at least one scene.")

if extra_locations:
    print("The following locations are not defined but used in scenes:")
    for location in extra_locations:
        print(f"- {location}")
else:
    print("All locations used in scenes are defined.")
# Out:
# All locations are included in at least one scene.
# All locations used in scenes are defined.

# %%
# check characters too
all_characters = {character["name"] for character in data["characters"]}
scene_characters = {character["name"] for scene in data["scenes"] for character in scene["characters"]}
missing_characters = all_characters - scene_characters
extra_characters = scene_characters - all_characters

if missing_characters:
    print("\nThe following characters are not included in any scene:")
    for character in missing_characters:
        print(f"- {character}")

if extra_characters:
    print("\nThe following characters are not defined but used in scenes:")
    for character in extra_characters:
        print(f"- {character}")

# %%
# print total number of scenes, characters and locations
print(f"\nTotal number of scenes: {len(data['scenes'])}")
print(f"Total number of characters: {len(data['characters'])}")
print(f"Total number of locations: {len(data['locations'])}")
# Out:
# Total number of scenes: 56
# Total number of characters: 34
# Total number of locations: 21

# %% [markdown]
# ## character/location counting

# %%
# read in json
import json

with open(f'json/{story}/story_outline.json', 'r') as file:
    story_outline = json.load(file)

scenes = story_outline['scenes']
chapters = story_outline['chapters']
characters = story_outline['characters']
locations = story_outline['locations']

# %%
# count how many scenes each character is in per chapter
character_scene_count = {}

for scene in scenes:
    chapter = scene['chapter']  # Ensure this is a string or integer
    if chapter not in character_scene_count:
        character_scene_count[chapter] = {}
        
    for character in scene['characters']:
        character_name = character['name']  # Extract a unique identifier from the character dictionary
        if character_name not in character_scene_count[chapter]:
            character_scene_count[chapter][character_name] = 1
        else:
            character_scene_count[chapter][character_name] += 1

character_scene_count
# Out:
# {'Chapter 1': {'Mei': 4, 'Zhang': 4, 'Lin': 1, 'Li Yuan': 1, 'Lao Feng': 1},
#  'Chapter 2': {'Mei': 5,
#   'Zhang': 2,
#   'Farid': 2,
#   'Kaveh': 2,
#   'Lin': 1,
#   'Old Wang': 1,
#   'Xiu': 1},
#  'Chapter 3': {'Mei': 5,
#   'Farid': 2,
#   'Old Wang': 1,
#   'Kaveh': 2,
#   'Jia': 1,
#   'Hadi': 1,
#   'Badr': 1,
#   'Aisha': 1},
#  'Chapter 4': {'Mei': 3,
#   'Zhang': 3,
#   'Farid': 3,
#   'Aisha': 2,
#   'Kaveh': 2,
#   'Saeed': 2,
#   'Yara': 2,
#   'Yao': 1,
#   'Jin': 1},
#  'Chapter 5': {'Mei': 4,
#   'Kaveh': 2,
#   'Zhang': 3,
#   'Li Wei': 1,
#   'Zhao': 1,
#   'Kalden': 1},
#  'Chapter 6': {'Mei': 5,
#   'Zhang': 2,
#   'Farid': 2,
#   'Aliya': 2,
#   'Kaveh': 2,
#   'Bahram': 1,
#   'Sohrab': 1,
#   'Lin': 1},
#  'Chapter 7': {'Mei': 5,
#   'Zhang': 1,
#   'Farid': 2,
#   'Jin': 1,
#   'Kaveh': 2,
#   'Nasrin': 1,
#   'Rashid': 1,
#   'Aliya': 1},
#  'Chapter 8': {'Mei': 5,
#   'Farid': 2,
#   'Jin': 2,
#   'Kaveh': 3,
#   'Emir': 1,
#   'Darya': 1,
#   'Hassan': 1},
#  'Chapter 9': {'Mei': 5,
#   'Kaveh': 5,
#   'Rashid': 3,
#   'Tarek': 1,
#   'Omar': 2,
#   'Nasrin': 1,
#   'Laila': 1},
#  'Chapter 10': {'Mei': 5,
#   'Prince Cyrus': 4,
#   'Kaveh': 3,
#   'Bahram': 1,
#   'Nasrin': 1,
#   'Parisa': 1,
#   'Rashid': 1},
#  'Chapter 11': {'Mei': 5,
#   'Prince Cyrus': 4,
#   'Bahram': 2,
#   'Rashid': 2,
#   'Queen Soraya': 2,
#   'Nasrin': 2,
#   'Kaveh': 2,
#   'Aisha': 1},
#  'Chapter 12': {'Mei': 4,
#   'Prince Cyrus': 1,
#   'Kaveh': 2,
#   'Hadi': 2,
#   'Queen Soraya': 1,
#   'Bahram': 1,
#   'Kalden': 2,
#   'Rashid': 1,
#   'Aisha': 1,
#   'Zhang': 1,
#   'Li Wei': 1}}

# %%
# repeat for locations
location_scene_count = {}

for scene in scenes:
    chapter = scene['chapter']
    if chapter not in location_scene_count:
        location_scene_count[chapter] = {}
        
    location_name = scene['location']
    if location_name not in location_scene_count[chapter]:
        location_scene_count[chapter][location_name] = 1
    else:
        location_scene_count[chapter][location_name] += 1

location_scene_count
# Out:
# {'Chapter 1': {"Mei's family home": 3, 'Tea market': 1},
#  'Chapter 2': {"Chang'an city gates": 1, 'Caravan encampment': 4},
#  'Chapter 3': {'Gobi Desert': 2, 'Oasis stop': 3},
#  'Chapter 4': {'Desert camp': 3, 'Bandit hideout in dunes': 1},
#  'Chapter 5': {'Caravanserai': 4},
#  'Chapter 6': {'Caravan encampment': 2, "Healer's tent in the desert": 3},
#  'Chapter 7': {'Mountains near Samarkand': 5},
#  'Chapter 8': {'Samarkand bazaar': 3, "Emir's guesthouse": 2},
#  'Chapter 9': {"Kaveh's quarters": 2,
#   'Secret meeting place': 1,
#   'Samarkand': 2},
#  'Chapter 10': {'Caravan route through Persia': 1, "Prince's encampment": 4},
#  'Chapter 11': {'Persian palace': 3, 'Royal gardens': 2},
#  'Chapter 12': {'Persian palace': 2, 'Caravan home camp': 2}}

# %%
for chapter in chapters:
    print(chapter['chapter'])
# Out:
# Chapter 1: The Merchant's Daughter
# Chapter 2: Caravan of Secrets
# Chapter 3: An Encounter in the Desert
# Chapter 4: Bandits in the Night
# Chapter 5: The Town of Lost Souls
# Chapter 6: The Scroll of Secrets
# Chapter 7: An Oath to Complete the Journey
# Chapter 8: The Golden Bazaar
# Chapter 9: Letters in the Dark
# Chapter 10: A Prince in Disguise
# Chapter 11: The Heart and the Choice
# Chapter 12: Whispers of the Silk Road

# %%
for chapter in character_scene_count:
    print(chapter)
# Out:
# Chapter 1
# Chapter 2
# Chapter 3
# Chapter 4
# Chapter 5
# Chapter 6
# Chapter 7
# Chapter 8
# Chapter 9
# Chapter 10
# Chapter 11
# Chapter 12

# %%
# update counts in chapter json object
for chapter in chapters:
    chap_characters = chapter['characters']
    chap_locations = chapter['locations']
    print(chapter['chapter'])
    if ':' in chapter['chapter']:
        chap_name = chapter['chapter'].split(':')[0]
    else:
        chap_name = chapter['chapter']

    for character in chap_characters:
        new_dict = {"role": chap_characters[character], "count": character_scene_count[chap_name][character]}
        chap_characters[character] = new_dict
    
    for location in chap_locations:
        new_dict = {"role": chap_locations[location], "count": location_scene_count[chap_name][location]}
        chap_locations[location] = new_dict
# Out:
# Chapter 1: The Merchant's Daughter
# Chapter 2: Caravan of Secrets
# Chapter 3: An Encounter in the Desert
# Chapter 4: Bandits in the Night
# Chapter 5: The Town of Lost Souls
# Chapter 6: The Scroll of Secrets
# Chapter 7: An Oath to Complete the Journey
# Chapter 8: The Golden Bazaar
# Chapter 9: Letters in the Dark
# Chapter 10: A Prince in Disguise
# Chapter 11: The Heart and the Choice
# Chapter 12: Whispers of the Silk Road

# %%
chapters
# Out:
# [{'chapter': "Chapter 1: The Merchant's Daughter",
#   'summary': 'Mei prepares for a journey on the Silk Road with her father.',
#   'description': 'Mei, the daughter of a respected tea merchant, helps her father pack for their Silk Road journey. She yearns for adventure but is told her place is at home. Circumstances change suddenly, and she is asked to accompany him, stepping into a world far beyond her imagination.',
#   'importance': 0.6,
#   'conflict': 0.2,
#   'locations': {"Mei's family home": {'role': "Chang'an, Mei's family home and the starting point for the journey.",
#     'count': 3},
#    'Tea market': {'role': "Local market in Chang'an where Mei's father trades.",
#     'count': 1}},
#   'characters': {'Mei': {'role': 'Protagonist, daughter of a tea merchant.',
#     'count': 4},
#    'Zhang': {'role': "Mei's father, a respected merchant.", 'count': 4},
#    'Lin': {'role': "Mei's servant and friend.", 'count': 1},
#    'Lao Feng': {'role': "Local merchant in Chang'an.", 'count': 1},
#    'Li Yuan': {'role': 'Family friend and fellow trader.', 'count': 1}}},
#  {'chapter': 'Chapter 2: Caravan of Secrets',
#   'summary': 'Mei joins the caravan and meets new travelers, including Kaveh.',
#   'description': "Mei joins her father and the caravan of traders. She meets intriguing travelers and realizes the Silk Road is alive with stories and whispered rumors of political schemes. She learns her father is involved in more than just trade—he's carrying a secret message to the Persian Empire.",
#   'importance': 0.7,
#   'conflict': 0.4,
#   'locations': {"Chang'an city gates": {'role': 'Departure point where Mei joins the caravan.',
#     'count': 1},
#    'Caravan encampment': {'role': 'Staging area for the travelers to organize before leaving.',
#     'count': 4}},
#   'characters': {'Mei': {'role': 'Protagonist, daughter of a tea merchant.',
#     'count': 5},
#    'Zhang': {'role': "Mei's father, a respected merchant.", 'count': 2},
#    'Kaveh': {'role': 'Persian merchant and potential love interest.',
#     'count': 2},
#    'Farid': {'role': 'Leader of the caravan.', 'count': 2},
#    'Xiu': {'role': 'Female servant in the caravan.', 'count': 1},
#    'Old Wang': {'role': 'Camel handler in the caravan.', 'count': 1}}},
#  {'chapter': 'Chapter 3: An Encounter in the Desert',
#   'summary': 'A Persian merchant joins, and Mei learns of potential spies.',
#   'description': "The caravan travels through the Gobi Desert. Mei meets a Persian merchant named Kaveh and is drawn to his knowledge and charm. He warns Mei of spies on the road and hints that her father's mission is dangerous.",
#   'importance': 0.6,
#   'conflict': 0.5,
#   'locations': {'Gobi Desert': {'role': 'Harsh terrain where the caravan encounters challenges.',
#     'count': 2},
#    'Oasis stop': {'role': 'Temporary rest stop for travelers and camels.',
#     'count': 3}},
#   'characters': {'Mei': {'role': 'Protagonist, daughter of a tea merchant.',
#     'count': 5},
#    'Kaveh': {'role': 'Persian merchant and potential love interest.',
#     'count': 2},
#    'Farid': {'role': 'Leader of the caravan.', 'count': 2},
#    'Jia': {'role': 'Young traveler within the caravan.', 'count': 1},
#    'Hadi': {'role': 'Indian trader along the Silk Road.', 'count': 1},
#    'Badr': {'role': "Kaveh's loyal bodyguard.", 'count': 1},
#    'Aisha': {'role': 'Skilled herbalist and healer.', 'count': 1},
#    'Old Wang': {'role': 'Camel handler in the caravan.', 'count': 1}}},
#  {'chapter': 'Chapter 4: Bandits in the Night',
#   'summary': "Bandits attack the caravan, injuring Mei's father.",
#   'description': "Bandits attack the caravan at night, attempting to steal Mei's father's goods. Mei narrowly escapes, but her father is injured. She begins to realize the stakes of the journey and the risks they face on this volatile route.",
#   'importance': 0.8,
#   'conflict': 0.8,
#   'locations': {'Desert camp': {'role': 'Temporary camp for the caravan, attacked by bandits.',
#     'count': 3},
#    'Bandit hideout in dunes': {'role': 'Location where bandits regroup after ambush.',
#     'count': 1}},
#   'characters': {'Mei': {'role': 'Protagonist, daughter of a tea merchant.',
#     'count': 3},
#    'Zhang': {'role': "Mei's father, a respected merchant.", 'count': 3},
#    'Kaveh': {'role': 'Persian merchant and potential love interest.',
#     'count': 2},
#    'Farid': {'role': 'Leader of the caravan.', 'count': 3},
#    'Aisha': {'role': 'Skilled herbalist and healer.', 'count': 2},
#    'Saeed': {'role': 'Leader of the bandits.', 'count': 2},
#    'Yara': {'role': 'Bandit skilled with a bow.', 'count': 2},
#    'Yao': {'role': 'Guard for the caravan.', 'count': 1},
#    'Jin': {'role': 'Caravan guard who befriends Mei.', 'count': 1}}},
#  {'chapter': 'Chapter 5: The Town of Lost Souls',
#   'summary': 'A mystic offers Mei a glimpse into her future.',
#   'description': "The caravan stops in a remote desert town. Mei meets an old woman who reads tea leaves and warns her of a choice between heart and duty. Mei learns about the cultural significance of tea and finds herself even more intrigued by Kaveh's world.",
#   'importance': 0.6,
#   'conflict': 0.3,
#   'locations': {'Caravanserai': {'role': 'Remote town with a mystical reputation where Mei meets the old woman.',
#     'count': 4}},
#   'characters': {'Mei': {'role': 'Protagonist, daughter of a tea merchant.',
#     'count': 4},
#    'Kaveh': {'role': 'Persian merchant and potential love interest.',
#     'count': 2},
#    'Li Wei': {'role': "Old woman who reads Mei's fortune.", 'count': 1},
#    'Zhang': {'role': "Mei's father, a respected merchant.", 'count': 3},
#    'Zhao': {'role': 'Local mystic in the town.', 'count': 1},
#    'Kalden': {'role': 'Tibetan monk and occasional healer.', 'count': 1}}},
#  {'chapter': 'Chapter 6: The Scroll of Secrets',
#   'summary': "Kaveh reveals the mission of peace Mei's father was tasked with.",
#   'description': "Mei's father falls ill, and Kaveh reveals her father is carrying a scroll intended to broker peace between China and Persia. Mei realizes the significance of their mission and feels a burden of responsibility as her father grows weaker.",
#   'importance': 0.9,
#   'conflict': 0.7,
#   'locations': {'Caravan encampment': {'role': "Desert stop where Mei takes responsibility for her father's mission.",
#     'count': 2},
#    "Healer's tent in the desert": {'role': "Where Mei's father receives treatment.",
#     'count': 3}},
#   'characters': {'Mei': {'role': 'Protagonist, daughter of a tea merchant.',
#     'count': 5},
#    'Kaveh': {'role': 'Persian merchant and potential love interest.',
#     'count': 2},
#    'Zhang': {'role': "Mei's father, a respected merchant.", 'count': 2},
#    'Farid': {'role': 'Leader of the caravan.', 'count': 2},
#    'Bahram': {'role': "Persian contact for Mei's father.", 'count': 1},
#    'Sohrab': {'role': 'Persian messenger.', 'count': 1},
#    'Lin': {'role': "Mei's servant and friend.", 'count': 1},
#    'Aliya': {'role': 'Persian healer who helps Zhang.', 'count': 2}}},
#  {'chapter': 'Chapter 7: An Oath to Complete the Journey',
#   'summary': "Mei takes on her father's role and leads the caravan.",
#   'description': 'With her father bedridden, Mei vows to complete his mission. She learns trade tactics, navigates caravan politics, and gains respect among the travelers. Kaveh supports her, but Mei suspects he has his own agenda.',
#   'importance': 0.9,
#   'conflict': 0.6,
#   'locations': {'Mountains near Samarkand': {'role': 'Symbolic entry point to Samarkand, where Mei takes on a leadership role.',
#     'count': 5}},
#   'characters': {'Mei': {'role': 'Protagonist, daughter of a tea merchant.',
#     'count': 5},
#    'Kaveh': {'role': 'Persian merchant and potential love interest.',
#     'count': 2},
#    'Zhang': {'role': "Mei's father, a respected merchant.", 'count': 1},
#    'Farid': {'role': 'Leader of the caravan.', 'count': 2},
#    'Jin': {'role': 'Caravan guard who befriends Mei.', 'count': 1},
#    'Nasrin': {'role': "Kaveh's estranged sister.", 'count': 1},
#    'Rashid': {'role': 'Caravan helper.', 'count': 1},
#    'Aliya': {'role': 'Persian healer who helps Zhang.', 'count': 1}}},
#  {'chapter': 'Chapter 8: The Golden Bazaar',
#   'summary': 'Mei encounters spies and deception in the bustling Samarkand bazaar.',
#   'description': "The caravan reaches Samarkand, a bustling trade hub. Mei encounters spies from rival kingdoms and narrowly escapes. She discovers that her father's mission is known to powerful forces, making her a target.",
#   'importance': 1.0,
#   'conflict': 0.9,
#   'locations': {'Samarkand bazaar': {'role': 'Lively trade center where Mei encounters spies.',
#     'count': 3},
#    "Emir's guesthouse": {'role': 'Lavish space where political deals take place.',
#     'count': 2}},
#   'characters': {'Mei': {'role': 'Protagonist, daughter of a tea merchant.',
#     'count': 5},
#    'Kaveh': {'role': 'Persian merchant and potential love interest.',
#     'count': 3},
#    'Farid': {'role': 'Leader of the caravan.', 'count': 2},
#    'Jin': {'role': 'Caravan guard who befriends Mei.', 'count': 2},
#    'Emir': {'role': 'Influential merchant in Samarkand.', 'count': 1},
#    'Darya': {'role': "Emir's wife, who befriends Mei.", 'count': 1},
#    'Hassan': {'role': 'Local trader and friend of the Emir.', 'count': 1}}},
#  {'chapter': 'Chapter 9: Letters in the Dark',
#   'summary': "Mei discovers Kaveh's true motives and hidden alliances.",
#   'description': "Mei finds letters revealing that Kaveh is part of a secret organization with its own aims. Mei must decide if she can trust him after realizing he's been protecting her for more than her mission's sake.",
#   'importance': 1.0,
#   'conflict': 1.0,
#   'locations': {'Samarkand': {'role': 'City where Mei uncovers the truth about Kaveh.',
#     'count': 2},
#    "Kaveh's quarters": {'role': 'Private space where Mei finds the letters.',
#     'count': 2},
#    'Secret meeting place': {'role': 'Secluded spot where Kaveh meets allies.',
#     'count': 1}},
#   'characters': {'Mei': {'role': 'Protagonist, daughter of a tea merchant.',
#     'count': 5},
#    'Kaveh': {'role': 'Persian merchant and potential love interest.',
#     'count': 5},
#    'Nasrin': {'role': "Kaveh's estranged sister.", 'count': 1},
#    'Rashid': {'role': 'Caravan helper.', 'count': 3},
#    'Tarek': {'role': 'Fellow trader with a suspicious side.', 'count': 1},
#    'Laila': {'role': 'Maid at the Samarkand guesthouse.', 'count': 1},
#    'Omar': {'role': 'Spy watching the caravan.', 'count': 2}}},
#  {'chapter': 'Chapter 10: A Prince in Disguise',
#   'summary': 'Mei allies with a Persian prince disguised as a commoner.',
#   'description': "In Persia, Mei meets a prince in disguise who supports her father's peace mission. She realizes the complex political web surrounding her journey and sees herself as a cultural link.",
#   'importance': 0.8,
#   'conflict': 0.6,
#   'locations': {'Caravan route through Persia': {'role': 'Road where Mei encounters the prince.',
#     'count': 1},
#    "Prince's encampment": {'role': 'Hidden camp where the prince meets Mei.',
#     'count': 4}},
#   'characters': {'Mei': {'role': 'Protagonist, daughter of a tea merchant.',
#     'count': 5},
#    'Kaveh': {'role': 'Persian merchant and potential love interest.',
#     'count': 3},
#    'Prince Cyrus': {'role': 'Persian prince in disguise.', 'count': 4},
#    'Bahram': {'role': "Persian contact for Mei's father.", 'count': 1},
#    'Nasrin': {'role': "Kaveh's estranged sister.", 'count': 1},
#    'Rashid': {'role': 'Caravan helper.', 'count': 1},
#    'Parisa': {'role': 'Palace maid who aids Mei.', 'count': 1}}},
#  {'chapter': 'Chapter 11: The Heart and the Choice',
#   'summary': 'Mei faces a decision between duty and love.',
#   'description': "Mei delivers the scroll, knowing it could change history. She's offered a choice: stay in Persia and learn her father's world or return home, possibly never seeing Kaveh again. She struggles between family loyalty and budding love.",
#   'importance': 0.9,
#   'conflict': 0.7,
#   'locations': {'Persian palace': {'role': "Site of Mei's pivotal decision.",
#     'count': 3},
#    'Royal gardens': {'role': 'Serene setting where Mei contemplates her choice.',
#     'count': 2}},
#   'characters': {'Mei': {'role': 'Protagonist, daughter of a tea merchant.',
#     'count': 5},
#    'Kaveh': {'role': 'Persian merchant and potential love interest.',
#     'count': 2},
#    'Prince Cyrus': {'role': 'Persian prince.', 'count': 4},
#    'Bahram': {'role': "Persian contact for Mei's father.", 'count': 2},
#    'Nasrin': {'role': "Kaveh's estranged sister.", 'count': 2},
#    'Rashid': {'role': 'Caravan helper.', 'count': 2},
#    'Aisha': {'role': 'Skilled herbalist and healer.', 'count': 1},
#    'Queen Soraya': {'role': 'Persian queen involved in political tensions.',
#     'count': 2}}},
#  {'chapter': 'Chapter 12: Whispers of the Silk Road',
#   'summary': 'Mei reflects on her journey and returns home, carrying new wisdom.',
#   'description': "Mei returns to China, her heart changed and her eyes opened to the world. She realizes her journey was just the beginning, and she has the potential to carry on her father's legacy of bridging cultures through trade and diplomacy.",
#   'importance': 1.0,
#   'conflict': 0.4,
#   'locations': {'Persian palace': {'role': "Site of Mei's final conversations and realizations.",
#     'count': 2},
#    'Caravan home camp': {'role': "Returning point marking the end of Mei's journey.",
#     'count': 2}},
#   'characters': {'Mei': {'role': 'Protagonist, daughter of a tea merchant.',
#     'count': 4},
#    'Kaveh': {'role': 'Persian merchant and potential love interest.',
#     'count': 2},
#    'Rashid': {'role': 'Caravan helper.', 'count': 1},
#    'Bahram': {'role': "Persian contact for Mei's father.", 'count': 1},
#    'Li Wei': {'role': 'Old woman and mystic.', 'count': 1},
#    'Zhang': {'role': "Mei's father, a respected merchant.", 'count': 1},
#    'Hadi': {'role': 'Indian trader.', 'count': 2},
#    'Kalden': {'role': 'Tibetan monk and occasional healer.', 'count': 2},
#    'Prince Cyrus': {'role': 'Persian prince.', 'count': 1},
#    'Queen Soraya': {'role': 'Persian queen.', 'count': 1},
#    'Aisha': {'role': 'Skilled herbalist and healer.', 'count': 1}}}]

# %%
# update json file
with open(f'json/{story}/story_outline.json', 'w') as file:
    new_outline = {  
        "title": "Whispers of the Tea Route",
        "type": "Book",
        "author": "ChatGPT",
        "year": 2024,
        "num_chapters": 12,
        "num_scenes": 56,
        "num_characters": 34,
        "num_locations": 21,
    }
    new_outline['chapters'] = chapters
    new_outline['scenes'] = scenes
    new_outline['characters'] = characters
    new_outline['locations'] = locations
    json.dump(new_outline, file, indent=4)

# %%
print(len(scenes))
print(len(characters))
print(len(locations))
print(len(chapters))
# Out:
# 56
# 34
# 21
# 12

# %% [markdown]
# ## rank by importance and conflict

# %%
# read in json
import json

with open(f'json/{story}/story_outline.json', 'r') as file:
    story_outline = json.load(file)

scenes = story_outline['scenes']
chapters = story_outline['chapters']
characters = story_outline['characters']
locations = story_outline['locations']

# %%
# rank each scene by importance
# and within each scene, the characters

for i, chapter in enumerate(chapters):
    importances = []
    conflicts = []
    num_scenes = 0

    if ':' in chapter['chapter']:
        chap_name = chapter["chapter"].split(":")[0]
    else:
        chap_name = chapter["chapter"]
    
    # extract importance from each scene
    for j, scene in enumerate(scenes):
        if scene["chapter"] != chap_name:
            continue
        importances.append((j, scene["importance"]))
        conflicts.append((j, scene["conflict"]))
        # now extract character importances
        character_importances = []
        for k, character in enumerate(scene["characters"]):
            character_importances.append((k, character["importance"]))
        # sort character importances
        sorted_character_importances = sorted(character_importances, key=lambda x: x[1], reverse=True)
        # add importance_rank to each character
        for k, (l, _) in enumerate(sorted_character_importances):
            scenes[j]["characters"][l]["importance_rank"] = k+1
        # add number of each scene
        scenes[j]["number"] = j+1
        num_scenes += 1
    # sort importances
    sorted_importances = sorted(importances, key=lambda x: x[1], reverse=True)
    # add importance_rank to each scene
    for k, (j, _) in enumerate(sorted_importances):
        scenes[j]["importance_rank"] = k+1
    # sort conflicts
    sorted_conflicts = sorted(conflicts, key=lambda x: x[1], reverse=True)
    # add conflict_rank to each scene
    for k, (j, _) in enumerate(sorted_conflicts):
        scenes[j]["conflict_rank"] = k+1
    
    # add number of scenes to chapter
    chapters[i]["scenes"] = num_scenes
    
    # print results
    # for j, scene in enumerate(scenes):
    #     print(scenes[j]["title"], scenes[j]["importance_rank"])
    #     print("--------------------------------")
    #     for k, character in enumerate(scene["characters"]):
    #         print(character["name"], character["importance_rank"])
    #     print()

# %%
scenes
# Out:
# [{'title': 'Packing for the Journey',
#   'number': 1,
#   'summary': 'Mei assists her father in preparing for the Silk Road journey.',
#   'chapter': 'Chapter 1',
#   'location': "Mei's family home",
#   'importance': 0.5,
#   'conflict': 0.1,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'eager yet uncertain',
#     'sentiment': 0.3,
#     'importance_rank': 1},
#    {'name': 'Zhang',
#     'role': "Mei's father, a respected merchant",
#     'importance': 0.9,
#     'emotion': 'focused on preparations',
#     'sentiment': 0.2,
#     'importance_rank': 2},
#    {'name': 'Lin',
#     'role': "Mei's servant and friend",
#     'importance': 0.3,
#     'emotion': 'supportive',
#     'sentiment': 0.4,
#     'importance_rank': 3}],
#   'importance_rank': 4,
#   'conflict_rank': 4},
#  {'title': 'Yearning for Adventure',
#   'number': 2,
#   'summary': 'Mei expresses her desire to join the journey but faces resistance.',
#   'chapter': 'Chapter 1',
#   'location': "Mei's family home",
#   'importance': 0.6,
#   'conflict': 0.3,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'longing and frustrated',
#     'sentiment': -0.1,
#     'importance_rank': 1},
#    {'name': 'Zhang',
#     'role': "Mei's father",
#     'importance': 0.8,
#     'emotion': 'protective and dismissive',
#     'sentiment': -0.3,
#     'importance_rank': 2}],
#   'importance_rank': 3,
#   'conflict_rank': 2},
#  {'title': 'A Change in Plans',
#   'number': 3,
#   'summary': 'Circumstances change, allowing Mei to join the journey unexpectedly.',
#   'chapter': 'Chapter 1',
#   'location': "Mei's family home",
#   'importance': 1.0,
#   'conflict': 0.5,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'excited and nervous',
#     'sentiment': 0.7,
#     'importance_rank': 1},
#    {'name': 'Zhang',
#     'role': "Mei's father",
#     'importance': 0.9,
#     'emotion': 'reluctant yet resigned',
#     'sentiment': 0.0,
#     'importance_rank': 2},
#    {'name': 'Li Yuan',
#     'role': 'family friend and fellow trader',
#     'importance': 0.4,
#     'emotion': 'supportive and encouraging',
#     'sentiment': 0.5,
#     'importance_rank': 3}],
#   'importance_rank': 1,
#   'conflict_rank': 1},
#  {'title': 'The Tea Market Farewell',
#   'number': 4,
#   'summary': 'Mei visits the local tea market with her father to make final trades.',
#   'chapter': 'Chapter 1',
#   'location': 'Tea market',
#   'importance': 0.7,
#   'conflict': 0.2,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'curious and observant',
#     'sentiment': 0.6,
#     'importance_rank': 1},
#    {'name': 'Zhang',
#     'role': "Mei's father",
#     'importance': 0.8,
#     'emotion': 'focused on business',
#     'sentiment': 0.2,
#     'importance_rank': 2},
#    {'name': 'Lao Feng',
#     'role': "local merchant in Chang'an",
#     'importance': 0.5,
#     'emotion': 'pleasant and amicable',
#     'sentiment': 0.5,
#     'importance_rank': 3}],
#   'importance_rank': 2,
#   'conflict_rank': 3},
#  {'title': 'Joining the Caravan',
#   'number': 5,
#   'summary': 'Mei joins her father and the caravan at the city gates.',
#   'chapter': 'Chapter 2',
#   'location': "Chang'an city gates",
#   'importance': 0.8,
#   'conflict': 0.2,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'nervous yet excited',
#     'sentiment': 0.6,
#     'importance_rank': 1},
#    {'name': 'Zhang',
#     'role': "Mei's father",
#     'importance': 0.9,
#     'emotion': 'determined and watchful',
#     'sentiment': 0.4,
#     'importance_rank': 2},
#    {'name': 'Farid',
#     'role': 'leader of the caravan',
#     'importance': 0.5,
#     'emotion': 'authoritative and calm',
#     'sentiment': 0.3,
#     'importance_rank': 3}],
#   'importance_rank': 3,
#   'conflict_rank': 4},
#  {'title': 'Meeting Kaveh',
#   'number': 6,
#   'summary': 'Mei meets Kaveh, a Persian merchant, and feels drawn to his mysterious presence.',
#   'chapter': 'Chapter 2',
#   'location': 'Caravan encampment',
#   'importance': 0.9,
#   'conflict': 0.3,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'curious and intrigued',
#     'sentiment': 0.7,
#     'importance_rank': 1},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.8,
#     'emotion': 'mysterious and warm',
#     'sentiment': 0.6,
#     'importance_rank': 2},
#    {'name': 'Lin',
#     'role': "Mei's servant and friend",
#     'importance': 0.4,
#     'emotion': 'protective and curious',
#     'sentiment': 0.3,
#     'importance_rank': 3}],
#   'importance_rank': 2,
#   'conflict_rank': 3},
#  {'title': 'Stories of the Silk Road',
#   'number': 7,
#   'summary': 'Mei hears travelers’ stories, revealing the mysteries and dangers of the Silk Road.',
#   'chapter': 'Chapter 2',
#   'location': 'Caravan encampment',
#   'importance': 0.7,
#   'conflict': 0.4,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'captivated and alert',
#     'sentiment': 0.5,
#     'importance_rank': 1},
#    {'name': 'Farid',
#     'role': 'leader of the caravan',
#     'importance': 0.6,
#     'emotion': 'serious and cautionary',
#     'sentiment': -0.1,
#     'importance_rank': 2},
#    {'name': 'Old Wang',
#     'role': 'camel handler',
#     'importance': 0.5,
#     'emotion': 'wise and pensive',
#     'sentiment': 0.3,
#     'importance_rank': 3}],
#   'importance_rank': 4,
#   'conflict_rank': 2},
#  {'title': 'A Secret Mission Revealed',
#   'number': 8,
#   'summary': 'Mei overhears her father talking about a secret message he is carrying.',
#   'chapter': 'Chapter 2',
#   'location': 'Caravan encampment',
#   'importance': 1.0,
#   'conflict': 0.5,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'anxious and determined',
#     'sentiment': -0.2,
#     'importance_rank': 1},
#    {'name': 'Zhang',
#     'role': "Mei's father",
#     'importance': 0.9,
#     'emotion': 'guarded and tense',
#     'sentiment': -0.4,
#     'importance_rank': 2},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.7,
#     'emotion': 'calm and observing',
#     'sentiment': 0.3,
#     'importance_rank': 3}],
#   'importance_rank': 1,
#   'conflict_rank': 1},
#  {'title': 'Crossing the Gobi Desert',
#   'number': 9,
#   'summary': 'The caravan faces the harshness of the Gobi Desert, testing their endurance.',
#   'chapter': 'Chapter 3',
#   'location': 'Gobi Desert',
#   'importance': 0.8,
#   'conflict': 0.4,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'exhausted yet determined',
#     'sentiment': -0.2,
#     'importance_rank': 1},
#    {'name': 'Farid',
#     'role': 'leader of the caravan',
#     'importance': 0.7,
#     'emotion': 'steady and focused',
#     'sentiment': 0.1,
#     'importance_rank': 2},
#    {'name': 'Old Wang',
#     'role': 'camel handler',
#     'importance': 0.5,
#     'emotion': 'resigned and tired',
#     'sentiment': -0.1,
#     'importance_rank': 3}],
#   'importance_rank': 2,
#   'conflict_rank': 3},
#  {'title': 'Meeting Kaveh Again',
#   'number': 10,
#   'summary': 'Mei encounters Kaveh and learns about his knowledge of the Silk Road.',
#   'chapter': 'Chapter 3',
#   'location': 'Gobi Desert',
#   'importance': 0.7,
#   'conflict': 0.3,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'curious and captivated',
#     'sentiment': 0.5,
#     'importance_rank': 1},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.9,
#     'emotion': 'insightful and mysterious',
#     'sentiment': 0.6,
#     'importance_rank': 2}],
#   'importance_rank': 4,
#   'conflict_rank': 4},
#  {'title': 'Whispers of Spies',
#   'number': 11,
#   'summary': 'Kaveh warns Mei of potential spies among the caravan, hinting at her father’s dangerous mission.',
#   'chapter': 'Chapter 3',
#   'location': 'Oasis stop',
#   'importance': 1.0,
#   'conflict': 0.6,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'anxious and wary',
#     'sentiment': -0.3,
#     'importance_rank': 1},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.9,
#     'emotion': 'serious and guarded',
#     'sentiment': 0.1,
#     'importance_rank': 2}],
#   'importance_rank': 1,
#   'conflict_rank': 1},
#  {'title': 'Secrets on the Road',
#   'number': 12,
#   'summary': 'Mei observes suspicious behavior among the caravan members, growing cautious of whom to trust.',
#   'chapter': 'Chapter 3',
#   'location': 'Oasis stop',
#   'importance': 0.8,
#   'conflict': 0.5,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'wary and watchful',
#     'sentiment': -0.1,
#     'importance_rank': 1},
#    {'name': 'Jia',
#     'role': 'young traveler within the caravan',
#     'importance': 0.5,
#     'emotion': 'curious but nervous',
#     'sentiment': 0.2,
#     'importance_rank': 3},
#    {'name': 'Hadi',
#     'role': 'Indian trader along the Silk Road',
#     'importance': 0.4,
#     'emotion': 'aloof and cautious',
#     'sentiment': -0.2,
#     'importance_rank': 4},
#    {'name': 'Badr',
#     'role': "Kaveh's loyal bodyguard",
#     'importance': 0.6,
#     'emotion': 'protective and tense',
#     'sentiment': 0.1,
#     'importance_rank': 2}],
#   'importance_rank': 3,
#   'conflict_rank': 2},
#  {'title': 'An Encounter with Aisha',
#   'number': 13,
#   'summary': "Mei meets Aisha, a skilled healer in the caravan, who gives her insight into the Silk Road's dangers.",
#   'chapter': 'Chapter 3',
#   'location': 'Oasis stop',
#   'importance': 0.7,
#   'conflict': 0.3,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'grateful and curious',
#     'sentiment': 0.5,
#     'importance_rank': 1},
#    {'name': 'Aisha',
#     'role': 'skilled healer and herbalist',
#     'importance': 0.8,
#     'emotion': 'compassionate and wise',
#     'sentiment': 0.7,
#     'importance_rank': 2},
#    {'name': 'Farid',
#     'role': 'leader of the caravan',
#     'importance': 0.5,
#     'emotion': 'respectful and alert',
#     'sentiment': 0.3,
#     'importance_rank': 3}],
#   'importance_rank': 5,
#   'conflict_rank': 5},
#  {'title': 'Nightfall at the Desert Camp',
#   'number': 14,
#   'summary': 'The caravan sets up camp for the night in the desert, unaware of the impending danger.',
#   'chapter': 'Chapter 4',
#   'location': 'Desert camp',
#   'importance': 0.6,
#   'conflict': 0.3,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'wary and alert',
#     'sentiment': 0.0,
#     'importance_rank': 1},
#    {'name': 'Zhang',
#     'role': "Mei's father",
#     'importance': 0.8,
#     'emotion': 'thoughtful and cautious',
#     'sentiment': -0.1,
#     'importance_rank': 2},
#    {'name': 'Farid',
#     'role': 'leader of the caravan',
#     'importance': 0.7,
#     'emotion': 'vigilant and focused',
#     'sentiment': 0.2,
#     'importance_rank': 3},
#    {'name': 'Aisha',
#     'role': 'skilled herbalist and healer',
#     'importance': 0.5,
#     'emotion': 'calm and prepared',
#     'sentiment': 0.3,
#     'importance_rank': 4}],
#   'importance_rank': 3,
#   'conflict_rank': 4},
#  {'title': 'The Bandit Attack',
#   'number': 15,
#   'summary': 'Bandits ambush the caravan at night, targeting Mei’s father’s goods.',
#   'chapter': 'Chapter 4',
#   'location': 'Desert camp',
#   'importance': 1.0,
#   'conflict': 1.0,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'terrified yet resolute',
#     'sentiment': -0.5,
#     'importance_rank': 1},
#    {'name': 'Zhang',
#     'role': "Mei's father",
#     'importance': 0.9,
#     'emotion': 'protective but injured',
#     'sentiment': -0.4,
#     'importance_rank': 2},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.8,
#     'emotion': 'determined and defensive',
#     'sentiment': 0.1,
#     'importance_rank': 3},
#    {'name': 'Farid',
#     'role': 'leader of the caravan',
#     'importance': 0.7,
#     'emotion': 'commanding and quick-thinking',
#     'sentiment': 0.0,
#     'importance_rank': 5},
#    {'name': 'Saeed',
#     'role': 'leader of the bandits',
#     'importance': 0.8,
#     'emotion': 'aggressive and ruthless',
#     'sentiment': -0.8,
#     'importance_rank': 4},
#    {'name': 'Yara',
#     'role': 'bandit skilled with a bow',
#     'importance': 0.6,
#     'emotion': 'focused and ruthless',
#     'sentiment': -0.7,
#     'importance_rank': 6},
#    {'name': 'Yao',
#     'role': 'guard for the caravan',
#     'importance': 0.6,
#     'emotion': 'alert and defensive',
#     'sentiment': 0.0,
#     'importance_rank': 7},
#    {'name': 'Jin',
#     'role': 'caravan guard who befriends Mei',
#     'importance': 0.5,
#     'emotion': 'brave and protective',
#     'sentiment': 0.2,
#     'importance_rank': 8}],
#   'importance_rank': 1,
#   'conflict_rank': 1},
#  {'title': 'Aftermath of the Attack',
#   'number': 16,
#   'summary': 'The caravan assesses their losses, and Mei tends to her father’s wounds.',
#   'chapter': 'Chapter 4',
#   'location': 'Desert camp',
#   'importance': 0.9,
#   'conflict': 0.7,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'distressed but caring',
#     'sentiment': -0.2,
#     'importance_rank': 1},
#    {'name': 'Zhang',
#     'role': "Mei's father",
#     'importance': 0.9,
#     'emotion': 'weak and injured',
#     'sentiment': -0.4,
#     'importance_rank': 2},
#    {'name': 'Aisha',
#     'role': 'skilled herbalist and healer',
#     'importance': 0.8,
#     'emotion': 'focused and nurturing',
#     'sentiment': 0.5,
#     'importance_rank': 3},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.7,
#     'emotion': 'concerned and attentive',
#     'sentiment': 0.3,
#     'importance_rank': 4},
#    {'name': 'Farid',
#     'role': 'leader of the caravan',
#     'importance': 0.5,
#     'emotion': 'calm and pragmatic',
#     'sentiment': 0.2,
#     'importance_rank': 5}],
#   'importance_rank': 2,
#   'conflict_rank': 2},
#  {'title': 'Retreat to the Bandit Hideout',
#   'number': 17,
#   'summary': 'The bandits regroup at their hideout after the ambush, plotting further attacks.',
#   'chapter': 'Chapter 4',
#   'location': 'Bandit hideout in dunes',
#   'importance': 0.6,
#   'conflict': 0.5,
#   'characters': [{'name': 'Saeed',
#     'role': 'leader of the bandits',
#     'importance': 1.0,
#     'emotion': 'angry and vengeful',
#     'sentiment': -0.9,
#     'importance_rank': 1},
#    {'name': 'Yara',
#     'role': 'bandit skilled with a bow',
#     'importance': 0.8,
#     'emotion': 'defiant and eager',
#     'sentiment': -0.6,
#     'importance_rank': 2}],
#   'importance_rank': 4,
#   'conflict_rank': 3},
#  {'title': 'Arrival in the Town of Lost Souls',
#   'number': 18,
#   'summary': 'The caravan arrives in a remote desert town known for its mystics and unusual atmosphere.',
#   'chapter': 'Chapter 5',
#   'location': 'Caravanserai',
#   'importance': 0.6,
#   'conflict': 0.3,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'wary and intrigued',
#     'sentiment': 0.2,
#     'importance_rank': 1},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.8,
#     'emotion': 'guarded and mysterious',
#     'sentiment': 0.3,
#     'importance_rank': 2},
#    {'name': 'Zhang',
#     'role': "Mei's father",
#     'importance': 0.7,
#     'emotion': 'weary and reflective',
#     'sentiment': -0.1,
#     'importance_rank': 3}],
#   'importance_rank': 4,
#   'conflict_rank': 3},
#  {'title': 'The Fortune Teller’s Warning',
#   'number': 19,
#   'summary': 'Mei meets an old woman who reads her fortune, hinting at a choice between heart and duty.',
#   'chapter': 'Chapter 5',
#   'location': 'Caravanserai',
#   'importance': 1.0,
#   'conflict': 0.5,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'curious and contemplative',
#     'sentiment': 0.4,
#     'importance_rank': 1},
#    {'name': 'Li Wei',
#     'role': "old woman who reads Mei's fortune",
#     'importance': 0.9,
#     'emotion': 'cryptic and wise',
#     'sentiment': 0.0,
#     'importance_rank': 2},
#    {'name': 'Zhang',
#     'role': "Mei's father",
#     'importance': 0.5,
#     'emotion': 'cautious and wary',
#     'sentiment': -0.2,
#     'importance_rank': 3}],
#   'importance_rank': 1,
#   'conflict_rank': 1},
#  {'title': 'The Cultural Significance of Tea',
#   'number': 20,
#   'summary': 'Mei learns about the importance of tea in the town’s culture, deepening her understanding of her family’s trade.',
#   'chapter': 'Chapter 5',
#   'location': 'Caravanserai',
#   'importance': 0.7,
#   'conflict': 0.2,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'engaged and thoughtful',
#     'sentiment': 0.6,
#     'importance_rank': 1},
#    {'name': 'Zhang',
#     'role': "Mei's father",
#     'importance': 0.6,
#     'emotion': 'proud and reflective',
#     'sentiment': 0.3,
#     'importance_rank': 2},
#    {'name': 'Zhao',
#     'role': 'local mystic in the town',
#     'importance': 0.5,
#     'emotion': 'reverent and insightful',
#     'sentiment': 0.4,
#     'importance_rank': 3}],
#   'importance_rank': 3,
#   'conflict_rank': 4},
#  {'title': 'Intrigued by Kaveh’s World',
#   'number': 21,
#   'summary': 'Mei finds herself more intrigued by Kaveh and the world he represents, hinting at her growing inner conflict.',
#   'chapter': 'Chapter 5',
#   'location': 'Caravanserai',
#   'importance': 0.8,
#   'conflict': 0.4,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'conflicted and intrigued',
#     'sentiment': 0.5,
#     'importance_rank': 1},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.9,
#     'emotion': 'charming and reserved',
#     'sentiment': 0.4,
#     'importance_rank': 2},
#    {'name': 'Kalden',
#     'role': 'Tibetan monk and occasional healer',
#     'importance': 0.4,
#     'emotion': 'observant and wise',
#     'sentiment': 0.3,
#     'importance_rank': 3}],
#   'importance_rank': 2,
#   'conflict_rank': 2},
#  {'title': 'A Sudden Illness',
#   'number': 22,
#   'summary': "Mei's father falls ill, jeopardizing their journey and raising concerns among the caravan.",
#   'chapter': 'Chapter 6',
#   'location': 'Caravan encampment',
#   'importance': 0.8,
#   'conflict': 0.6,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'worried and distressed',
#     'sentiment': -0.4,
#     'importance_rank': 1},
#    {'name': 'Zhang',
#     'role': "Mei's father",
#     'importance': 0.9,
#     'emotion': 'weak and feverish',
#     'sentiment': -0.5,
#     'importance_rank': 2},
#    {'name': 'Farid',
#     'role': 'leader of the caravan',
#     'importance': 0.6,
#     'emotion': 'concerned and pragmatic',
#     'sentiment': 0.1,
#     'importance_rank': 4},
#    {'name': 'Aliya',
#     'role': 'Persian healer',
#     'importance': 0.7,
#     'emotion': 'calm and attentive',
#     'sentiment': 0.5,
#     'importance_rank': 3}],
#   'importance_rank': 3,
#   'conflict_rank': 2},
#  {'title': 'A Secret Mission Revealed',
#   'number': 23,
#   'summary': 'Kaveh reveals to Mei that her father is carrying a scroll meant to broker peace between China and Persia.',
#   'chapter': 'Chapter 6',
#   'location': 'Caravan encampment',
#   'importance': 1.0,
#   'conflict': 0.7,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'shocked and burdened',
#     'sentiment': -0.2,
#     'importance_rank': 1},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.9,
#     'emotion': 'solemn and sincere',
#     'sentiment': 0.4,
#     'importance_rank': 2},
#    {'name': 'Farid',
#     'role': 'leader of the caravan',
#     'importance': 0.5,
#     'emotion': 'concerned and supportive',
#     'sentiment': 0.2,
#     'importance_rank': 3}],
#   'importance_rank': 1,
#   'conflict_rank': 1},
#  {'title': 'Responsibility and Doubt',
#   'number': 24,
#   'summary': 'Mei grapples with the responsibility of her father’s mission as he grows weaker.',
#   'chapter': 'Chapter 6',
#   'location': "Healer's tent in the desert",
#   'importance': 0.9,
#   'conflict': 0.5,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'overwhelmed yet determined',
#     'sentiment': -0.1,
#     'importance_rank': 1},
#    {'name': 'Zhang',
#     'role': "Mei's father",
#     'importance': 0.8,
#     'emotion': 'weak and resigned',
#     'sentiment': -0.6,
#     'importance_rank': 2},
#    {'name': 'Aliya',
#     'role': 'Persian healer',
#     'importance': 0.7,
#     'emotion': 'compassionate and wise',
#     'sentiment': 0.5,
#     'importance_rank': 3}],
#   'importance_rank': 2,
#   'conflict_rank': 3},
#  {'title': 'Preparing for the Mission Ahead',
#   'number': 25,
#   'summary': 'With her father bedridden, Mei begins to accept the responsibility of his mission and prepares herself for the challenges ahead.',
#   'chapter': 'Chapter 6',
#   'location': "Healer's tent in the desert",
#   'importance': 0.8,
#   'conflict': 0.4,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'determined and resolute',
#     'sentiment': 0.6,
#     'importance_rank': 1},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.9,
#     'emotion': 'supportive and encouraging',
#     'sentiment': 0.5,
#     'importance_rank': 2},
#    {'name': 'Bahram',
#     'role': "Persian contact for Mei's father",
#     'importance': 0.8,
#     'emotion': 'respectful and hopeful',
#     'sentiment': 0.4,
#     'importance_rank': 3},
#    {'name': 'Sohrab',
#     'role': 'Persian messenger',
#     'importance': 0.6,
#     'emotion': 'respectful and dutiful',
#     'sentiment': 0.3,
#     'importance_rank': 4}],
#   'importance_rank': 4,
#   'conflict_rank': 4},
#  {'title': 'Seeking Comfort and Support',
#   'number': 26,
#   'summary': "Mei confides in Lin about her fears and doubts, finding comfort in her friend's loyalty.",
#   'chapter': 'Chapter 6',
#   'location': "Healer's tent in the desert",
#   'importance': 0.7,
#   'conflict': 0.3,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'vulnerable yet comforted',
#     'sentiment': 0.2,
#     'importance_rank': 1},
#    {'name': 'Lin',
#     'role': "Mei's servant and friend",
#     'importance': 0.8,
#     'emotion': 'supportive and compassionate',
#     'sentiment': 0.6,
#     'importance_rank': 2}],
#   'importance_rank': 5,
#   'conflict_rank': 5},
#  {'title': 'Oath to Complete the Journey',
#   'number': 27,
#   'summary': 'With her father bedridden, Mei vows to fulfill his mission, stepping into his role.',
#   'chapter': 'Chapter 7',
#   'location': 'Mountains near Samarkand',
#   'importance': 1.0,
#   'conflict': 0.6,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'determined and solemn',
#     'sentiment': 0.7,
#     'importance_rank': 1},
#    {'name': 'Zhang',
#     'role': "Mei's father",
#     'importance': 0.8,
#     'emotion': 'proud but weak',
#     'sentiment': 0.3,
#     'importance_rank': 2},
#    {'name': 'Farid',
#     'role': 'leader of the caravan',
#     'importance': 0.6,
#     'emotion': 'respectful and encouraging',
#     'sentiment': 0.5,
#     'importance_rank': 3}],
#   'importance_rank': 1,
#   'conflict_rank': 1},
#  {'title': 'Navigating Caravan Politics',
#   'number': 28,
#   'summary': 'Mei learns the complex dynamics within the caravan, gaining respect as a leader.',
#   'chapter': 'Chapter 7',
#   'location': 'Mountains near Samarkand',
#   'importance': 0.8,
#   'conflict': 0.5,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'empowered and cautious',
#     'sentiment': 0.6,
#     'importance_rank': 1},
#    {'name': 'Farid',
#     'role': 'leader of the caravan',
#     'importance': 0.7,
#     'emotion': 'supportive and instructive',
#     'sentiment': 0.4,
#     'importance_rank': 2},
#    {'name': 'Jin',
#     'role': 'caravan guard who befriends Mei',
#     'importance': 0.5,
#     'emotion': 'friendly and respectful',
#     'sentiment': 0.5,
#     'importance_rank': 3}],
#   'importance_rank': 3,
#   'conflict_rank': 3},
#  {'title': 'Kaveh’s Support and Mei’s Suspicions',
#   'number': 29,
#   'summary': 'Kaveh assists Mei with her new role, but she grows suspicious of his motives.',
#   'chapter': 'Chapter 7',
#   'location': 'Mountains near Samarkand',
#   'importance': 0.9,
#   'conflict': 0.6,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'grateful yet doubtful',
#     'sentiment': 0.2,
#     'importance_rank': 1},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.9,
#     'emotion': 'encouraging and enigmatic',
#     'sentiment': 0.4,
#     'importance_rank': 2}],
#   'importance_rank': 2,
#   'conflict_rank': 2},
#  {'title': 'The Bond with Nasrin',
#   'number': 30,
#   'summary': 'Mei meets Nasrin, Kaveh’s estranged sister, and learns more about Kaveh’s past.',
#   'chapter': 'Chapter 7',
#   'location': 'Mountains near Samarkand',
#   'importance': 0.8,
#   'conflict': 0.4,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'curious and empathetic',
#     'sentiment': 0.5,
#     'importance_rank': 1},
#    {'name': 'Nasrin',
#     'role': "Kaveh's estranged sister",
#     'importance': 0.8,
#     'emotion': 'guarded and reflective',
#     'sentiment': 0.1,
#     'importance_rank': 2},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.6,
#     'emotion': 'quiet and distant',
#     'sentiment': 0.2,
#     'importance_rank': 3}],
#   'importance_rank': 4,
#   'conflict_rank': 4},
#  {'title': 'Strengthening Alliances',
#   'number': 31,
#   'summary': 'Mei gains the respect of caravan members like Rashid, solidifying her position.',
#   'chapter': 'Chapter 7',
#   'location': 'Mountains near Samarkand',
#   'importance': 0.7,
#   'conflict': 0.3,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'determined and respected',
#     'sentiment': 0.6,
#     'importance_rank': 1},
#    {'name': 'Rashid',
#     'role': 'caravan helper',
#     'importance': 0.5,
#     'emotion': 'respectful and approving',
#     'sentiment': 0.4,
#     'importance_rank': 2},
#    {'name': 'Aliya',
#     'role': 'Persian healer who helps Zhang',
#     'importance': 0.4,
#     'emotion': 'kind and supportive',
#     'sentiment': 0.5,
#     'importance_rank': 3}],
#   'importance_rank': 5,
#   'conflict_rank': 5},
#  {'title': 'Entering the Golden Bazaar',
#   'number': 32,
#   'summary': 'The caravan arrives in the bustling Samarkand bazaar, where Mei is dazzled by its sights and sounds.',
#   'chapter': 'Chapter 8',
#   'location': 'Samarkand bazaar',
#   'importance': 0.7,
#   'conflict': 0.3,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'awe-inspired and curious',
#     'sentiment': 0.8,
#     'importance_rank': 1},
#    {'name': 'Farid',
#     'role': 'leader of the caravan',
#     'importance': 0.6,
#     'emotion': 'focused and vigilant',
#     'sentiment': 0.3,
#     'importance_rank': 2},
#    {'name': 'Jin',
#     'role': 'caravan guard who befriends Mei',
#     'importance': 0.4,
#     'emotion': 'protective and watchful',
#     'sentiment': 0.5,
#     'importance_rank': 3}],
#   'importance_rank': 5,
#   'conflict_rank': 5},
#  {'title': 'Encounter with Spies',
#   'number': 33,
#   'summary': 'Mei encounters spies in the bazaar who seem aware of her father’s mission.',
#   'chapter': 'Chapter 8',
#   'location': 'Samarkand bazaar',
#   'importance': 0.9,
#   'conflict': 0.8,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'alarmed and cautious',
#     'sentiment': -0.4,
#     'importance_rank': 1},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.8,
#     'emotion': 'protective and alert',
#     'sentiment': 0.1,
#     'importance_rank': 2},
#    {'name': 'Farid',
#     'role': 'leader of the caravan',
#     'importance': 0.7,
#     'emotion': 'concerned and tactical',
#     'sentiment': -0.1,
#     'importance_rank': 3}],
#   'importance_rank': 3,
#   'conflict_rank': 3},
#  {'title': 'Narrow Escape',
#   'number': 34,
#   'summary': 'Mei narrowly escapes from the spies in the bazaar with help from Kaveh and Jin.',
#   'chapter': 'Chapter 8',
#   'location': 'Samarkand bazaar',
#   'importance': 1.0,
#   'conflict': 0.9,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'fearful yet determined',
#     'sentiment': -0.3,
#     'importance_rank': 1},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.9,
#     'emotion': 'tense but quick-thinking',
#     'sentiment': 0.2,
#     'importance_rank': 2},
#    {'name': 'Jin',
#     'role': 'caravan guard who befriends Mei',
#     'importance': 0.7,
#     'emotion': 'brave and loyal',
#     'sentiment': 0.5,
#     'importance_rank': 3}],
#   'importance_rank': 1,
#   'conflict_rank': 1},
#  {'title': "The Emir's Guesthouse",
#   'number': 35,
#   'summary': 'The Emir provides Mei and the caravan shelter at his guesthouse, where political tensions surface.',
#   'chapter': 'Chapter 8',
#   'location': "Emir's guesthouse",
#   'importance': 0.8,
#   'conflict': 0.6,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'relieved yet suspicious',
#     'sentiment': 0.4,
#     'importance_rank': 1},
#    {'name': 'Emir',
#     'role': 'influential merchant in Samarkand',
#     'importance': 0.7,
#     'emotion': 'cordial but calculating',
#     'sentiment': 0.3,
#     'importance_rank': 2},
#    {'name': 'Darya',
#     'role': "Emir's wife who befriends Mei",
#     'importance': 0.6,
#     'emotion': 'friendly and empathetic',
#     'sentiment': 0.5,
#     'importance_rank': 3}],
#   'importance_rank': 4,
#   'conflict_rank': 4},
#  {'title': "Discovering the Mission's Exposure",
#   'number': 36,
#   'summary': "Mei realizes that her father's mission is known to powerful figures, placing her in danger.",
#   'chapter': 'Chapter 8',
#   'location': "Emir's guesthouse",
#   'importance': 1.0,
#   'conflict': 0.9,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'panicked but resolute',
#     'sentiment': -0.4,
#     'importance_rank': 1},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.8,
#     'emotion': 'supportive and strategic',
#     'sentiment': 0.2,
#     'importance_rank': 2},
#    {'name': 'Hassan',
#     'role': 'local trader and friend of the Emir',
#     'importance': 0.6,
#     'emotion': 'insightful but wary',
#     'sentiment': 0.1,
#     'importance_rank': 3}],
#   'importance_rank': 2,
#   'conflict_rank': 2},
#  {'title': 'Letters in the Dark',
#   'number': 37,
#   'summary': 'Mei discovers hidden letters that reveal Kaveh’s involvement with a secret organization.',
#   'chapter': 'Chapter 9',
#   'location': "Kaveh's quarters",
#   'importance': 1.0,
#   'conflict': 1.0,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'shocked and betrayed',
#     'sentiment': -0.6,
#     'importance_rank': 1},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.9,
#     'emotion': 'secretive and guarded',
#     'sentiment': -0.2,
#     'importance_rank': 2},
#    {'name': 'Rashid',
#     'role': 'caravan helper',
#     'importance': 0.5,
#     'emotion': 'loyal but conflicted',
#     'sentiment': 0.1,
#     'importance_rank': 3}],
#   'importance_rank': 1,
#   'conflict_rank': 1},
#  {'title': 'Confronting Kaveh',
#   'number': 38,
#   'summary': 'Mei confronts Kaveh about his hidden alliances and questions his loyalty.',
#   'chapter': 'Chapter 9',
#   'location': "Kaveh's quarters",
#   'importance': 1.0,
#   'conflict': 0.9,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'angry and hurt',
#     'sentiment': -0.5,
#     'importance_rank': 1},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 1.0,
#     'emotion': 'remorseful and conflicted',
#     'sentiment': -0.1,
#     'importance_rank': 2},
#    {'name': 'Rashid',
#     'role': 'caravan helper',
#     'importance': 0.4,
#     'emotion': 'tense and uneasy',
#     'sentiment': -0.2,
#     'importance_rank': 3}],
#   'importance_rank': 2,
#   'conflict_rank': 2},
#  {'title': 'Secrets of the Secret Meeting',
#   'number': 39,
#   'summary': 'Mei follows Kaveh to a hidden meeting spot and realizes his connection to influential allies.',
#   'chapter': 'Chapter 9',
#   'location': 'Secret meeting place',
#   'importance': 0.9,
#   'conflict': 0.8,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'tense and fearful',
#     'sentiment': -0.4,
#     'importance_rank': 1},
#    {'name': 'Tarek',
#     'role': 'fellow trader with a suspicious side',
#     'importance': 0.6,
#     'emotion': 'guarded and suspicious',
#     'sentiment': -0.3,
#     'importance_rank': 4},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.8,
#     'emotion': 'nervous and cautious',
#     'sentiment': -0.2,
#     'importance_rank': 2},
#    {'name': 'Omar',
#     'role': 'spy watching the caravan',
#     'importance': 0.7,
#     'emotion': 'calculating and wary',
#     'sentiment': -0.5,
#     'importance_rank': 3}],
#   'importance_rank': 4,
#   'conflict_rank': 4},
#  {'title': 'The Choice to Trust',
#   'number': 40,
#   'summary': 'Mei faces a choice: confront Kaveh about her discovery or trust him despite his secrecy.',
#   'chapter': 'Chapter 9',
#   'location': 'Samarkand',
#   'importance': 1.0,
#   'conflict': 0.9,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'conflicted and anxious',
#     'sentiment': -0.2,
#     'importance_rank': 1},
#    {'name': 'Nasrin',
#     'role': "Kaveh's estranged sister",
#     'importance': 0.8,
#     'emotion': 'understanding and supportive',
#     'sentiment': 0.4,
#     'importance_rank': 3},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 1.0,
#     'emotion': 'remorseful and sincere',
#     'sentiment': 0.2,
#     'importance_rank': 2},
#    {'name': 'Rashid',
#     'role': 'caravan helper',
#     'importance': 0.5,
#     'emotion': 'loyal and supportive',
#     'sentiment': 0.3,
#     'importance_rank': 4}],
#   'importance_rank': 3,
#   'conflict_rank': 3},
#  {'title': 'Revelations and Realizations',
#   'number': 41,
#   'summary': 'Mei realizes that Kaveh has been protecting her, not only for the mission, but because of personal loyalty.',
#   'chapter': 'Chapter 9',
#   'location': 'Samarkand',
#   'importance': 0.8,
#   'conflict': 0.7,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'surprised and softened',
#     'sentiment': 0.3,
#     'importance_rank': 1},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 1.0,
#     'emotion': 'honest and vulnerable',
#     'sentiment': 0.4,
#     'importance_rank': 2},
#    {'name': 'Laila',
#     'role': 'maid at the Samarkand guesthouse',
#     'importance': 0.5,
#     'emotion': 'empathetic and gentle',
#     'sentiment': 0.5,
#     'importance_rank': 4},
#    {'name': 'Omar',
#     'role': 'spy watching the caravan',
#     'importance': 0.6,
#     'emotion': 'disappointed and cautious',
#     'sentiment': -0.4,
#     'importance_rank': 3}],
#   'importance_rank': 5,
#   'conflict_rank': 5},
#  {'title': 'Encounter on the Persian Road',
#   'number': 42,
#   'summary': 'Mei meets a disguised prince on the caravan route through Persia, who shows interest in her father’s mission.',
#   'chapter': 'Chapter 10',
#   'location': 'Caravan route through Persia',
#   'importance': 0.8,
#   'conflict': 0.4,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'curious and cautious',
#     'sentiment': 0.5,
#     'importance_rank': 1},
#    {'name': 'Prince Cyrus',
#     'role': 'Persian prince in disguise',
#     'importance': 0.9,
#     'emotion': 'charming and enigmatic',
#     'sentiment': 0.6,
#     'importance_rank': 2},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.7,
#     'emotion': 'respectful but reserved',
#     'sentiment': 0.4,
#     'importance_rank': 3}],
#   'importance_rank': 3,
#   'conflict_rank': 3},
#  {'title': 'The Prince’s Encampment',
#   'number': 43,
#   'summary': 'Prince Cyrus invites Mei to his secluded encampment, where he offers support for her father’s peace mission.',
#   'chapter': 'Chapter 10',
#   'location': "Prince's encampment",
#   'importance': 1.0,
#   'conflict': 0.5,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'honored yet cautious',
#     'sentiment': 0.7,
#     'importance_rank': 1},
#    {'name': 'Prince Cyrus',
#     'role': 'Persian prince in disguise',
#     'importance': 1.0,
#     'emotion': 'insightful and sincere',
#     'sentiment': 0.8,
#     'importance_rank': 2},
#    {'name': 'Bahram',
#     'role': "Persian contact for Mei's father",
#     'importance': 0.6,
#     'emotion': 'loyal and respectful',
#     'sentiment': 0.5,
#     'importance_rank': 3}],
#   'importance_rank': 1,
#   'conflict_rank': 2},
#  {'title': 'Glimpses of Political Intrigue',
#   'number': 44,
#   'summary': 'Mei realizes the complex political web surrounding her father’s mission, with various factions having vested interests.',
#   'chapter': 'Chapter 10',
#   'location': "Prince's encampment",
#   'importance': 0.9,
#   'conflict': 0.6,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'overwhelmed but determined',
#     'sentiment': 0.3,
#     'importance_rank': 1},
#    {'name': 'Prince Cyrus',
#     'role': 'Persian prince in disguise',
#     'importance': 0.8,
#     'emotion': 'strategic and thoughtful',
#     'sentiment': 0.5,
#     'importance_rank': 2},
#    {'name': 'Nasrin',
#     'role': "Kaveh's estranged sister",
#     'importance': 0.7,
#     'emotion': 'insightful and supportive',
#     'sentiment': 0.4,
#     'importance_rank': 3},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.7,
#     'emotion': 'thoughtful and protective',
#     'sentiment': 0.5,
#     'importance_rank': 4}],
#   'importance_rank': 2,
#   'conflict_rank': 1},
#  {'title': 'A Cultural Link',
#   'number': 45,
#   'summary': 'Mei realizes her role as a cultural bridge, connecting China and Persia through her father’s mission.',
#   'chapter': 'Chapter 10',
#   'location': "Prince's encampment",
#   'importance': 0.8,
#   'conflict': 0.3,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'reflective and inspired',
#     'sentiment': 0.6,
#     'importance_rank': 1},
#    {'name': 'Prince Cyrus',
#     'role': 'Persian prince in disguise',
#     'importance': 0.9,
#     'emotion': 'supportive and encouraging',
#     'sentiment': 0.7,
#     'importance_rank': 2},
#    {'name': 'Parisa',
#     'role': 'palace maid who aids Mei',
#     'importance': 0.5,
#     'emotion': 'humble and kind',
#     'sentiment': 0.4,
#     'importance_rank': 3}],
#   'importance_rank': 4,
#   'conflict_rank': 4},
#  {'title': 'Strengthening Bonds',
#   'number': 46,
#   'summary': 'Mei forms a stronger bond with Rashid, who offers his insights on the Persian culture and the journey ahead.',
#   'chapter': 'Chapter 10',
#   'location': "Prince's encampment",
#   'importance': 0.7,
#   'conflict': 0.2,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'grateful and contemplative',
#     'sentiment': 0.5,
#     'importance_rank': 1},
#    {'name': 'Rashid',
#     'role': 'caravan helper',
#     'importance': 0.6,
#     'emotion': 'supportive and wise',
#     'sentiment': 0.4,
#     'importance_rank': 2},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.5,
#     'emotion': 'attentive and thoughtful',
#     'sentiment': 0.5,
#     'importance_rank': 3}],
#   'importance_rank': 5,
#   'conflict_rank': 5},
#  {'title': 'Arrival at the Persian Palace',
#   'number': 47,
#   'summary': 'Mei arrives at the grand Persian palace to deliver the scroll, facing a mix of awe and trepidation.',
#   'chapter': 'Chapter 11',
#   'location': 'Persian palace',
#   'importance': 0.9,
#   'conflict': 0.4,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'awed and anxious',
#     'sentiment': 0.4,
#     'importance_rank': 1},
#    {'name': 'Prince Cyrus',
#     'role': 'Persian prince',
#     'importance': 0.8,
#     'emotion': 'welcoming yet formal',
#     'sentiment': 0.5,
#     'importance_rank': 2},
#    {'name': 'Bahram',
#     'role': "Persian contact for Mei's father",
#     'importance': 0.7,
#     'emotion': 'respectful and supportive',
#     'sentiment': 0.5,
#     'importance_rank': 3},
#    {'name': 'Rashid',
#     'role': 'caravan helper',
#     'importance': 0.6,
#     'emotion': 'loyal and reassuring',
#     'sentiment': 0.4,
#     'importance_rank': 4}],
#   'importance_rank': 3,
#   'conflict_rank': 5},
#  {'title': 'Delivering the Scroll',
#   'number': 48,
#   'summary': 'Mei formally delivers the scroll, understanding the potential impact on relations between China and Persia.',
#   'chapter': 'Chapter 11',
#   'location': 'Persian palace',
#   'importance': 1.0,
#   'conflict': 0.6,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'focused and resolved',
#     'sentiment': 0.6,
#     'importance_rank': 1},
#    {'name': 'Prince Cyrus',
#     'role': 'Persian prince',
#     'importance': 0.9,
#     'emotion': 'appreciative and solemn',
#     'sentiment': 0.6,
#     'importance_rank': 2},
#    {'name': 'Queen Soraya',
#     'role': 'Persian queen involved in political tensions',
#     'importance': 0.8,
#     'emotion': 'dignified yet skeptical',
#     'sentiment': -0.1,
#     'importance_rank': 3},
#    {'name': 'Nasrin',
#     'role': "Kaveh's estranged sister",
#     'importance': 0.7,
#     'emotion': 'quietly supportive',
#     'sentiment': 0.3,
#     'importance_rank': 4}],
#   'importance_rank': 1,
#   'conflict_rank': 3},
#  {'title': 'A Moment in the Royal Gardens',
#   'number': 49,
#   'summary': 'Mei reflects in the serene royal gardens, weighing her decision between love and duty.',
#   'chapter': 'Chapter 11',
#   'location': 'Royal gardens',
#   'importance': 0.8,
#   'conflict': 0.5,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'pensive and conflicted',
#     'sentiment': 0.2,
#     'importance_rank': 1},
#    {'name': 'Prince Cyrus',
#     'role': 'Persian prince',
#     'importance': 0.7,
#     'emotion': 'encouraging and insightful',
#     'sentiment': 0.5,
#     'importance_rank': 3},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.9,
#     'emotion': 'hopeful yet understanding',
#     'sentiment': 0.4,
#     'importance_rank': 2},
#    {'name': 'Aisha',
#     'role': 'skilled herbalist and healer',
#     'importance': 0.6,
#     'emotion': 'calming and wise',
#     'sentiment': 0.5,
#     'importance_rank': 4}],
#   'importance_rank': 5,
#   'conflict_rank': 4},
#  {'title': 'The Queen’s Offer',
#   'number': 50,
#   'summary': 'Queen Soraya offers Mei a choice: to remain in Persia and deepen her role in diplomacy or return to China.',
#   'chapter': 'Chapter 11',
#   'location': 'Persian palace',
#   'importance': 0.9,
#   'conflict': 0.7,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'torn and contemplative',
#     'sentiment': 0.3,
#     'importance_rank': 1},
#    {'name': 'Queen Soraya',
#     'role': 'Persian queen involved in political tensions',
#     'importance': 1.0,
#     'emotion': 'strategic and persuasive',
#     'sentiment': 0.0,
#     'importance_rank': 2},
#    {'name': 'Bahram',
#     'role': "Persian contact for Mei's father",
#     'importance': 0.6,
#     'emotion': 'supportive and understanding',
#     'sentiment': 0.5,
#     'importance_rank': 3},
#    {'name': 'Nasrin',
#     'role': "Kaveh's estranged sister",
#     'importance': 0.5,
#     'emotion': 'encouraging and empathetic',
#     'sentiment': 0.4,
#     'importance_rank': 4}],
#   'importance_rank': 4,
#   'conflict_rank': 2},
#  {'title': 'Heart and Duty',
#   'number': 51,
#   'summary': 'Mei confronts her inner conflict between family loyalty and her feelings for Kaveh, recognizing the gravity of her choice.',
#   'chapter': 'Chapter 11',
#   'location': 'Royal gardens',
#   'importance': 1.0,
#   'conflict': 0.9,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'conflicted and emotional',
#     'sentiment': -0.1,
#     'importance_rank': 1},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 1.0,
#     'emotion': 'understanding and hopeful',
#     'sentiment': 0.4,
#     'importance_rank': 2},
#    {'name': 'Prince Cyrus',
#     'role': 'Persian prince',
#     'importance': 0.7,
#     'emotion': 'supportive and neutral',
#     'sentiment': 0.3,
#     'importance_rank': 3},
#    {'name': 'Rashid',
#     'role': 'caravan helper',
#     'importance': 0.5,
#     'emotion': 'respectful and supportive',
#     'sentiment': 0.3,
#     'importance_rank': 4}],
#   'importance_rank': 2,
#   'conflict_rank': 1},
#  {'title': 'Final Conversations in the Palace',
#   'number': 52,
#   'summary': 'Before leaving, Mei has final conversations in the Persian palace, reflecting on her journey and growth.',
#   'chapter': 'Chapter 12',
#   'location': 'Persian palace',
#   'importance': 0.8,
#   'conflict': 0.3,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'reflective and grateful',
#     'sentiment': 0.6,
#     'importance_rank': 1},
#    {'name': 'Prince Cyrus',
#     'role': 'Persian prince',
#     'importance': 0.7,
#     'emotion': 'supportive and encouraging',
#     'sentiment': 0.5,
#     'importance_rank': 3},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.8,
#     'emotion': 'hopeful and warm',
#     'sentiment': 0.5,
#     'importance_rank': 2},
#    {'name': 'Hadi',
#     'role': 'Indian trader',
#     'importance': 0.5,
#     'emotion': 'respectful and admiring',
#     'sentiment': 0.4,
#     'importance_rank': 4}],
#   'importance_rank': 4,
#   'conflict_rank': 2},
#  {'title': 'Farewell to Persia',
#   'number': 53,
#   'summary': 'Mei says goodbye to her friends and allies, knowing her journey has changed her forever.',
#   'chapter': 'Chapter 12',
#   'location': 'Persian palace',
#   'importance': 0.9,
#   'conflict': 0.4,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'grateful and emotional',
#     'sentiment': 0.6,
#     'importance_rank': 1},
#    {'name': 'Queen Soraya',
#     'role': 'Persian queen involved in political tensions',
#     'importance': 0.6,
#     'emotion': 'dignified and approving',
#     'sentiment': 0.3,
#     'importance_rank': 3},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.9,
#     'emotion': 'supportive but saddened',
#     'sentiment': 0.4,
#     'importance_rank': 2},
#    {'name': 'Bahram',
#     'role': "Persian contact for Mei's father",
#     'importance': 0.5,
#     'emotion': 'loyal and respectful',
#     'sentiment': 0.4,
#     'importance_rank': 4},
#    {'name': 'Kalden',
#     'role': 'Tibetan monk and occasional healer',
#     'importance': 0.5,
#     'emotion': 'wise and calm',
#     'sentiment': 0.5,
#     'importance_rank': 5}],
#   'importance_rank': 3,
#   'conflict_rank': 1},
#  {'title': 'Reflecting on the Silk Road',
#   'number': 54,
#   'summary': 'As the caravan begins its return, Mei reflects on the journey and her newfound purpose.',
#   'chapter': 'Chapter 12',
#   'location': 'Caravan home camp',
#   'importance': 1.0,
#   'conflict': 0.2,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'hopeful and fulfilled',
#     'sentiment': 0.7,
#     'importance_rank': 1},
#    {'name': 'Rashid',
#     'role': 'caravan helper',
#     'importance': 0.6,
#     'emotion': 'encouraging and loyal',
#     'sentiment': 0.5,
#     'importance_rank': 2},
#    {'name': 'Aisha',
#     'role': 'skilled herbalist and healer',
#     'importance': 0.5,
#     'emotion': 'wise and compassionate',
#     'sentiment': 0.6,
#     'importance_rank': 3},
#    {'name': 'Hadi',
#     'role': 'Indian trader',
#     'importance': 0.4,
#     'emotion': 'friendly and respectful',
#     'sentiment': 0.4,
#     'importance_rank': 4}],
#   'importance_rank': 1,
#   'conflict_rank': 4},
#  {'title': 'Returning Home with New Wisdom',
#   'number': 55,
#   'summary': 'Mei returns to China, transformed by her experiences, and contemplates carrying on her father’s legacy.',
#   'chapter': 'Chapter 12',
#   'location': 'Caravan home camp',
#   'importance': 1.0,
#   'conflict': 0.3,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'resolved and inspired',
#     'sentiment': 0.8,
#     'importance_rank': 1},
#    {'name': 'Zhang',
#     'role': "Mei's father",
#     'importance': 0.8,
#     'emotion': 'proud and supportive',
#     'sentiment': 0.7,
#     'importance_rank': 2},
#    {'name': 'Li Wei',
#     'role': 'old woman and mystic',
#     'importance': 0.5,
#     'emotion': 'wise and mysterious',
#     'sentiment': 0.4,
#     'importance_rank': 4},
#    {'name': 'Kalden',
#     'role': 'Tibetan monk and occasional healer',
#     'importance': 0.6,
#     'emotion': 'serene and reflective',
#     'sentiment': 0.5,
#     'importance_rank': 3}],
#   'importance_rank': 2,
#   'conflict_rank': 3}]

# %%
chapters
# Out:
# [{'chapter': "Chapter 1: The Merchant's Daughter",
#   'summary': 'Mei prepares for a journey on the Silk Road with her father.',
#   'description': 'Mei, the daughter of a respected tea merchant, helps her father pack for their Silk Road journey. She yearns for adventure but is told her place is at home. Circumstances change suddenly, and she is asked to accompany him, stepping into a world far beyond her imagination.',
#   'importance': 0.6,
#   'conflict': 0.2,
#   'locations': {"Mei's family home": {'role': "Chang'an, Mei's family home and the starting point for the journey.",
#     'count': 3},
#    'Tea market': {'role': "Local market in Chang'an where Mei's father trades.",
#     'count': 1}},
#   'characters': {'Mei': {'role': 'Protagonist, daughter of a tea merchant.',
#     'count': 4},
#    'Zhang': {'role': "Mei's father, a respected merchant.", 'count': 4},
#    'Lin': {'role': "Mei's servant and friend.", 'count': 1},
#    'Lao Feng': {'role': "Local merchant in Chang'an.", 'count': 1},
#    'Li Yuan': {'role': 'Family friend and fellow trader.', 'count': 1}},
#   'scenes': 4},
#  {'chapter': 'Chapter 2: Caravan of Secrets',
#   'summary': 'Mei joins the caravan and meets new travelers, including Kaveh.',
#   'description': "Mei joins her father and the caravan of traders. She meets intriguing travelers and realizes the Silk Road is alive with stories and whispered rumors of political schemes. She learns her father is involved in more than just trade—he's carrying a secret message to the Persian Empire.",
#   'importance': 0.7,
#   'conflict': 0.4,
#   'locations': {"Chang'an city gates": {'role': 'Departure point where Mei joins the caravan.',
#     'count': 1},
#    'Caravan encampment': {'role': 'Staging area for the travelers to organize before leaving.',
#     'count': 4}},
#   'characters': {'Mei': {'role': 'Protagonist, daughter of a tea merchant.',
#     'count': 5},
#    'Zhang': {'role': "Mei's father, a respected merchant.", 'count': 2},
#    'Kaveh': {'role': 'Persian merchant and potential love interest.',
#     'count': 2},
#    'Farid': {'role': 'Leader of the caravan.', 'count': 2},
#    'Old Wang': {'role': 'Camel handler in the caravan.', 'count': 1}},
#   'scenes': 4},
#  {'chapter': 'Chapter 3: An Encounter in the Desert',
#   'summary': 'A Persian merchant joins, and Mei learns of potential spies.',
#   'description': "The caravan travels through the Gobi Desert. Mei meets a Persian merchant named Kaveh and is drawn to his knowledge and charm. He warns Mei of spies on the road and hints that her father's mission is dangerous.",
#   'importance': 0.6,
#   'conflict': 0.5,
#   'locations': {'Gobi Desert': {'role': 'Harsh terrain where the caravan encounters challenges.',
#     'count': 2},
#    'Oasis stop': {'role': 'Temporary rest stop for travelers and camels.',
#     'count': 3}},
#   'characters': {'Mei': {'role': 'Protagonist, daughter of a tea merchant.',
#     'count': 5},
#    'Kaveh': {'role': 'Persian merchant and potential love interest.',
#     'count': 2},
#    'Farid': {'role': 'Leader of the caravan.', 'count': 2},
#    'Jia': {'role': 'Young traveler within the caravan.', 'count': 1},
#    'Hadi': {'role': 'Indian trader along the Silk Road.', 'count': 1},
#    'Badr': {'role': "Kaveh's loyal bodyguard.", 'count': 1},
#    'Aisha': {'role': 'Skilled herbalist and healer.', 'count': 1},
#    'Old Wang': {'role': 'Camel handler in the caravan.', 'count': 1}},
#   'scenes': 5},
#  {'chapter': 'Chapter 4: Bandits in the Night',
#   'summary': "Bandits attack the caravan, injuring Mei's father.",
#   'description': "Bandits attack the caravan at night, attempting to steal Mei's father's goods. Mei narrowly escapes, but her father is injured. She begins to realize the stakes of the journey and the risks they face on this volatile route.",
#   'importance': 0.8,
#   'conflict': 0.8,
#   'locations': {'Desert camp': {'role': 'Temporary camp for the caravan, attacked by bandits.',
#     'count': 3},
#    'Bandit hideout in dunes': {'role': 'Location where bandits regroup after ambush.',
#     'count': 1}},
#   'characters': {'Mei': {'role': 'Protagonist, daughter of a tea merchant.',
#     'count': 3},
#    'Zhang': {'role': "Mei's father, a respected merchant.", 'count': 3},
#    'Kaveh': {'role': 'Persian merchant and potential love interest.',
#     'count': 2},
#    'Farid': {'role': 'Leader of the caravan.', 'count': 3},
#    'Aisha': {'role': 'Skilled herbalist and healer.', 'count': 2},
#    'Saeed': {'role': 'Leader of the bandits.', 'count': 2},
#    'Yara': {'role': 'Bandit skilled with a bow.', 'count': 2},
#    'Yao': {'role': 'Guard for the caravan.', 'count': 1},
#    'Jin': {'role': 'Caravan guard who befriends Mei.', 'count': 1}},
#   'scenes': 4},
#  {'chapter': 'Chapter 5: The Town of Lost Souls',
#   'summary': 'A mystic offers Mei a glimpse into her future.',
#   'description': "The caravan stops in a remote desert town. Mei meets an old woman who reads tea leaves and warns her of a choice between heart and duty. Mei learns about the cultural significance of tea and finds herself even more intrigued by Kaveh's world.",
#   'importance': 0.6,
#   'conflict': 0.3,
#   'locations': {'Caravanserai': {'role': 'Remote town with a mystical reputation where Mei meets the old woman.',
#     'count': 4}},
#   'characters': {'Mei': {'role': 'Protagonist, daughter of a tea merchant.',
#     'count': 4},
#    'Kaveh': {'role': 'Persian merchant and potential love interest.',
#     'count': 2},
#    'Li Wei': {'role': "Old woman who reads Mei's fortune.", 'count': 1},
#    'Zhang': {'role': "Mei's father, a respected merchant.", 'count': 3},
#    'Zhao': {'role': 'Local mystic in the town.', 'count': 1},
#    'Kalden': {'role': 'Tibetan monk and occasional healer.', 'count': 1}},
#   'scenes': 4},
#  {'chapter': 'Chapter 6: The Scroll of Secrets',
#   'summary': "Kaveh reveals the mission of peace Mei's father was tasked with.",
#   'description': "Mei's father falls ill, and Kaveh reveals her father is carrying a scroll intended to broker peace between China and Persia. Mei realizes the significance of their mission and feels a burden of responsibility as her father grows weaker.",
#   'importance': 0.9,
#   'conflict': 0.7,
#   'locations': {'Caravan encampment': {'role': "Desert stop where Mei takes responsibility for her father's mission.",
#     'count': 2},
#    "Healer's tent in the desert": {'role': "Where Mei's father receives treatment.",
#     'count': 3}},
#   'characters': {'Mei': {'role': 'Protagonist, daughter of a tea merchant.',
#     'count': 5},
#    'Kaveh': {'role': 'Persian merchant and potential love interest.',
#     'count': 2},
#    'Zhang': {'role': "Mei's father, a respected merchant.", 'count': 2},
#    'Farid': {'role': 'Leader of the caravan.', 'count': 2},
#    'Bahram': {'role': "Persian contact for Mei's father.", 'count': 1},
#    'Sohrab': {'role': 'Persian messenger.', 'count': 1},
#    'Lin': {'role': "Mei's servant and friend.", 'count': 1},
#    'Aliya': {'role': 'Persian healer who helps Zhang.', 'count': 2}},
#   'scenes': 5},
#  {'chapter': 'Chapter 7: An Oath to Complete the Journey',
#   'summary': "Mei takes on her father's role and leads the caravan.",
#   'description': 'With her father bedridden, Mei vows to complete his mission. She learns trade tactics, navigates caravan politics, and gains respect among the travelers. Kaveh supports her, but Mei suspects he has his own agenda.',
#   'importance': 0.9,
#   'conflict': 0.6,
#   'locations': {'Mountains near Samarkand': {'role': 'Symbolic entry point to Samarkand, where Mei takes on a leadership role.',
#     'count': 5}},
#   'characters': {'Mei': {'role': 'Protagonist, daughter of a tea merchant.',
#     'count': 5},
#    'Kaveh': {'role': 'Persian merchant and potential love interest.',
#     'count': 2},
#    'Zhang': {'role': "Mei's father, a respected merchant.", 'count': 1},
#    'Farid': {'role': 'Leader of the caravan.', 'count': 2},
#    'Jin': {'role': 'Caravan guard who befriends Mei.', 'count': 1},
#    'Nasrin': {'role': "Kaveh's estranged sister.", 'count': 1},
#    'Rashid': {'role': 'Caravan helper.', 'count': 1},
#    'Aliya': {'role': 'Persian healer who helps Zhang.', 'count': 1}},
#   'scenes': 5},
#  {'chapter': 'Chapter 8: The Golden Bazaar',
#   'summary': 'Mei encounters spies and deception in the bustling Samarkand bazaar.',
#   'description': "The caravan reaches Samarkand, a bustling trade hub. Mei encounters spies from rival kingdoms and narrowly escapes. She discovers that her father's mission is known to powerful forces, making her a target.",
#   'importance': 1.0,
#   'conflict': 0.9,
#   'locations': {'Samarkand bazaar': {'role': 'Lively trade center where Mei encounters spies.',
#     'count': 3},
#    "Emir's guesthouse": {'role': 'Lavish space where political deals take place.',
#     'count': 2}},
#   'characters': {'Mei': {'role': 'Protagonist, daughter of a tea merchant.',
#     'count': 5},
#    'Kaveh': {'role': 'Persian merchant and potential love interest.',
#     'count': 3},
#    'Farid': {'role': 'Leader of the caravan.', 'count': 2},
#    'Jin': {'role': 'Caravan guard who befriends Mei.', 'count': 2},
#    'Emir': {'role': 'Influential merchant in Samarkand.', 'count': 1},
#    'Darya': {'role': "Emir's wife, who befriends Mei.", 'count': 1},
#    'Hassan': {'role': 'Local trader and friend of the Emir.', 'count': 1}},
#   'scenes': 5},
#  {'chapter': 'Chapter 9: Letters in the Dark',
#   'summary': "Mei discovers Kaveh's true motives and hidden alliances.",
#   'description': "Mei finds letters revealing that Kaveh is part of a secret organization with its own aims. Mei must decide if she can trust him after realizing he's been protecting her for more than her mission's sake.",
#   'importance': 1.0,
#   'conflict': 1.0,
#   'locations': {'Samarkand': {'role': 'City where Mei uncovers the truth about Kaveh.',
#     'count': 2},
#    "Kaveh's quarters": {'role': 'Private space where Mei finds the letters.',
#     'count': 2},
#    'Secret meeting place': {'role': 'Secluded spot where Kaveh meets allies.',
#     'count': 1}},
#   'characters': {'Mei': {'role': 'Protagonist, daughter of a tea merchant.',
#     'count': 5},
#    'Kaveh': {'role': 'Persian merchant and potential love interest.',
#     'count': 5},
#    'Nasrin': {'role': "Kaveh's estranged sister.", 'count': 1},
#    'Rashid': {'role': 'Caravan helper.', 'count': 3},
#    'Tarek': {'role': 'Fellow trader with a suspicious side.', 'count': 1},
#    'Laila': {'role': 'Maid at the Samarkand guesthouse.', 'count': 1},
#    'Omar': {'role': 'Spy watching the caravan.', 'count': 2}},
#   'scenes': 5},
#  {'chapter': 'Chapter 10: A Prince in Disguise',
#   'summary': 'Mei allies with a Persian prince disguised as a commoner.',
#   'description': "In Persia, Mei meets a prince in disguise who supports her father's peace mission. She realizes the complex political web surrounding her journey and sees herself as a cultural link.",
#   'importance': 0.8,
#   'conflict': 0.6,
#   'locations': {'Caravan route through Persia': {'role': 'Road where Mei encounters the prince.',
#     'count': 1},
#    "Prince's encampment": {'role': 'Hidden camp where the prince meets Mei.',
#     'count': 4}},
#   'characters': {'Mei': {'role': 'Protagonist, daughter of a tea merchant.',
#     'count': 5},
#    'Kaveh': {'role': 'Persian merchant and potential love interest.',
#     'count': 3},
#    'Prince Cyrus': {'role': 'Persian prince in disguise.', 'count': 4},
#    'Bahram': {'role': "Persian contact for Mei's father.", 'count': 1},
#    'Nasrin': {'role': "Kaveh's estranged sister.", 'count': 1},
#    'Rashid': {'role': 'Caravan helper.', 'count': 1},
#    'Parisa': {'role': 'Palace maid who aids Mei.', 'count': 1}},
#   'scenes': 5},
#  {'chapter': 'Chapter 11: The Heart and the Choice',
#   'summary': 'Mei faces a decision between duty and love.',
#   'description': "Mei delivers the scroll, knowing it could change history. She's offered a choice: stay in Persia and learn her father's world or return home, possibly never seeing Kaveh again. She struggles between family loyalty and budding love.",
#   'importance': 0.9,
#   'conflict': 0.7,
#   'locations': {'Persian palace': {'role': "Site of Mei's pivotal decision.",
#     'count': 3},
#    'Royal gardens': {'role': 'Serene setting where Mei contemplates her choice.',
#     'count': 2}},
#   'characters': {'Mei': {'role': 'Protagonist, daughter of a tea merchant.',
#     'count': 5},
#    'Kaveh': {'role': 'Persian merchant and potential love interest.',
#     'count': 2},
#    'Prince Cyrus': {'role': 'Persian prince.', 'count': 4},
#    'Bahram': {'role': "Persian contact for Mei's father.", 'count': 2},
#    'Nasrin': {'role': "Kaveh's estranged sister.", 'count': 2},
#    'Rashid': {'role': 'Caravan helper.', 'count': 2},
#    'Aisha': {'role': 'Skilled herbalist and healer.', 'count': 1},
#    'Queen Soraya': {'role': 'Persian queen involved in political tensions.',
#     'count': 2}},
#   'scenes': 5},
#  {'chapter': 'Chapter 12: Whispers of the Silk Road',
#   'summary': 'Mei reflects on her journey and returns home, carrying new wisdom.',
#   'description': "Mei returns to China, her heart changed and her eyes opened to the world. She realizes her journey was just the beginning, and she has the potential to carry on her father's legacy of bridging cultures through trade and diplomacy.",
#   'importance': 1.0,
#   'conflict': 0.4,
#   'locations': {'Persian palace': {'role': "Site of Mei's final conversations and realizations.",
#     'count': 2},
#    'Caravan home camp': {'role': "Returning point marking the end of Mei's journey.",
#     'count': 2}},
#   'characters': {'Mei': {'role': 'Protagonist, daughter of a tea merchant.',
#     'count': 4},
#    'Kaveh': {'role': 'Persian merchant and potential love interest.',
#     'count': 2},
#    'Rashid': {'role': 'Caravan helper.', 'count': 1},
#    'Bahram': {'role': "Persian contact for Mei's father.", 'count': 1},
#    'Li Wei': {'role': 'Old woman and mystic.', 'count': 1},
#    'Zhang': {'role': "Mei's father, a respected merchant.", 'count': 1},
#    'Hadi': {'role': 'Indian trader.', 'count': 2},
#    'Kalden': {'role': 'Tibetan monk and occasional healer.', 'count': 2},
#    'Prince Cyrus': {'role': 'Persian prince.', 'count': 1},
#    'Queen Soraya': {'role': 'Persian queen.', 'count': 1},
#    'Aisha': {'role': 'Skilled herbalist and healer.', 'count': 1}},
#   'scenes': 4}]

# %%
# update json file
with open(f'json/{story}/story_outline.json', 'w') as file:
    new_outline = {
        "title": "Whispers of the Tea Route",
        "type": "Book",
        "author": "ChatGPT",
        "year": 2024,
        "num_chapters": 12,
        "num_scenes": 56,
        "num_characters": 34,
        "num_locations": 21,
    }
    new_outline['chapters'] = chapters
    new_outline['scenes'] = scenes
    new_outline['characters'] = characters
    new_outline['locations'] = locations
    json.dump(new_outline, file, indent=4)

# %% [markdown]
# ## get first and last lines for each scene

# %%
def get_scene_boundaries(text_file_path, line_file_path):
    # Read the main text file and find positions of "XXX"
    with open(text_file_path, 'r') as text_file:
        text_lines = text_file.readlines()
    
    # read file with line numbers
    with open(line_file_path, 'r') as line_file:
        line_numbers = line_file.readlines()
    
    # Gather start and end line numbers for each scene based on "XXX" markers
    scene_boundaries = []
    scene_start = 1  # Assuming line numbers start from 1
    for idx, line in enumerate(text_lines):
        if "XXX" in line:
            # find first line after "XXX" that is not empty
            next_line = text_lines[idx + 2][:50]

            # find line number in line_numbers file
            end_index = -1
            for i, line_num in enumerate(line_numbers):
                if next_line in line_num:
                    end_index = i + 1
                    scene_boundaries.append((scene_start, end_index - 1))
                    scene_start = end_index  # Set next scene start after "XXX"
                    idx += 3
                    break
    
    # add last scene boundary
    scene_boundaries.append((scene_start, len(line_numbers)))
    
    
    # Translate scene boundaries to line numbers
    # scene_line_numbers = [(line_numbers[start - 1], line_numbers[end - 1]) for start, end in scene_boundaries]
    
    return scene_boundaries

# %%
# Paths to your files
chapter_folder = f'chapters/{story}'              # Folder with chapter files
scripts_folder = f'scripts'                         # Folder with script files
text_file_path = f'{scripts_folder}/{story}_og.txt'  # File with main text and "XXX"

# read in story_outline.json
with open(f'json/{story}/story_outline.json', 'r') as file:
    story_outline = json.load(file)

chapters = story_outline['chapters']
scenes = story_outline['scenes']

chapter_lines = {}

for chapter in chapters:
    chapter_name = chapter['chapter']
    line_file_path = f'{chapter_folder}/{chapter_name}.txt'      # File with line numbers

    # Call the function and display results
    scene_line_numbers = get_scene_boundaries(text_file_path, line_file_path) 

    # Print scene line numbers
    print(chapter_name)
    for idx, (start, end) in enumerate(scene_line_numbers, 1):
        print(f"scene {idx}: starts at line {start}, ends at line {end}")
    print()

    chapter_lines[chapter_name] = scene_line_numbers
# Out:
# Chapter 1: The Merchant's Daughter
# scene 1: starts at line 1, ends at line 32
# scene 2: starts at line 33, ends at line 56
# scene 3: starts at line 57, ends at line 76
# scene 4: starts at line 77, ends at line 96
#
# Chapter 2: Caravan of Secrets
# scene 1: starts at line 1, ends at line 37
# scene 2: starts at line 38, ends at line 72
# scene 3: starts at line 73, ends at line 101
# scene 4: starts at line 102, ends at line 127
#
# Chapter 3: An Encounter in the Desert
# scene 1: starts at line 1, ends at line 53
# scene 2: starts at line 54, ends at line 87
# scene 3: starts at line 88, ends at line 113
# scene 4: starts at line 114, ends at line 147
# scene 5: starts at line 148, ends at line 180
#
# Chapter 4: Bandits in the Night
# scene 1: starts at line 1, ends at line 40
# scene 2: starts at line 41, ends at line 79
# scene 3: starts at line 80, ends at line 117
# scene 4: starts at line 118, ends at line 154
#
# Chapter 5: The Town of Lost Souls
# scene 1: starts at line 1, ends at line 52
# scene 2: starts at line 53, ends at line 87
# scene 3: starts at line 88, ends at line 118
# scene 4: starts at line 119, ends at line 150
#
# Chapter 6: The Scroll of Secrets
# scene 1: starts at line 1, ends at line 42
# scene 2: starts at line 43, ends at line 76
# scene 3: starts at line 77, ends at line 105
# scene 4: starts at line 106, ends at line 132
# scene 5: starts at line 133, ends at line 165
#
# Chapter 7: An Oath to Complete the Journey
# scene 1: starts at line 1, ends at line 31
# scene 2: starts at line 32, ends at line 65
# scene 3: starts at line 66, ends at line 99
# scene 4: starts at line 100, ends at line 129
# scene 5: starts at line 130, ends at line 157
#
# Chapter 8: The Golden Bazaar
# scene 1: starts at line 1, ends at line 35
# scene 2: starts at line 36, ends at line 66
# scene 3: starts at line 67, ends at line 96
# scene 4: starts at line 97, ends at line 122
# scene 5: starts at line 123, ends at line 148
#
# Chapter 9: Letters in the Dark
# scene 1: starts at line 1, ends at line 43
# scene 2: starts at line 44, ends at line 74
# scene 3: starts at line 75, ends at line 102
# scene 4: starts at line 103, ends at line 130
# scene 5: starts at line 131, ends at line 156
#
# Chapter 10: A Prince in Disguise
# scene 1: starts at line 1, ends at line 38
# scene 2: starts at line 39, ends at line 69
# scene 3: starts at line 70, ends at line 96
# scene 4: starts at line 97, ends at line 121
# scene 5: starts at line 122, ends at line 149
#
# Chapter 11: The Heart and the Choice
# scene 1: starts at line 1, ends at line 39
# scene 2: starts at line 40, ends at line 68
# scene 3: starts at line 69, ends at line 96
# scene 4: starts at line 97, ends at line 124
# scene 5: starts at line 125, ends at line 152
#
# Chapter 12: Whispers of the Silk Road
# scene 1: starts at line 1, ends at line 27
# scene 2: starts at line 28, ends at line 58
# scene 3: starts at line 59, ends at line 81
# scene 4: starts at line 82, ends at line 107

# %%
chapter_lines
# Out:
# {"Chapter 1: The Merchant's Daughter": [(1, 32), (33, 56), (57, 76), (77, 96)],
#  'Chapter 2: Caravan of Secrets': [(1, 37), (38, 72), (73, 101), (102, 127)],
#  'Chapter 3: An Encounter in the Desert': [(1, 53),
#   (54, 87),
#   (88, 113),
#   (114, 147),
#   (148, 180)],
#  'Chapter 4: Bandits in the Night': [(1, 40), (41, 79), (80, 117), (118, 154)],
#  'Chapter 5: The Town of Lost Souls': [(1, 52),
#   (53, 87),
#   (88, 118),
#   (119, 150)],
#  'Chapter 6: The Scroll of Secrets': [(1, 42),
#   (43, 76),
#   (77, 105),
#   (106, 132),
#   (133, 165)],
#  'Chapter 7: An Oath to Complete the Journey': [(1, 31),
#   (32, 65),
#   (66, 99),
#   (100, 129),
#   (130, 157)],
#  'Chapter 8: The Golden Bazaar': [(1, 35),
#   (36, 66),
#   (67, 96),
#   (97, 122),
#   (123, 148)],
#  'Chapter 9: Letters in the Dark': [(1, 43),
#   (44, 74),
#   (75, 102),
#   (103, 130),
#   (131, 156)],
#  'Chapter 10: A Prince in Disguise': [(1, 38),
#   (39, 69),
#   (70, 96),
#   (97, 121),
#   (122, 149)],
#  'Chapter 11: The Heart and the Choice': [(1, 39),
#   (40, 68),
#   (69, 96),
#   (97, 124),
#   (125, 152)],
#  'Chapter 12: Whispers of the Silk Road': [(1, 27),
#   (28, 58),
#   (59, 81),
#   (82, 107)]}

# %%
# add "first_line" and "last_line" to each scene
for chapter in chapters:
    chapter_name = chapter['chapter']
    print(chapter_name)
    scene_line_numbers = chapter_lines[chapter_name]
    print(scene_line_numbers)
    scene_num = 0
    for i, scene in enumerate(scenes):
        compare_chapter = chapter_name
        if ':' in chapter_name:
            compare_chapter = chapter_name.split(":")[0]
        if scene['chapter'] == compare_chapter:
            print(scene['chapter'], compare_chapter)
            print(scene_num)
            scene['first_line'] = scene_line_numbers[scene_num][0] 
            scene['last_line'] = scene_line_numbers[scene_num][1]
            scene_num += 1
# Out:
# Chapter 1: The Merchant's Daughter
# [(1, 32), (33, 56), (57, 76), (77, 96)]
# Chapter 1 Chapter 1
# 0
# Chapter 1 Chapter 1
# 1
# Chapter 1 Chapter 1
# 2
# Chapter 1 Chapter 1
# 3
# Chapter 2: Caravan of Secrets
# [(1, 37), (38, 72), (73, 101), (102, 127)]
# Chapter 2 Chapter 2
# 0
# Chapter 2 Chapter 2
# 1
# Chapter 2 Chapter 2
# 2
# Chapter 2 Chapter 2
# 3
# Chapter 3: An Encounter in the Desert
# [(1, 53), (54, 87), (88, 113), (114, 147), (148, 180)]
# Chapter 3 Chapter 3
# 0
# Chapter 3 Chapter 3
# 1
# Chapter 3 Chapter 3
# 2
# Chapter 3 Chapter 3
# 3
# Chapter 3 Chapter 3
# 4
# Chapter 4: Bandits in the Night
# [(1, 40), (41, 79), (80, 117), (118, 154)]
# Chapter 4 Chapter 4
# 0
# Chapter 4 Chapter 4
# 1
# Chapter 4 Chapter 4
# 2
# Chapter 4 Chapter 4
# 3
# Chapter 5: The Town of Lost Souls
# [(1, 52), (53, 87), (88, 118), (119, 150)]
# Chapter 5 Chapter 5
# 0
# Chapter 5 Chapter 5
# 1
# Chapter 5 Chapter 5
# 2
# Chapter 5 Chapter 5
# 3
# Chapter 6: The Scroll of Secrets
# [(1, 42), (43, 76), (77, 105), (106, 132), (133, 165)]
# Chapter 6 Chapter 6
# 0
# Chapter 6 Chapter 6
# 1
# Chapter 6 Chapter 6
# 2
# Chapter 6 Chapter 6
# 3
# Chapter 6 Chapter 6
# 4
# Chapter 7: An Oath to Complete the Journey
# [(1, 31), (32, 65), (66, 99), (100, 129), (130, 157)]
# Chapter 7 Chapter 7
# 0
# Chapter 7 Chapter 7
# 1
# Chapter 7 Chapter 7
# 2
# Chapter 7 Chapter 7
# 3
# Chapter 7 Chapter 7
# 4
# Chapter 8: The Golden Bazaar
# [(1, 35), (36, 66), (67, 96), (97, 122), (123, 148)]
# Chapter 8 Chapter 8
# 0
# Chapter 8 Chapter 8
# 1
# Chapter 8 Chapter 8
# 2
# Chapter 8 Chapter 8
# 3
# Chapter 8 Chapter 8
# 4
# Chapter 9: Letters in the Dark
# [(1, 43), (44, 74), (75, 102), (103, 130), (131, 156)]
# Chapter 9 Chapter 9
# 0
# Chapter 9 Chapter 9
# 1
# Chapter 9 Chapter 9
# 2
# Chapter 9 Chapter 9
# 3
# Chapter 9 Chapter 9
# 4
# Chapter 10: A Prince in Disguise
# [(1, 38), (39, 69), (70, 96), (97, 121), (122, 149)]
# Chapter 10 Chapter 10
# 0
# Chapter 10 Chapter 10
# 1
# Chapter 10 Chapter 10
# 2
# Chapter 10 Chapter 10
# 3
# Chapter 10 Chapter 10
# 4
# Chapter 11: The Heart and the Choice
# [(1, 39), (40, 68), (69, 96), (97, 124), (125, 152)]
# Chapter 11 Chapter 11
# 0
# Chapter 11 Chapter 11
# 1
# Chapter 11 Chapter 11
# 2
# Chapter 11 Chapter 11
# 3
# Chapter 11 Chapter 11
# 4
# Chapter 12: Whispers of the Silk Road
# [(1, 27), (28, 58), (59, 81), (82, 107)]
# Chapter 12 Chapter 12
# 0
# Chapter 12 Chapter 12
# 1
# Chapter 12 Chapter 12
# 2
# Chapter 12 Chapter 12
# 3

# %%
scenes
# Out:
# [{'title': 'Packing for the Journey',
#   'number': 1,
#   'summary': 'Mei assists her father in preparing for the Silk Road journey.',
#   'chapter': 'Chapter 1',
#   'location': "Mei's family home",
#   'importance': 0.5,
#   'conflict': 0.1,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'eager yet uncertain',
#     'sentiment': 0.3,
#     'importance_rank': 1},
#    {'name': 'Zhang',
#     'role': "Mei's father, a respected merchant",
#     'importance': 0.9,
#     'emotion': 'focused on preparations',
#     'sentiment': 0.2,
#     'importance_rank': 2},
#    {'name': 'Lin',
#     'role': "Mei's servant and friend",
#     'importance': 0.3,
#     'emotion': 'supportive',
#     'sentiment': 0.4,
#     'importance_rank': 3}],
#   'importance_rank': 4,
#   'conflict_rank': 4,
#   'first_line': 1,
#   'last_line': 32},
#  {'title': 'Yearning for Adventure',
#   'number': 2,
#   'summary': 'Mei expresses her desire to join the journey but faces resistance.',
#   'chapter': 'Chapter 1',
#   'location': "Mei's family home",
#   'importance': 0.6,
#   'conflict': 0.3,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'longing and frustrated',
#     'sentiment': -0.1,
#     'importance_rank': 1},
#    {'name': 'Zhang',
#     'role': "Mei's father",
#     'importance': 0.8,
#     'emotion': 'protective and dismissive',
#     'sentiment': -0.3,
#     'importance_rank': 2}],
#   'importance_rank': 3,
#   'conflict_rank': 2,
#   'first_line': 33,
#   'last_line': 56},
#  {'title': 'A Change in Plans',
#   'number': 3,
#   'summary': 'Circumstances change, allowing Mei to join the journey unexpectedly.',
#   'chapter': 'Chapter 1',
#   'location': "Mei's family home",
#   'importance': 1.0,
#   'conflict': 0.5,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'excited and nervous',
#     'sentiment': 0.7,
#     'importance_rank': 1},
#    {'name': 'Zhang',
#     'role': "Mei's father",
#     'importance': 0.9,
#     'emotion': 'reluctant yet resigned',
#     'sentiment': 0.0,
#     'importance_rank': 2},
#    {'name': 'Li Yuan',
#     'role': 'family friend and fellow trader',
#     'importance': 0.4,
#     'emotion': 'supportive and encouraging',
#     'sentiment': 0.5,
#     'importance_rank': 3}],
#   'importance_rank': 1,
#   'conflict_rank': 1,
#   'first_line': 57,
#   'last_line': 76},
#  {'title': 'The Tea Market Farewell',
#   'number': 4,
#   'summary': 'Mei visits the local tea market with her father to make final trades.',
#   'chapter': 'Chapter 1',
#   'location': 'Tea market',
#   'importance': 0.7,
#   'conflict': 0.2,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'curious and observant',
#     'sentiment': 0.6,
#     'importance_rank': 1},
#    {'name': 'Zhang',
#     'role': "Mei's father",
#     'importance': 0.8,
#     'emotion': 'focused on business',
#     'sentiment': 0.2,
#     'importance_rank': 2},
#    {'name': 'Lao Feng',
#     'role': "local merchant in Chang'an",
#     'importance': 0.5,
#     'emotion': 'pleasant and amicable',
#     'sentiment': 0.5,
#     'importance_rank': 3}],
#   'importance_rank': 2,
#   'conflict_rank': 3,
#   'first_line': 77,
#   'last_line': 96},
#  {'title': 'Joining the Caravan',
#   'number': 5,
#   'summary': 'Mei joins her father and the caravan at the city gates.',
#   'chapter': 'Chapter 2',
#   'location': "Chang'an city gates",
#   'importance': 0.8,
#   'conflict': 0.2,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'nervous yet excited',
#     'sentiment': 0.6,
#     'importance_rank': 1},
#    {'name': 'Zhang',
#     'role': "Mei's father",
#     'importance': 0.9,
#     'emotion': 'determined and watchful',
#     'sentiment': 0.4,
#     'importance_rank': 2},
#    {'name': 'Farid',
#     'role': 'leader of the caravan',
#     'importance': 0.5,
#     'emotion': 'authoritative and calm',
#     'sentiment': 0.3,
#     'importance_rank': 3}],
#   'importance_rank': 3,
#   'conflict_rank': 4,
#   'first_line': 1,
#   'last_line': 37},
#  {'title': 'Meeting Kaveh',
#   'number': 6,
#   'summary': 'Mei meets Kaveh, a Persian merchant, and feels drawn to his mysterious presence.',
#   'chapter': 'Chapter 2',
#   'location': 'Caravan encampment',
#   'importance': 0.9,
#   'conflict': 0.3,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'curious and intrigued',
#     'sentiment': 0.7,
#     'importance_rank': 1},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.8,
#     'emotion': 'mysterious and warm',
#     'sentiment': 0.6,
#     'importance_rank': 2},
#    {'name': 'Lin',
#     'role': "Mei's servant and friend",
#     'importance': 0.4,
#     'emotion': 'protective and curious',
#     'sentiment': 0.3,
#     'importance_rank': 3}],
#   'importance_rank': 2,
#   'conflict_rank': 3,
#   'first_line': 38,
#   'last_line': 72},
#  {'title': 'Stories of the Silk Road',
#   'number': 7,
#   'summary': 'Mei hears travelers’ stories, revealing the mysteries and dangers of the Silk Road.',
#   'chapter': 'Chapter 2',
#   'location': 'Caravan encampment',
#   'importance': 0.7,
#   'conflict': 0.4,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'captivated and alert',
#     'sentiment': 0.5,
#     'importance_rank': 1},
#    {'name': 'Farid',
#     'role': 'leader of the caravan',
#     'importance': 0.6,
#     'emotion': 'serious and cautionary',
#     'sentiment': -0.1,
#     'importance_rank': 2},
#    {'name': 'Old Wang',
#     'role': 'camel handler',
#     'importance': 0.5,
#     'emotion': 'wise and pensive',
#     'sentiment': 0.3,
#     'importance_rank': 3}],
#   'importance_rank': 4,
#   'conflict_rank': 2,
#   'first_line': 73,
#   'last_line': 101},
#  {'title': 'A Secret Mission Revealed',
#   'number': 8,
#   'summary': 'Mei overhears her father talking about a secret message he is carrying.',
#   'chapter': 'Chapter 2',
#   'location': 'Caravan encampment',
#   'importance': 1.0,
#   'conflict': 0.5,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'anxious and determined',
#     'sentiment': -0.2,
#     'importance_rank': 1},
#    {'name': 'Zhang',
#     'role': "Mei's father",
#     'importance': 0.9,
#     'emotion': 'guarded and tense',
#     'sentiment': -0.4,
#     'importance_rank': 2},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.7,
#     'emotion': 'calm and observing',
#     'sentiment': 0.3,
#     'importance_rank': 3}],
#   'importance_rank': 1,
#   'conflict_rank': 1,
#   'first_line': 102,
#   'last_line': 127},
#  {'title': 'Crossing the Gobi Desert',
#   'number': 9,
#   'summary': 'The caravan faces the harshness of the Gobi Desert, testing their endurance.',
#   'chapter': 'Chapter 3',
#   'location': 'Gobi Desert',
#   'importance': 0.8,
#   'conflict': 0.4,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'exhausted yet determined',
#     'sentiment': -0.2,
#     'importance_rank': 1},
#    {'name': 'Farid',
#     'role': 'leader of the caravan',
#     'importance': 0.7,
#     'emotion': 'steady and focused',
#     'sentiment': 0.1,
#     'importance_rank': 2},
#    {'name': 'Old Wang',
#     'role': 'camel handler',
#     'importance': 0.5,
#     'emotion': 'resigned and tired',
#     'sentiment': -0.1,
#     'importance_rank': 3}],
#   'importance_rank': 2,
#   'conflict_rank': 3,
#   'first_line': 1,
#   'last_line': 53},
#  {'title': 'Meeting Kaveh Again',
#   'number': 10,
#   'summary': 'Mei encounters Kaveh and learns about his knowledge of the Silk Road.',
#   'chapter': 'Chapter 3',
#   'location': 'Gobi Desert',
#   'importance': 0.7,
#   'conflict': 0.3,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'curious and captivated',
#     'sentiment': 0.5,
#     'importance_rank': 1},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.9,
#     'emotion': 'insightful and mysterious',
#     'sentiment': 0.6,
#     'importance_rank': 2}],
#   'importance_rank': 4,
#   'conflict_rank': 4,
#   'first_line': 54,
#   'last_line': 87},
#  {'title': 'Whispers of Spies',
#   'number': 11,
#   'summary': 'Kaveh warns Mei of potential spies among the caravan, hinting at her father’s dangerous mission.',
#   'chapter': 'Chapter 3',
#   'location': 'Oasis stop',
#   'importance': 1.0,
#   'conflict': 0.6,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'anxious and wary',
#     'sentiment': -0.3,
#     'importance_rank': 1},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.9,
#     'emotion': 'serious and guarded',
#     'sentiment': 0.1,
#     'importance_rank': 2}],
#   'importance_rank': 1,
#   'conflict_rank': 1,
#   'first_line': 88,
#   'last_line': 113},
#  {'title': 'Secrets on the Road',
#   'number': 12,
#   'summary': 'Mei observes suspicious behavior among the caravan members, growing cautious of whom to trust.',
#   'chapter': 'Chapter 3',
#   'location': 'Oasis stop',
#   'importance': 0.8,
#   'conflict': 0.5,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'wary and watchful',
#     'sentiment': -0.1,
#     'importance_rank': 1},
#    {'name': 'Jia',
#     'role': 'young traveler within the caravan',
#     'importance': 0.5,
#     'emotion': 'curious but nervous',
#     'sentiment': 0.2,
#     'importance_rank': 3},
#    {'name': 'Hadi',
#     'role': 'Indian trader along the Silk Road',
#     'importance': 0.4,
#     'emotion': 'aloof and cautious',
#     'sentiment': -0.2,
#     'importance_rank': 4},
#    {'name': 'Badr',
#     'role': "Kaveh's loyal bodyguard",
#     'importance': 0.6,
#     'emotion': 'protective and tense',
#     'sentiment': 0.1,
#     'importance_rank': 2}],
#   'importance_rank': 3,
#   'conflict_rank': 2,
#   'first_line': 114,
#   'last_line': 147},
#  {'title': 'An Encounter with Aisha',
#   'number': 13,
#   'summary': "Mei meets Aisha, a skilled healer in the caravan, who gives her insight into the Silk Road's dangers.",
#   'chapter': 'Chapter 3',
#   'location': 'Oasis stop',
#   'importance': 0.7,
#   'conflict': 0.3,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'grateful and curious',
#     'sentiment': 0.5,
#     'importance_rank': 1},
#    {'name': 'Aisha',
#     'role': 'skilled healer and herbalist',
#     'importance': 0.8,
#     'emotion': 'compassionate and wise',
#     'sentiment': 0.7,
#     'importance_rank': 2},
#    {'name': 'Farid',
#     'role': 'leader of the caravan',
#     'importance': 0.5,
#     'emotion': 'respectful and alert',
#     'sentiment': 0.3,
#     'importance_rank': 3}],
#   'importance_rank': 5,
#   'conflict_rank': 5,
#   'first_line': 148,
#   'last_line': 180},
#  {'title': 'Nightfall at the Desert Camp',
#   'number': 14,
#   'summary': 'The caravan sets up camp for the night in the desert, unaware of the impending danger.',
#   'chapter': 'Chapter 4',
#   'location': 'Desert camp',
#   'importance': 0.6,
#   'conflict': 0.3,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'wary and alert',
#     'sentiment': 0.0,
#     'importance_rank': 1},
#    {'name': 'Zhang',
#     'role': "Mei's father",
#     'importance': 0.8,
#     'emotion': 'thoughtful and cautious',
#     'sentiment': -0.1,
#     'importance_rank': 2},
#    {'name': 'Farid',
#     'role': 'leader of the caravan',
#     'importance': 0.7,
#     'emotion': 'vigilant and focused',
#     'sentiment': 0.2,
#     'importance_rank': 3},
#    {'name': 'Aisha',
#     'role': 'skilled herbalist and healer',
#     'importance': 0.5,
#     'emotion': 'calm and prepared',
#     'sentiment': 0.3,
#     'importance_rank': 4}],
#   'importance_rank': 3,
#   'conflict_rank': 4,
#   'first_line': 1,
#   'last_line': 40},
#  {'title': 'The Bandit Attack',
#   'number': 15,
#   'summary': 'Bandits ambush the caravan at night, targeting Mei’s father’s goods.',
#   'chapter': 'Chapter 4',
#   'location': 'Desert camp',
#   'importance': 1.0,
#   'conflict': 1.0,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'terrified yet resolute',
#     'sentiment': -0.5,
#     'importance_rank': 1},
#    {'name': 'Zhang',
#     'role': "Mei's father",
#     'importance': 0.9,
#     'emotion': 'protective but injured',
#     'sentiment': -0.4,
#     'importance_rank': 2},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.8,
#     'emotion': 'determined and defensive',
#     'sentiment': 0.1,
#     'importance_rank': 3},
#    {'name': 'Farid',
#     'role': 'leader of the caravan',
#     'importance': 0.7,
#     'emotion': 'commanding and quick-thinking',
#     'sentiment': 0.0,
#     'importance_rank': 5},
#    {'name': 'Saeed',
#     'role': 'leader of the bandits',
#     'importance': 0.8,
#     'emotion': 'aggressive and ruthless',
#     'sentiment': -0.8,
#     'importance_rank': 4},
#    {'name': 'Yara',
#     'role': 'bandit skilled with a bow',
#     'importance': 0.6,
#     'emotion': 'focused and ruthless',
#     'sentiment': -0.7,
#     'importance_rank': 6},
#    {'name': 'Yao',
#     'role': 'guard for the caravan',
#     'importance': 0.6,
#     'emotion': 'alert and defensive',
#     'sentiment': 0.0,
#     'importance_rank': 7},
#    {'name': 'Jin',
#     'role': 'caravan guard who befriends Mei',
#     'importance': 0.5,
#     'emotion': 'brave and protective',
#     'sentiment': 0.2,
#     'importance_rank': 8}],
#   'importance_rank': 1,
#   'conflict_rank': 1,
#   'first_line': 41,
#   'last_line': 79},
#  {'title': 'Aftermath of the Attack',
#   'number': 16,
#   'summary': 'The caravan assesses their losses, and Mei tends to her father’s wounds.',
#   'chapter': 'Chapter 4',
#   'location': 'Desert camp',
#   'importance': 0.9,
#   'conflict': 0.7,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'distressed but caring',
#     'sentiment': -0.2,
#     'importance_rank': 1},
#    {'name': 'Zhang',
#     'role': "Mei's father",
#     'importance': 0.9,
#     'emotion': 'weak and injured',
#     'sentiment': -0.4,
#     'importance_rank': 2},
#    {'name': 'Aisha',
#     'role': 'skilled herbalist and healer',
#     'importance': 0.8,
#     'emotion': 'focused and nurturing',
#     'sentiment': 0.5,
#     'importance_rank': 3},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.7,
#     'emotion': 'concerned and attentive',
#     'sentiment': 0.3,
#     'importance_rank': 4},
#    {'name': 'Farid',
#     'role': 'leader of the caravan',
#     'importance': 0.5,
#     'emotion': 'calm and pragmatic',
#     'sentiment': 0.2,
#     'importance_rank': 5}],
#   'importance_rank': 2,
#   'conflict_rank': 2,
#   'first_line': 80,
#   'last_line': 117},
#  {'title': 'Retreat to the Bandit Hideout',
#   'number': 17,
#   'summary': 'The bandits regroup at their hideout after the ambush, plotting further attacks.',
#   'chapter': 'Chapter 4',
#   'location': 'Bandit hideout in dunes',
#   'importance': 0.6,
#   'conflict': 0.5,
#   'characters': [{'name': 'Saeed',
#     'role': 'leader of the bandits',
#     'importance': 1.0,
#     'emotion': 'angry and vengeful',
#     'sentiment': -0.9,
#     'importance_rank': 1},
#    {'name': 'Yara',
#     'role': 'bandit skilled with a bow',
#     'importance': 0.8,
#     'emotion': 'defiant and eager',
#     'sentiment': -0.6,
#     'importance_rank': 2}],
#   'importance_rank': 4,
#   'conflict_rank': 3,
#   'first_line': 118,
#   'last_line': 154},
#  {'title': 'Arrival in the Town of Lost Souls',
#   'number': 18,
#   'summary': 'The caravan arrives in a remote desert town known for its mystics and unusual atmosphere.',
#   'chapter': 'Chapter 5',
#   'location': 'Caravanserai',
#   'importance': 0.6,
#   'conflict': 0.3,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'wary and intrigued',
#     'sentiment': 0.2,
#     'importance_rank': 1},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.8,
#     'emotion': 'guarded and mysterious',
#     'sentiment': 0.3,
#     'importance_rank': 2},
#    {'name': 'Zhang',
#     'role': "Mei's father",
#     'importance': 0.7,
#     'emotion': 'weary and reflective',
#     'sentiment': -0.1,
#     'importance_rank': 3}],
#   'importance_rank': 4,
#   'conflict_rank': 3,
#   'first_line': 1,
#   'last_line': 52},
#  {'title': 'The Fortune Teller’s Warning',
#   'number': 19,
#   'summary': 'Mei meets an old woman who reads her fortune, hinting at a choice between heart and duty.',
#   'chapter': 'Chapter 5',
#   'location': 'Caravanserai',
#   'importance': 1.0,
#   'conflict': 0.5,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'curious and contemplative',
#     'sentiment': 0.4,
#     'importance_rank': 1},
#    {'name': 'Li Wei',
#     'role': "old woman who reads Mei's fortune",
#     'importance': 0.9,
#     'emotion': 'cryptic and wise',
#     'sentiment': 0.0,
#     'importance_rank': 2},
#    {'name': 'Zhang',
#     'role': "Mei's father",
#     'importance': 0.5,
#     'emotion': 'cautious and wary',
#     'sentiment': -0.2,
#     'importance_rank': 3}],
#   'importance_rank': 1,
#   'conflict_rank': 1,
#   'first_line': 53,
#   'last_line': 87},
#  {'title': 'The Cultural Significance of Tea',
#   'number': 20,
#   'summary': 'Mei learns about the importance of tea in the town’s culture, deepening her understanding of her family’s trade.',
#   'chapter': 'Chapter 5',
#   'location': 'Caravanserai',
#   'importance': 0.7,
#   'conflict': 0.2,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'engaged and thoughtful',
#     'sentiment': 0.6,
#     'importance_rank': 1},
#    {'name': 'Zhang',
#     'role': "Mei's father",
#     'importance': 0.6,
#     'emotion': 'proud and reflective',
#     'sentiment': 0.3,
#     'importance_rank': 2},
#    {'name': 'Zhao',
#     'role': 'local mystic in the town',
#     'importance': 0.5,
#     'emotion': 'reverent and insightful',
#     'sentiment': 0.4,
#     'importance_rank': 3}],
#   'importance_rank': 3,
#   'conflict_rank': 4,
#   'first_line': 88,
#   'last_line': 118},
#  {'title': 'Intrigued by Kaveh’s World',
#   'number': 21,
#   'summary': 'Mei finds herself more intrigued by Kaveh and the world he represents, hinting at her growing inner conflict.',
#   'chapter': 'Chapter 5',
#   'location': 'Caravanserai',
#   'importance': 0.8,
#   'conflict': 0.4,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'conflicted and intrigued',
#     'sentiment': 0.5,
#     'importance_rank': 1},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.9,
#     'emotion': 'charming and reserved',
#     'sentiment': 0.4,
#     'importance_rank': 2},
#    {'name': 'Kalden',
#     'role': 'Tibetan monk and occasional healer',
#     'importance': 0.4,
#     'emotion': 'observant and wise',
#     'sentiment': 0.3,
#     'importance_rank': 3}],
#   'importance_rank': 2,
#   'conflict_rank': 2,
#   'first_line': 119,
#   'last_line': 150},
#  {'title': 'A Sudden Illness',
#   'number': 22,
#   'summary': "Mei's father falls ill, jeopardizing their journey and raising concerns among the caravan.",
#   'chapter': 'Chapter 6',
#   'location': 'Caravan encampment',
#   'importance': 0.8,
#   'conflict': 0.6,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'worried and distressed',
#     'sentiment': -0.4,
#     'importance_rank': 1},
#    {'name': 'Zhang',
#     'role': "Mei's father",
#     'importance': 0.9,
#     'emotion': 'weak and feverish',
#     'sentiment': -0.5,
#     'importance_rank': 2},
#    {'name': 'Farid',
#     'role': 'leader of the caravan',
#     'importance': 0.6,
#     'emotion': 'concerned and pragmatic',
#     'sentiment': 0.1,
#     'importance_rank': 4},
#    {'name': 'Aliya',
#     'role': 'Persian healer',
#     'importance': 0.7,
#     'emotion': 'calm and attentive',
#     'sentiment': 0.5,
#     'importance_rank': 3}],
#   'importance_rank': 3,
#   'conflict_rank': 2,
#   'first_line': 1,
#   'last_line': 42},
#  {'title': 'A Secret Mission Revealed',
#   'number': 23,
#   'summary': 'Kaveh reveals to Mei that her father is carrying a scroll meant to broker peace between China and Persia.',
#   'chapter': 'Chapter 6',
#   'location': 'Caravan encampment',
#   'importance': 1.0,
#   'conflict': 0.7,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'shocked and burdened',
#     'sentiment': -0.2,
#     'importance_rank': 1},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.9,
#     'emotion': 'solemn and sincere',
#     'sentiment': 0.4,
#     'importance_rank': 2},
#    {'name': 'Farid',
#     'role': 'leader of the caravan',
#     'importance': 0.5,
#     'emotion': 'concerned and supportive',
#     'sentiment': 0.2,
#     'importance_rank': 3}],
#   'importance_rank': 1,
#   'conflict_rank': 1,
#   'first_line': 43,
#   'last_line': 76},
#  {'title': 'Responsibility and Doubt',
#   'number': 24,
#   'summary': 'Mei grapples with the responsibility of her father’s mission as he grows weaker.',
#   'chapter': 'Chapter 6',
#   'location': "Healer's tent in the desert",
#   'importance': 0.9,
#   'conflict': 0.5,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'overwhelmed yet determined',
#     'sentiment': -0.1,
#     'importance_rank': 1},
#    {'name': 'Zhang',
#     'role': "Mei's father",
#     'importance': 0.8,
#     'emotion': 'weak and resigned',
#     'sentiment': -0.6,
#     'importance_rank': 2},
#    {'name': 'Aliya',
#     'role': 'Persian healer',
#     'importance': 0.7,
#     'emotion': 'compassionate and wise',
#     'sentiment': 0.5,
#     'importance_rank': 3}],
#   'importance_rank': 2,
#   'conflict_rank': 3,
#   'first_line': 77,
#   'last_line': 105},
#  {'title': 'Preparing for the Mission Ahead',
#   'number': 25,
#   'summary': 'With her father bedridden, Mei begins to accept the responsibility of his mission and prepares herself for the challenges ahead.',
#   'chapter': 'Chapter 6',
#   'location': "Healer's tent in the desert",
#   'importance': 0.8,
#   'conflict': 0.4,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'determined and resolute',
#     'sentiment': 0.6,
#     'importance_rank': 1},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.9,
#     'emotion': 'supportive and encouraging',
#     'sentiment': 0.5,
#     'importance_rank': 2},
#    {'name': 'Bahram',
#     'role': "Persian contact for Mei's father",
#     'importance': 0.8,
#     'emotion': 'respectful and hopeful',
#     'sentiment': 0.4,
#     'importance_rank': 3},
#    {'name': 'Sohrab',
#     'role': 'Persian messenger',
#     'importance': 0.6,
#     'emotion': 'respectful and dutiful',
#     'sentiment': 0.3,
#     'importance_rank': 4}],
#   'importance_rank': 4,
#   'conflict_rank': 4,
#   'first_line': 106,
#   'last_line': 132},
#  {'title': 'Seeking Comfort and Support',
#   'number': 26,
#   'summary': "Mei confides in Lin about her fears and doubts, finding comfort in her friend's loyalty.",
#   'chapter': 'Chapter 6',
#   'location': "Healer's tent in the desert",
#   'importance': 0.7,
#   'conflict': 0.3,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'vulnerable yet comforted',
#     'sentiment': 0.2,
#     'importance_rank': 1},
#    {'name': 'Lin',
#     'role': "Mei's servant and friend",
#     'importance': 0.8,
#     'emotion': 'supportive and compassionate',
#     'sentiment': 0.6,
#     'importance_rank': 2}],
#   'importance_rank': 5,
#   'conflict_rank': 5,
#   'first_line': 133,
#   'last_line': 165},
#  {'title': 'Oath to Complete the Journey',
#   'number': 27,
#   'summary': 'With her father bedridden, Mei vows to fulfill his mission, stepping into his role.',
#   'chapter': 'Chapter 7',
#   'location': 'Mountains near Samarkand',
#   'importance': 1.0,
#   'conflict': 0.6,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'determined and solemn',
#     'sentiment': 0.7,
#     'importance_rank': 1},
#    {'name': 'Zhang',
#     'role': "Mei's father",
#     'importance': 0.8,
#     'emotion': 'proud but weak',
#     'sentiment': 0.3,
#     'importance_rank': 2},
#    {'name': 'Farid',
#     'role': 'leader of the caravan',
#     'importance': 0.6,
#     'emotion': 'respectful and encouraging',
#     'sentiment': 0.5,
#     'importance_rank': 3}],
#   'importance_rank': 1,
#   'conflict_rank': 1,
#   'first_line': 1,
#   'last_line': 31},
#  {'title': 'Navigating Caravan Politics',
#   'number': 28,
#   'summary': 'Mei learns the complex dynamics within the caravan, gaining respect as a leader.',
#   'chapter': 'Chapter 7',
#   'location': 'Mountains near Samarkand',
#   'importance': 0.8,
#   'conflict': 0.5,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'empowered and cautious',
#     'sentiment': 0.6,
#     'importance_rank': 1},
#    {'name': 'Farid',
#     'role': 'leader of the caravan',
#     'importance': 0.7,
#     'emotion': 'supportive and instructive',
#     'sentiment': 0.4,
#     'importance_rank': 2},
#    {'name': 'Jin',
#     'role': 'caravan guard who befriends Mei',
#     'importance': 0.5,
#     'emotion': 'friendly and respectful',
#     'sentiment': 0.5,
#     'importance_rank': 3}],
#   'importance_rank': 3,
#   'conflict_rank': 3,
#   'first_line': 32,
#   'last_line': 65},
#  {'title': 'Kaveh’s Support and Mei’s Suspicions',
#   'number': 29,
#   'summary': 'Kaveh assists Mei with her new role, but she grows suspicious of his motives.',
#   'chapter': 'Chapter 7',
#   'location': 'Mountains near Samarkand',
#   'importance': 0.9,
#   'conflict': 0.6,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'grateful yet doubtful',
#     'sentiment': 0.2,
#     'importance_rank': 1},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.9,
#     'emotion': 'encouraging and enigmatic',
#     'sentiment': 0.4,
#     'importance_rank': 2}],
#   'importance_rank': 2,
#   'conflict_rank': 2,
#   'first_line': 66,
#   'last_line': 99},
#  {'title': 'The Bond with Nasrin',
#   'number': 30,
#   'summary': 'Mei meets Nasrin, Kaveh’s estranged sister, and learns more about Kaveh’s past.',
#   'chapter': 'Chapter 7',
#   'location': 'Mountains near Samarkand',
#   'importance': 0.8,
#   'conflict': 0.4,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'curious and empathetic',
#     'sentiment': 0.5,
#     'importance_rank': 1},
#    {'name': 'Nasrin',
#     'role': "Kaveh's estranged sister",
#     'importance': 0.8,
#     'emotion': 'guarded and reflective',
#     'sentiment': 0.1,
#     'importance_rank': 2},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.6,
#     'emotion': 'quiet and distant',
#     'sentiment': 0.2,
#     'importance_rank': 3}],
#   'importance_rank': 4,
#   'conflict_rank': 4,
#   'first_line': 100,
#   'last_line': 129},
#  {'title': 'Strengthening Alliances',
#   'number': 31,
#   'summary': 'Mei gains the respect of caravan members like Rashid, solidifying her position.',
#   'chapter': 'Chapter 7',
#   'location': 'Mountains near Samarkand',
#   'importance': 0.7,
#   'conflict': 0.3,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'determined and respected',
#     'sentiment': 0.6,
#     'importance_rank': 1},
#    {'name': 'Rashid',
#     'role': 'caravan helper',
#     'importance': 0.5,
#     'emotion': 'respectful and approving',
#     'sentiment': 0.4,
#     'importance_rank': 2},
#    {'name': 'Aliya',
#     'role': 'Persian healer who helps Zhang',
#     'importance': 0.4,
#     'emotion': 'kind and supportive',
#     'sentiment': 0.5,
#     'importance_rank': 3}],
#   'importance_rank': 5,
#   'conflict_rank': 5,
#   'first_line': 130,
#   'last_line': 157},
#  {'title': 'Entering the Golden Bazaar',
#   'number': 32,
#   'summary': 'The caravan arrives in the bustling Samarkand bazaar, where Mei is dazzled by its sights and sounds.',
#   'chapter': 'Chapter 8',
#   'location': 'Samarkand bazaar',
#   'importance': 0.7,
#   'conflict': 0.3,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'awe-inspired and curious',
#     'sentiment': 0.8,
#     'importance_rank': 1},
#    {'name': 'Farid',
#     'role': 'leader of the caravan',
#     'importance': 0.6,
#     'emotion': 'focused and vigilant',
#     'sentiment': 0.3,
#     'importance_rank': 2},
#    {'name': 'Jin',
#     'role': 'caravan guard who befriends Mei',
#     'importance': 0.4,
#     'emotion': 'protective and watchful',
#     'sentiment': 0.5,
#     'importance_rank': 3}],
#   'importance_rank': 5,
#   'conflict_rank': 5,
#   'first_line': 1,
#   'last_line': 35},
#  {'title': 'Encounter with Spies',
#   'number': 33,
#   'summary': 'Mei encounters spies in the bazaar who seem aware of her father’s mission.',
#   'chapter': 'Chapter 8',
#   'location': 'Samarkand bazaar',
#   'importance': 0.9,
#   'conflict': 0.8,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'alarmed and cautious',
#     'sentiment': -0.4,
#     'importance_rank': 1},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.8,
#     'emotion': 'protective and alert',
#     'sentiment': 0.1,
#     'importance_rank': 2},
#    {'name': 'Farid',
#     'role': 'leader of the caravan',
#     'importance': 0.7,
#     'emotion': 'concerned and tactical',
#     'sentiment': -0.1,
#     'importance_rank': 3}],
#   'importance_rank': 3,
#   'conflict_rank': 3,
#   'first_line': 36,
#   'last_line': 66},
#  {'title': 'Narrow Escape',
#   'number': 34,
#   'summary': 'Mei narrowly escapes from the spies in the bazaar with help from Kaveh and Jin.',
#   'chapter': 'Chapter 8',
#   'location': 'Samarkand bazaar',
#   'importance': 1.0,
#   'conflict': 0.9,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'fearful yet determined',
#     'sentiment': -0.3,
#     'importance_rank': 1},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.9,
#     'emotion': 'tense but quick-thinking',
#     'sentiment': 0.2,
#     'importance_rank': 2},
#    {'name': 'Jin',
#     'role': 'caravan guard who befriends Mei',
#     'importance': 0.7,
#     'emotion': 'brave and loyal',
#     'sentiment': 0.5,
#     'importance_rank': 3}],
#   'importance_rank': 1,
#   'conflict_rank': 1,
#   'first_line': 67,
#   'last_line': 96},
#  {'title': "The Emir's Guesthouse",
#   'number': 35,
#   'summary': 'The Emir provides Mei and the caravan shelter at his guesthouse, where political tensions surface.',
#   'chapter': 'Chapter 8',
#   'location': "Emir's guesthouse",
#   'importance': 0.8,
#   'conflict': 0.6,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'relieved yet suspicious',
#     'sentiment': 0.4,
#     'importance_rank': 1},
#    {'name': 'Emir',
#     'role': 'influential merchant in Samarkand',
#     'importance': 0.7,
#     'emotion': 'cordial but calculating',
#     'sentiment': 0.3,
#     'importance_rank': 2},
#    {'name': 'Darya',
#     'role': "Emir's wife who befriends Mei",
#     'importance': 0.6,
#     'emotion': 'friendly and empathetic',
#     'sentiment': 0.5,
#     'importance_rank': 3}],
#   'importance_rank': 4,
#   'conflict_rank': 4,
#   'first_line': 97,
#   'last_line': 122},
#  {'title': "Discovering the Mission's Exposure",
#   'number': 36,
#   'summary': "Mei realizes that her father's mission is known to powerful figures, placing her in danger.",
#   'chapter': 'Chapter 8',
#   'location': "Emir's guesthouse",
#   'importance': 1.0,
#   'conflict': 0.9,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'panicked but resolute',
#     'sentiment': -0.4,
#     'importance_rank': 1},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.8,
#     'emotion': 'supportive and strategic',
#     'sentiment': 0.2,
#     'importance_rank': 2},
#    {'name': 'Hassan',
#     'role': 'local trader and friend of the Emir',
#     'importance': 0.6,
#     'emotion': 'insightful but wary',
#     'sentiment': 0.1,
#     'importance_rank': 3}],
#   'importance_rank': 2,
#   'conflict_rank': 2,
#   'first_line': 123,
#   'last_line': 148},
#  {'title': 'Letters in the Dark',
#   'number': 37,
#   'summary': 'Mei discovers hidden letters that reveal Kaveh’s involvement with a secret organization.',
#   'chapter': 'Chapter 9',
#   'location': "Kaveh's quarters",
#   'importance': 1.0,
#   'conflict': 1.0,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'shocked and betrayed',
#     'sentiment': -0.6,
#     'importance_rank': 1},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.9,
#     'emotion': 'secretive and guarded',
#     'sentiment': -0.2,
#     'importance_rank': 2},
#    {'name': 'Rashid',
#     'role': 'caravan helper',
#     'importance': 0.5,
#     'emotion': 'loyal but conflicted',
#     'sentiment': 0.1,
#     'importance_rank': 3}],
#   'importance_rank': 1,
#   'conflict_rank': 1,
#   'first_line': 1,
#   'last_line': 43},
#  {'title': 'Confronting Kaveh',
#   'number': 38,
#   'summary': 'Mei confronts Kaveh about his hidden alliances and questions his loyalty.',
#   'chapter': 'Chapter 9',
#   'location': "Kaveh's quarters",
#   'importance': 1.0,
#   'conflict': 0.9,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'angry and hurt',
#     'sentiment': -0.5,
#     'importance_rank': 1},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 1.0,
#     'emotion': 'remorseful and conflicted',
#     'sentiment': -0.1,
#     'importance_rank': 2},
#    {'name': 'Rashid',
#     'role': 'caravan helper',
#     'importance': 0.4,
#     'emotion': 'tense and uneasy',
#     'sentiment': -0.2,
#     'importance_rank': 3}],
#   'importance_rank': 2,
#   'conflict_rank': 2,
#   'first_line': 44,
#   'last_line': 74},
#  {'title': 'Secrets of the Secret Meeting',
#   'number': 39,
#   'summary': 'Mei follows Kaveh to a hidden meeting spot and realizes his connection to influential allies.',
#   'chapter': 'Chapter 9',
#   'location': 'Secret meeting place',
#   'importance': 0.9,
#   'conflict': 0.8,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'tense and fearful',
#     'sentiment': -0.4,
#     'importance_rank': 1},
#    {'name': 'Tarek',
#     'role': 'fellow trader with a suspicious side',
#     'importance': 0.6,
#     'emotion': 'guarded and suspicious',
#     'sentiment': -0.3,
#     'importance_rank': 4},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.8,
#     'emotion': 'nervous and cautious',
#     'sentiment': -0.2,
#     'importance_rank': 2},
#    {'name': 'Omar',
#     'role': 'spy watching the caravan',
#     'importance': 0.7,
#     'emotion': 'calculating and wary',
#     'sentiment': -0.5,
#     'importance_rank': 3}],
#   'importance_rank': 4,
#   'conflict_rank': 4,
#   'first_line': 75,
#   'last_line': 102},
#  {'title': 'The Choice to Trust',
#   'number': 40,
#   'summary': 'Mei faces a choice: confront Kaveh about her discovery or trust him despite his secrecy.',
#   'chapter': 'Chapter 9',
#   'location': 'Samarkand',
#   'importance': 1.0,
#   'conflict': 0.9,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'conflicted and anxious',
#     'sentiment': -0.2,
#     'importance_rank': 1},
#    {'name': 'Nasrin',
#     'role': "Kaveh's estranged sister",
#     'importance': 0.8,
#     'emotion': 'understanding and supportive',
#     'sentiment': 0.4,
#     'importance_rank': 3},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 1.0,
#     'emotion': 'remorseful and sincere',
#     'sentiment': 0.2,
#     'importance_rank': 2},
#    {'name': 'Rashid',
#     'role': 'caravan helper',
#     'importance': 0.5,
#     'emotion': 'loyal and supportive',
#     'sentiment': 0.3,
#     'importance_rank': 4}],
#   'importance_rank': 3,
#   'conflict_rank': 3,
#   'first_line': 103,
#   'last_line': 130},
#  {'title': 'Revelations and Realizations',
#   'number': 41,
#   'summary': 'Mei realizes that Kaveh has been protecting her, not only for the mission, but because of personal loyalty.',
#   'chapter': 'Chapter 9',
#   'location': 'Samarkand',
#   'importance': 0.8,
#   'conflict': 0.7,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'surprised and softened',
#     'sentiment': 0.3,
#     'importance_rank': 1},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 1.0,
#     'emotion': 'honest and vulnerable',
#     'sentiment': 0.4,
#     'importance_rank': 2},
#    {'name': 'Laila',
#     'role': 'maid at the Samarkand guesthouse',
#     'importance': 0.5,
#     'emotion': 'empathetic and gentle',
#     'sentiment': 0.5,
#     'importance_rank': 4},
#    {'name': 'Omar',
#     'role': 'spy watching the caravan',
#     'importance': 0.6,
#     'emotion': 'disappointed and cautious',
#     'sentiment': -0.4,
#     'importance_rank': 3}],
#   'importance_rank': 5,
#   'conflict_rank': 5,
#   'first_line': 131,
#   'last_line': 156},
#  {'title': 'Encounter on the Persian Road',
#   'number': 42,
#   'summary': 'Mei meets a disguised prince on the caravan route through Persia, who shows interest in her father’s mission.',
#   'chapter': 'Chapter 10',
#   'location': 'Caravan route through Persia',
#   'importance': 0.8,
#   'conflict': 0.4,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'curious and cautious',
#     'sentiment': 0.5,
#     'importance_rank': 1},
#    {'name': 'Prince Cyrus',
#     'role': 'Persian prince in disguise',
#     'importance': 0.9,
#     'emotion': 'charming and enigmatic',
#     'sentiment': 0.6,
#     'importance_rank': 2},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.7,
#     'emotion': 'respectful but reserved',
#     'sentiment': 0.4,
#     'importance_rank': 3}],
#   'importance_rank': 3,
#   'conflict_rank': 3,
#   'first_line': 1,
#   'last_line': 38},
#  {'title': 'The Prince’s Encampment',
#   'number': 43,
#   'summary': 'Prince Cyrus invites Mei to his secluded encampment, where he offers support for her father’s peace mission.',
#   'chapter': 'Chapter 10',
#   'location': "Prince's encampment",
#   'importance': 1.0,
#   'conflict': 0.5,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'honored yet cautious',
#     'sentiment': 0.7,
#     'importance_rank': 1},
#    {'name': 'Prince Cyrus',
#     'role': 'Persian prince in disguise',
#     'importance': 1.0,
#     'emotion': 'insightful and sincere',
#     'sentiment': 0.8,
#     'importance_rank': 2},
#    {'name': 'Bahram',
#     'role': "Persian contact for Mei's father",
#     'importance': 0.6,
#     'emotion': 'loyal and respectful',
#     'sentiment': 0.5,
#     'importance_rank': 3}],
#   'importance_rank': 1,
#   'conflict_rank': 2,
#   'first_line': 39,
#   'last_line': 69},
#  {'title': 'Glimpses of Political Intrigue',
#   'number': 44,
#   'summary': 'Mei realizes the complex political web surrounding her father’s mission, with various factions having vested interests.',
#   'chapter': 'Chapter 10',
#   'location': "Prince's encampment",
#   'importance': 0.9,
#   'conflict': 0.6,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'overwhelmed but determined',
#     'sentiment': 0.3,
#     'importance_rank': 1},
#    {'name': 'Prince Cyrus',
#     'role': 'Persian prince in disguise',
#     'importance': 0.8,
#     'emotion': 'strategic and thoughtful',
#     'sentiment': 0.5,
#     'importance_rank': 2},
#    {'name': 'Nasrin',
#     'role': "Kaveh's estranged sister",
#     'importance': 0.7,
#     'emotion': 'insightful and supportive',
#     'sentiment': 0.4,
#     'importance_rank': 3},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.7,
#     'emotion': 'thoughtful and protective',
#     'sentiment': 0.5,
#     'importance_rank': 4}],
#   'importance_rank': 2,
#   'conflict_rank': 1,
#   'first_line': 70,
#   'last_line': 96},
#  {'title': 'A Cultural Link',
#   'number': 45,
#   'summary': 'Mei realizes her role as a cultural bridge, connecting China and Persia through her father’s mission.',
#   'chapter': 'Chapter 10',
#   'location': "Prince's encampment",
#   'importance': 0.8,
#   'conflict': 0.3,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'reflective and inspired',
#     'sentiment': 0.6,
#     'importance_rank': 1},
#    {'name': 'Prince Cyrus',
#     'role': 'Persian prince in disguise',
#     'importance': 0.9,
#     'emotion': 'supportive and encouraging',
#     'sentiment': 0.7,
#     'importance_rank': 2},
#    {'name': 'Parisa',
#     'role': 'palace maid who aids Mei',
#     'importance': 0.5,
#     'emotion': 'humble and kind',
#     'sentiment': 0.4,
#     'importance_rank': 3}],
#   'importance_rank': 4,
#   'conflict_rank': 4,
#   'first_line': 97,
#   'last_line': 121},
#  {'title': 'Strengthening Bonds',
#   'number': 46,
#   'summary': 'Mei forms a stronger bond with Rashid, who offers his insights on the Persian culture and the journey ahead.',
#   'chapter': 'Chapter 10',
#   'location': "Prince's encampment",
#   'importance': 0.7,
#   'conflict': 0.2,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'grateful and contemplative',
#     'sentiment': 0.5,
#     'importance_rank': 1},
#    {'name': 'Rashid',
#     'role': 'caravan helper',
#     'importance': 0.6,
#     'emotion': 'supportive and wise',
#     'sentiment': 0.4,
#     'importance_rank': 2},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.5,
#     'emotion': 'attentive and thoughtful',
#     'sentiment': 0.5,
#     'importance_rank': 3}],
#   'importance_rank': 5,
#   'conflict_rank': 5,
#   'first_line': 122,
#   'last_line': 149},
#  {'title': 'Arrival at the Persian Palace',
#   'number': 47,
#   'summary': 'Mei arrives at the grand Persian palace to deliver the scroll, facing a mix of awe and trepidation.',
#   'chapter': 'Chapter 11',
#   'location': 'Persian palace',
#   'importance': 0.9,
#   'conflict': 0.4,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'awed and anxious',
#     'sentiment': 0.4,
#     'importance_rank': 1},
#    {'name': 'Prince Cyrus',
#     'role': 'Persian prince',
#     'importance': 0.8,
#     'emotion': 'welcoming yet formal',
#     'sentiment': 0.5,
#     'importance_rank': 2},
#    {'name': 'Bahram',
#     'role': "Persian contact for Mei's father",
#     'importance': 0.7,
#     'emotion': 'respectful and supportive',
#     'sentiment': 0.5,
#     'importance_rank': 3},
#    {'name': 'Rashid',
#     'role': 'caravan helper',
#     'importance': 0.6,
#     'emotion': 'loyal and reassuring',
#     'sentiment': 0.4,
#     'importance_rank': 4}],
#   'importance_rank': 3,
#   'conflict_rank': 5,
#   'first_line': 1,
#   'last_line': 39},
#  {'title': 'Delivering the Scroll',
#   'number': 48,
#   'summary': 'Mei formally delivers the scroll, understanding the potential impact on relations between China and Persia.',
#   'chapter': 'Chapter 11',
#   'location': 'Persian palace',
#   'importance': 1.0,
#   'conflict': 0.6,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'focused and resolved',
#     'sentiment': 0.6,
#     'importance_rank': 1},
#    {'name': 'Prince Cyrus',
#     'role': 'Persian prince',
#     'importance': 0.9,
#     'emotion': 'appreciative and solemn',
#     'sentiment': 0.6,
#     'importance_rank': 2},
#    {'name': 'Queen Soraya',
#     'role': 'Persian queen involved in political tensions',
#     'importance': 0.8,
#     'emotion': 'dignified yet skeptical',
#     'sentiment': -0.1,
#     'importance_rank': 3},
#    {'name': 'Nasrin',
#     'role': "Kaveh's estranged sister",
#     'importance': 0.7,
#     'emotion': 'quietly supportive',
#     'sentiment': 0.3,
#     'importance_rank': 4}],
#   'importance_rank': 1,
#   'conflict_rank': 3,
#   'first_line': 40,
#   'last_line': 68},
#  {'title': 'A Moment in the Royal Gardens',
#   'number': 49,
#   'summary': 'Mei reflects in the serene royal gardens, weighing her decision between love and duty.',
#   'chapter': 'Chapter 11',
#   'location': 'Royal gardens',
#   'importance': 0.8,
#   'conflict': 0.5,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'pensive and conflicted',
#     'sentiment': 0.2,
#     'importance_rank': 1},
#    {'name': 'Prince Cyrus',
#     'role': 'Persian prince',
#     'importance': 0.7,
#     'emotion': 'encouraging and insightful',
#     'sentiment': 0.5,
#     'importance_rank': 3},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.9,
#     'emotion': 'hopeful yet understanding',
#     'sentiment': 0.4,
#     'importance_rank': 2},
#    {'name': 'Aisha',
#     'role': 'skilled herbalist and healer',
#     'importance': 0.6,
#     'emotion': 'calming and wise',
#     'sentiment': 0.5,
#     'importance_rank': 4}],
#   'importance_rank': 5,
#   'conflict_rank': 4,
#   'first_line': 69,
#   'last_line': 96},
#  {'title': 'The Queen’s Offer',
#   'number': 50,
#   'summary': 'Queen Soraya offers Mei a choice: to remain in Persia and deepen her role in diplomacy or return to China.',
#   'chapter': 'Chapter 11',
#   'location': 'Persian palace',
#   'importance': 0.9,
#   'conflict': 0.7,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'torn and contemplative',
#     'sentiment': 0.3,
#     'importance_rank': 1},
#    {'name': 'Queen Soraya',
#     'role': 'Persian queen involved in political tensions',
#     'importance': 1.0,
#     'emotion': 'strategic and persuasive',
#     'sentiment': 0.0,
#     'importance_rank': 2},
#    {'name': 'Bahram',
#     'role': "Persian contact for Mei's father",
#     'importance': 0.6,
#     'emotion': 'supportive and understanding',
#     'sentiment': 0.5,
#     'importance_rank': 3},
#    {'name': 'Nasrin',
#     'role': "Kaveh's estranged sister",
#     'importance': 0.5,
#     'emotion': 'encouraging and empathetic',
#     'sentiment': 0.4,
#     'importance_rank': 4}],
#   'importance_rank': 4,
#   'conflict_rank': 2,
#   'first_line': 97,
#   'last_line': 124},
#  {'title': 'Heart and Duty',
#   'number': 51,
#   'summary': 'Mei confronts her inner conflict between family loyalty and her feelings for Kaveh, recognizing the gravity of her choice.',
#   'chapter': 'Chapter 11',
#   'location': 'Royal gardens',
#   'importance': 1.0,
#   'conflict': 0.9,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'conflicted and emotional',
#     'sentiment': -0.1,
#     'importance_rank': 1},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 1.0,
#     'emotion': 'understanding and hopeful',
#     'sentiment': 0.4,
#     'importance_rank': 2},
#    {'name': 'Prince Cyrus',
#     'role': 'Persian prince',
#     'importance': 0.7,
#     'emotion': 'supportive and neutral',
#     'sentiment': 0.3,
#     'importance_rank': 3},
#    {'name': 'Rashid',
#     'role': 'caravan helper',
#     'importance': 0.5,
#     'emotion': 'respectful and supportive',
#     'sentiment': 0.3,
#     'importance_rank': 4}],
#   'importance_rank': 2,
#   'conflict_rank': 1,
#   'first_line': 125,
#   'last_line': 152},
#  {'title': 'Final Conversations in the Palace',
#   'number': 52,
#   'summary': 'Before leaving, Mei has final conversations in the Persian palace, reflecting on her journey and growth.',
#   'chapter': 'Chapter 12',
#   'location': 'Persian palace',
#   'importance': 0.8,
#   'conflict': 0.3,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'reflective and grateful',
#     'sentiment': 0.6,
#     'importance_rank': 1},
#    {'name': 'Prince Cyrus',
#     'role': 'Persian prince',
#     'importance': 0.7,
#     'emotion': 'supportive and encouraging',
#     'sentiment': 0.5,
#     'importance_rank': 3},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.8,
#     'emotion': 'hopeful and warm',
#     'sentiment': 0.5,
#     'importance_rank': 2},
#    {'name': 'Hadi',
#     'role': 'Indian trader',
#     'importance': 0.5,
#     'emotion': 'respectful and admiring',
#     'sentiment': 0.4,
#     'importance_rank': 4}],
#   'importance_rank': 4,
#   'conflict_rank': 2,
#   'first_line': 1,
#   'last_line': 27},
#  {'title': 'Farewell to Persia',
#   'number': 53,
#   'summary': 'Mei says goodbye to her friends and allies, knowing her journey has changed her forever.',
#   'chapter': 'Chapter 12',
#   'location': 'Persian palace',
#   'importance': 0.9,
#   'conflict': 0.4,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'grateful and emotional',
#     'sentiment': 0.6,
#     'importance_rank': 1},
#    {'name': 'Queen Soraya',
#     'role': 'Persian queen involved in political tensions',
#     'importance': 0.6,
#     'emotion': 'dignified and approving',
#     'sentiment': 0.3,
#     'importance_rank': 3},
#    {'name': 'Kaveh',
#     'role': 'Persian merchant and potential love interest',
#     'importance': 0.9,
#     'emotion': 'supportive but saddened',
#     'sentiment': 0.4,
#     'importance_rank': 2},
#    {'name': 'Bahram',
#     'role': "Persian contact for Mei's father",
#     'importance': 0.5,
#     'emotion': 'loyal and respectful',
#     'sentiment': 0.4,
#     'importance_rank': 4},
#    {'name': 'Kalden',
#     'role': 'Tibetan monk and occasional healer',
#     'importance': 0.5,
#     'emotion': 'wise and calm',
#     'sentiment': 0.5,
#     'importance_rank': 5}],
#   'importance_rank': 3,
#   'conflict_rank': 1,
#   'first_line': 28,
#   'last_line': 58},
#  {'title': 'Reflecting on the Silk Road',
#   'number': 54,
#   'summary': 'As the caravan begins its return, Mei reflects on the journey and her newfound purpose.',
#   'chapter': 'Chapter 12',
#   'location': 'Caravan home camp',
#   'importance': 1.0,
#   'conflict': 0.2,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'hopeful and fulfilled',
#     'sentiment': 0.7,
#     'importance_rank': 1},
#    {'name': 'Rashid',
#     'role': 'caravan helper',
#     'importance': 0.6,
#     'emotion': 'encouraging and loyal',
#     'sentiment': 0.5,
#     'importance_rank': 2},
#    {'name': 'Aisha',
#     'role': 'skilled herbalist and healer',
#     'importance': 0.5,
#     'emotion': 'wise and compassionate',
#     'sentiment': 0.6,
#     'importance_rank': 3},
#    {'name': 'Hadi',
#     'role': 'Indian trader',
#     'importance': 0.4,
#     'emotion': 'friendly and respectful',
#     'sentiment': 0.4,
#     'importance_rank': 4}],
#   'importance_rank': 1,
#   'conflict_rank': 4,
#   'first_line': 59,
#   'last_line': 81},
#  {'title': 'Returning Home with New Wisdom',
#   'number': 55,
#   'summary': 'Mei returns to China, transformed by her experiences, and contemplates carrying on her father’s legacy.',
#   'chapter': 'Chapter 12',
#   'location': 'Caravan home camp',
#   'importance': 1.0,
#   'conflict': 0.3,
#   'characters': [{'name': 'Mei',
#     'role': 'protagonist, daughter of a tea merchant',
#     'importance': 1.0,
#     'emotion': 'resolved and inspired',
#     'sentiment': 0.8,
#     'importance_rank': 1},
#    {'name': 'Zhang',
#     'role': "Mei's father",
#     'importance': 0.8,
#     'emotion': 'proud and supportive',
#     'sentiment': 0.7,
#     'importance_rank': 2},
#    {'name': 'Li Wei',
#     'role': 'old woman and mystic',
#     'importance': 0.5,
#     'emotion': 'wise and mysterious',
#     'sentiment': 0.4,
#     'importance_rank': 4},
#    {'name': 'Kalden',
#     'role': 'Tibetan monk and occasional healer',
#     'importance': 0.6,
#     'emotion': 'serene and reflective',
#     'sentiment': 0.5,
#     'importance_rank': 3}],
#   'importance_rank': 2,
#   'conflict_rank': 3,
#   'first_line': 82,
#   'last_line': 107}]

# %%
# update json file
with open(f'json/{story}/story_outline.json', 'w') as file:
    json.dump(story_outline, file, indent=4)
