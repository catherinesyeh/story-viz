# %% [markdown]
# ## see if scene text can be found in chapter file

# %%
import json
import os

import pandas as pd
import altair as alt

import re

# %%
# load json data
story = "alice"
with open(f"../src/data/{story}-new.json") as f:
    data = json.load(f)

# %%
chapters_folder = f"chapters/{story}/"
chapters = data["chapters"]
scenes = data["scenes"]

# %%
for chap in chapters:
    chap_title = chap["chapter"]
    chap_text_file = f"{chapters_folder}{chap_title}.txt"
    with open(chap_text_file, "r") as f:
        chap_text = f.read()

    # only take text after ": " in each line
    chap_text = "\n".join([line.split(": ", 1)[1] for line in chap_text.split("\n") if ": " in line])

    chap_scenes = [scene for scene in scenes if scene["chapter"] == chap_title]
    for scene in chap_scenes:
        scene_num = scene["number"]
        scene_title = scene["title"]
        scene_text = scene["text"]
        
        if scene_text not in chap_text:
            print(f"Scene {chap_title}-{scene_title} (scene #{scene_num}) not found in {chap_title}.")
            # print(f"Scene text: {scene_text}")
            # print(f"Chapter text: {chap_text}")
            print()

# %% [markdown]
# ## check if chapters in public match those in notebooks

# %%
# list public chapter folder names
public_chapter_folder = f"../public/chapters/"
public_data_folder = f"../src/data/"

ignore_stories = ["yourname"]

public_chapters = os.listdir(public_chapter_folder)
public_chapters = [chap for chap in public_chapters if os.path.isdir(public_chapter_folder + chap)]
public_chapters = sorted([chap for chap in public_chapters if chap not in ignore_stories])

public_data = os.listdir(public_data_folder)
public_data = [data for data in public_data if data.endswith(".json") and "-new.json" in data]
# also remove ignore_stories
public_data = [data for data in public_data if data.split("-new.json")[0] not in ignore_stories]

# len(public_chapters), public_chapters
len(public_data), public_data
# Out:
# (36,
#  ['whispers-new.json',
#   'littlewomen-new.json',
#   'tenant-new.json',
#   'bookstore-new.json',
#   'redchamber-new.json',
#   'starlight-new.json',
#   'genji-new.json',
#   'ulysses-new.json',
#   'romeo-new.json',
#   'victoria-new.json',
#   'janeeyre-new.json',
#   'odyssey-new.json',
#   'trial-new.json',
#   'pygmalion-new.json',
#   'faust-new.json',
#   'time-new.json',
#   'mendips-new.json',
#   'candide-new.json',
#   'artofwar-new.json',
#   'metamorphosis-new.json',
#   'war-new.json',
#   'anne-new.json',
#   'frankenstein-new.json',
#   'greatexp-new.json',
#   'school-new.json',
#   'alice-new.json',
#   'threads-new.json',
#   'gatsby-new.json',
#   'iliad-new.json',
#   'color-new.json',
#   'donquixote-new.json',
#   'pride-new.json',
#   'hamlet-new.json',
#   'emma-new.json',
#   'wizard-new.json',
#   'marrow-new.json'])

# %%
for story in public_chapters:
    # compare each .txt file in this folder with the corresponding chapter in the json file
    chapters_folder = f"{public_chapter_folder}/{story}/"
    notebook_chapter_folder = f"chapters/{story}/"
    public_txt_files = os.listdir(chapters_folder)
    public_txt_files = [f for f in public_txt_files if f.endswith(".txt")]
    public_txt_files = sorted(public_txt_files)

    for pf in public_txt_files:
        # load in txt file
        with open(chapters_folder + pf, "r") as f:
            chap_text = f.read()
        
        # load corresponding chapter txt from notebook_chapter_folder
        with open(f"{notebook_chapter_folder}{pf}", "r") as f:
            notebook_chap_text = f.read()
        
        if chap_text != notebook_chap_text:
            print(f"Chapter {pf} in {story} does not match.")
            # find problematic lines
            chap_text_lines = chap_text.split("\n")
            notebook_chap_text_lines = notebook_chap_text.split("\n")

            for i, (line1, line2) in enumerate(zip(chap_text_lines, notebook_chap_text_lines)):
                if line1 != line2:
                    print(f"Line {i}:")
                    print(f"  {line1}")
                    print(f"  {line2}")
                    print()
            print()
            print()

# %% [markdown]
# ## print number of lines in each story

# %%
# llm-generated stories
llm_stories = ["bookstore", "color", "starlight", "threads", "time", "whispers"]
plays = ["faust", "hamlet", "pygmalion", "romeo", "school"]

# %%
all_line_counts = {}
all_quote_counts = {}
scene_divisions = []
for f in sorted(public_data):
    story_formatted = f.split("-new.json")[0]

    with open(f"{public_data_folder}{f}", "r") as file:
        data = json.load(file)
    
    chapters = data["chapters"]
    scenes = data["scenes"]
    num_lines = 0
    num_quotes = 0
    for chap in chapters:
        chap_lines = chap["num_lines"]
        num_lines += chap_lines
    for scene in scenes:
        scene_quotes = len(scene["characters"])
        num_quotes += scene_quotes
        story_type = "llm" if story_formatted in llm_stories else "play" if story_formatted in plays else "non-play"
        scene_divisions.append({"exp": scene["explanation"], "story_type": story_type})
    
    print(f"{f}: {num_lines}, {num_quotes}")

    all_line_counts[story_formatted] = num_lines
    all_quote_counts[story_formatted] = num_quotes
# Out:
# alice-new.json: 2463, 176
# anne-new.json: 8703, 626
# artofwar-new.json: 7571, 351
# bookstore-new.json: 1388, 103
# candide-new.json: 2877, 350
# color-new.json: 1672, 92
# donquixote-new.json: 16099, 804
# emma-new.json: 4215, 276
# faust-new.json: 6242, 123
# frankenstein-new.json: 6655, 332
# gatsby-new.json: 4710, 181
# genji-new.json: 7864, 342
# greatexp-new.json: 16105, 908
# hamlet-new.json: 5199, 92
# iliad-new.json: 19463, 561
# janeeyre-new.json: 16560, 615
# littlewomen-new.json: 16680, 1022
# marrow-new.json: 7820, 526
# mendips-new.json: 7511, 424
# metamorphosis-new.json: 1752, 82
# odyssey-new.json: 9246, 511
# pride-new.json: 10997, 911
# pygmalion-new.json: 2630, 95
# redchamber-new.json: 15778, 882
# romeo-new.json: 3401, 85
# school-new.json: 2948, 94
# starlight-new.json: 1575, 101
# tenant-new.json: 14546, 739
# threads-new.json: 1504, 100
# time-new.json: 1650, 123
# trial-new.json: 6472, 155
# ulysses-new.json: 25435, 583
# victoria-new.json: 7555, 341
# war-new.json: 4482, 309
# whispers-new.json: 1741, 165
# wizard-new.json: 3403, 344

# %%
# llm-generated stories
llm_stories = ["bookstore", "color", "starlight", "time", "threads", "whispers"]

# %%
# line_count_dict for llm stories
llm_count_dict = {}
for story in llm_stories:
    llm_count_dict[story] = all_line_counts[story]

human_count_dict = {}
for story in public_chapters:
    if story not in llm_stories:
        human_count_dict[story] = all_line_counts[story]

# %%
len(human_count_dict), human_count_dict, len(llm_count_dict), llm_count_dict
# Out:
# (30,
#  {'alice': 2463,
#   'anne': 8703,
#   'artofwar': 7571,
#   'candide': 2877,
#   'donquixote': 16099,
#   'emma': 4215,
#   'faust': 6242,
#   'frankenstein': 6655,
#   'gatsby': 4710,
#   'genji': 7864,
#   'greatexp': 16105,
#   'hamlet': 5199,
#   'iliad': 19463,
#   'janeeyre': 16560,
#   'littlewomen': 16680,
#   'marrow': 7820,
#   'mendips': 7511,
#   'metamorphosis': 1752,
#   'odyssey': 9246,
#   'pride': 10997,
#   'pygmalion': 2630,
#   'redchamber': 15778,
#   'romeo': 3401,
#   'school': 2948,
#   'tenant': 14546,
#   'trial': 6472,
#   'ulysses': 25435,
#   'victoria': 7555,
#   'war': 4482,
#   'wizard': 3403},
#  6,
#  {'bookstore': 1388,
#   'color': 1672,
#   'starlight': 1575,
#   'time': 1650,
#   'threads': 1504,
#   'whispers': 1741})

# %%
# shortest story in Human stories
min_lines_human = min(human_count_dict.values())
min_lines_human_story = [k for k, v in human_count_dict.items() if v == min_lines_human]

# longest story in Human stories
max_lines_human = max(human_count_dict.values())
max_lines_human_story = [k for k, v in human_count_dict.items() if v == max_lines_human]

# average line count for Human stories
avg_lines_human = sum(human_count_dict.values()) / len(human_count_dict)

# shortest story in LLM stories
min_lines_llm = min(llm_count_dict.values())
min_lines_llm_story = [k for k, v in llm_count_dict.items() if v == min_lines_llm]

# longest story in LLM stories
max_lines_llm = max(llm_count_dict.values())
max_lines_llm_story = [k for k, v in llm_count_dict.items() if v == max_lines_llm]

# average line count for LLM stories
avg_lines_llm = sum(llm_count_dict.values()) / len(llm_count_dict)

print(f"Human counts")
print(f"  Min: {min_lines_human} ({min_lines_human_story})")
print(f"  Max: {max_lines_human} ({max_lines_human_story})")
print(f"  Avg: {avg_lines_human}")

print(f"LLM counts")
print(f"  Min: {min_lines_llm} ({min_lines_llm_story})")
print(f"  Max: {max_lines_llm} ({max_lines_llm_story})")
print(f"  Avg: {avg_lines_llm}")
# Out:
# Human counts
#   Min: 1752 (['metamorphosis'])
#   Max: 25435 (['ulysses'])
#   Avg: 8846.066666666668
# LLM counts
#   Min: 1388 (['bookstore'])
#   Max: 1741 (['whispers'])
#   Avg: 1588.3333333333333

# %% [markdown]
# ### create histogram

# %%
# convert to dataframe
human_df = pd.DataFrame(human_count_dict.items(), columns=["story", "num_lines"])
llm_df = pd.DataFrame(llm_count_dict.items(), columns=["story", "num_lines"])

human_df["type"] = "human"
llm_df["type"] = "llm"

df = pd.concat([human_df, llm_df])

# %%
# Create histogram
chart = alt.Chart(df).mark_bar().encode(
    x=alt.X('num_lines:Q', bin=alt.Bin(maxbins=20), title="Count"),
    y=alt.Y('count()', title="Number of Stories"),
    color=alt.Color('type:N', scale=alt.Scale(scheme='category10'), title="Story Type"),
    tooltip=['type', 'count()']
).properties(
    title="Length Distribution of Human and LLM Stories",
    width=500,
    height=200
)

# show chart
chart
# Out:
# alt.Chart(...)

# %%
boxplot = alt.Chart(df).mark_boxplot().encode(
    y=alt.Y('type:N', title="Story Type"),
    x=alt.X('num_lines:Q', title="Number of Lines"),
    color=alt.Color('type:N', scale=alt.Scale(scheme='category10'), title="Story Type"),
    tooltip=['type', 'num_lines']
).properties(
    title="Length Distribution in Human and LLM Stories",
    width=600,
    height=200
)

boxplot
# Out:
# alt.Chart(...)

# %% [markdown]
# ## analyze scene divisions

# %%
len(scene_divisions), scene_divisions
# Out:
# (4633,
#  [{'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to the rabbit hole.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to the hall.', 'story_type': 'non-play'},
#   {'exp': 'Location remains at the table.', 'story_type': 'non-play'},
#   {'exp': 'Location remains at the table.', 'story_type': 'non-play'},
#   {'exp': 'Location remains at the table.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to the pool.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': "The focus shifts to the Mouse's speech.", 'story_type': 'non-play'},
#   {'exp': 'The Dodo introduces the idea of the race.',
#    'story_type': 'non-play'},
#   {'exp': 'The race concludes and prizes are distributed.',
#    'story_type': 'non-play'},
#   {'exp': "The scene shifts to the Mouse's story.", 'story_type': 'non-play'},
#   {'exp': 'The location changes as Alice is left alone.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': "Alice enters the Rabbit's house.", 'story_type': 'non-play'},
#   {'exp': "Alice drinks from the bottle in the Rabbit's house.",
#    'story_type': 'non-play'},
#   {'exp': 'The Rabbit comes back to the house.', 'story_type': 'non-play'},
#   {'exp': "The scene shifts outside the Rabbit's house.",
#    'story_type': 'non-play'},
#   {'exp': "Alice leaves the Rabbit's house.", 'story_type': 'non-play'},
#   {'exp': 'Alice is now in the woods.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': "Alice's location changes as she interacts with the mushroom.",
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to inside the kitchen.', 'story_type': 'non-play'},
#   {'exp': 'Location remains in the kitchen but focuses on the baby.',
#    'story_type': 'non-play'},
#   {'exp': 'Location changes to the woods.', 'story_type': 'non-play'},
#   {'exp': "Location changes to near the March Hare's house.",
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to the garden.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'The location changes as the procession arrives.',
#    'story_type': 'non-play'},
#   {'exp': "The scene shifts to the Queen's command.",
#    'story_type': 'non-play'},
#   {'exp': 'The location changes to the croquet ground.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'The conversation shifts to morals.', 'story_type': 'non-play'},
#   {'exp': 'The location changes as the Queen arrives.',
#    'story_type': 'non-play'},
#   {'exp': 'The scene shifts to the croquet ground.', 'story_type': 'non-play'},
#   {'exp': 'The scene changes as they find the Mock Turtle.',
#    'story_type': 'non-play'},
#   {'exp': 'The Mock Turtle starts his narrative.', 'story_type': 'non-play'},
#   {'exp': 'The conversation shifts to lessons and games.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'The focus shifts to the dance they are performing.',
#    'story_type': 'non-play'},
#   {'exp': 'The conversation changes to the topic of whiting.',
#    'story_type': 'non-play'},
#   {'exp': 'Alice begins recounting her experiences.',
#    'story_type': 'non-play'},
#   {'exp': 'The scene shifts to the Mock Turtle singing.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': "Alice's perspective in the courtroom.", 'story_type': 'non-play'},
#   {'exp': 'The trial officially starts.', 'story_type': 'non-play'},
#   {'exp': "The focus shifts to the Hatter's testimony.",
#    'story_type': 'non-play'},
#   {'exp': 'A new witness is introduced.', 'story_type': 'non-play'},
#   {'exp': 'The scene shifts to the next witness.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': "The focus shifts to the King's ruling.", 'story_type': 'non-play'},
#   {'exp': 'The scene changes with the introduction of new evidence.',
#    'story_type': 'non-play'},
#   {'exp': 'The focus shifts to the content of the verses.',
#    'story_type': 'non-play'},
#   {'exp': "Alice's interruption leads to a new focus.",
#    'story_type': 'non-play'},
#   {'exp': "The tension escalates with the Queen's command.",
#    'story_type': 'non-play'},
#   {'exp': 'The scene shifts to reality as Alice wakes.',
#    'story_type': 'non-play'},
#   {'exp': "The focus shifts to Alice's sister's thoughts.",
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Change of focus to Matthew Cuthbert.', 'story_type': 'non-play'},
#   {'exp': 'Change of location to Green Gables.', 'story_type': 'non-play'},
#   {'exp': 'Inside Green Gables kitchen.', 'story_type': 'non-play'},
#   {'exp': 'Discussion about the orphan boy.', 'story_type': 'non-play'},
#   {'exp': 'Continuation of conversation at Green Gables.',
#    'story_type': 'non-play'},
#   {'exp': 'End of chapter as she exits.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to the station.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to the platform where Anne is waiting.',
#    'story_type': 'non-play'},
#   {'exp': 'Location changes to the buggy as they leave the station.',
#    'story_type': 'non-play'},
#   {'exp': 'Location changes as they enter the Avenue.',
#    'story_type': 'non-play'},
#   {'exp': 'Location changes as they approach Green Gables.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same, emotional shift.',
#    'story_type': 'non-play'},
#   {'exp': 'Discussion about names continues in the same location.',
#    'story_type': 'non-play'},
#   {'exp': 'Dinner setting introduces a new atmosphere.',
#    'story_type': 'non-play'},
#   {'exp': "Change of location to Anne's room.", 'story_type': 'non-play'},
#   {'exp': 'Final scene takes place in the kitchen after Anne is settled.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Marilla enters the room.', 'story_type': 'non-play'},
#   {'exp': 'Scene shifts to the breakfast table.', 'story_type': 'non-play'},
#   {'exp': 'Scene shifts to the kitchen after breakfast.',
#    'story_type': 'non-play'},
#   {'exp': 'Scene shifts as they prepare to leave.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to the parlor.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to the parlor with Mrs. Blewett.',
#    'story_type': 'non-play'},
#   {'exp': 'Location changes to the dairy at Green Gables.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to a discussion about prayer.',
#    'story_type': 'non-play'},
#   {'exp': 'Location changes to Anne praying.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to Marilla in the kitchen.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to the sitting room.', 'story_type': 'non-play'},
#   {'exp': "Location changes to Anne's room.", 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': "Location changes to Anne's explorations.",
#    'story_type': 'non-play'},
#   {'exp': 'Location changes to the orchard.', 'story_type': 'non-play'},
#   {'exp': "Location changes to Anne's room.", 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Matthew enters the house and goes upstairs.',
#    'story_type': 'non-play'},
#   {'exp': 'Marilla and Anne leave the house.', 'story_type': 'non-play'},
#   {'exp': "They arrive at Mrs. Lynde's house.", 'story_type': 'non-play'},
#   {'exp': "They leave Mrs. Lynde's house and walk home.",
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to outside the house.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to the church.', 'story_type': 'non-play'},
#   {'exp': 'Location remains in the church but shifts to the classroom.',
#    'story_type': 'non-play'},
#   {'exp': 'Location changes back to home.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to Orchard Slope.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to the garden.', 'story_type': 'non-play'},
#   {'exp': 'Location changes back to Green Gables.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': "Location remains the same, focus shifts to Anne's conversation.",
#    'story_type': 'non-play'},
#   {'exp': 'Still in the same location, Anne continues her thoughts.',
#    'story_type': 'non-play'},
#   {'exp': "The scene shifts to a new topic about Marilla's brooch.",
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to the next morning.', 'story_type': 'non-play'},
#   {'exp': "Location changes to Anne's room.", 'story_type': 'non-play'},
#   {'exp': 'Location changes to the kitchen.', 'story_type': 'non-play'},
#   {'exp': 'Location changes back to Green Gables.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to the school.', 'story_type': 'non-play'},
#   {'exp': 'Location changes back to home.', 'story_type': 'non-play'},
#   {'exp': "Location changes to Rachel's house.", 'story_type': 'non-play'},
#   {'exp': 'Location changes back to home.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location remains at Green Gables.', 'story_type': 'non-play'},
#   {'exp': "Transition to Diana's arrival at Green Gables.",
#    'story_type': 'non-play'},
#   {'exp': 'Location changes to the orchard.', 'story_type': 'non-play'},
#   {'exp': 'Still in the orchard, but focus shifts to the cordial.',
#    'story_type': 'non-play'},
#   {'exp': 'Location remains in the orchard.', 'story_type': 'non-play'},
#   {'exp': 'Transition back to Green Gables.', 'story_type': 'non-play'},
#   {'exp': 'Location remains at Green Gables.', 'story_type': 'non-play'},
#   {'exp': "Transition to Mrs. Barry's house.", 'story_type': 'non-play'},
#   {'exp': 'Location returns to Green Gables.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': "Location changes to Anne's home.", 'story_type': 'non-play'},
#   {'exp': "Location changes to Anne's home.", 'story_type': 'non-play'},
#   {'exp': 'Location changes to the school.', 'story_type': 'non-play'},
#   {'exp': 'Still at school.', 'story_type': 'non-play'},
#   {'exp': 'Still at school.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location remains at Green Gables.', 'story_type': 'non-play'},
#   {'exp': 'Diana arrives at Green Gables.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to the Barry household.',
#    'story_type': 'non-play'},
#   {'exp': 'Still at the Barry household.', 'story_type': 'non-play'},
#   {'exp': 'Location changes back to Green Gables.', 'story_type': 'non-play'},
#   {'exp': 'Still at Green Gables.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same, but the topic shifts to the concert.',
#    'story_type': 'non-play'},
#   {'exp': "The conversation shifts to Matthew and Marilla's discussion.",
#    'story_type': 'non-play'},
#   {'exp': 'Change in location to the school.', 'story_type': 'non-play'},
#   {'exp': "Location changes to Diana's home as they prepare.",
#    'story_type': 'non-play'},
#   {'exp': 'Location changes to the sleigh ride.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to the concert hall.', 'story_type': 'non-play'},
#   {'exp': "Location changes back to Diana's home.", 'story_type': 'non-play'},
#   {'exp': 'Location changes to the Barry household.',
#    'story_type': 'non-play'},
#   {'exp': 'Location remains in the Barry household.',
#    'story_type': 'non-play'},
#   {'exp': 'Location remains in the Barry household.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to Violet Vale.', 'story_type': 'non-play'},
#   {'exp': "Location changes to Anne's gable room.", 'story_type': 'non-play'},
#   {'exp': 'Continues in the same room.', 'story_type': 'non-play'},
#   {'exp': "Location changes to the path to Barry's.",
#    'story_type': 'non-play'},
#   {'exp': 'Location changes back to the path.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': "Location changes to Mrs. Lynde's.", 'story_type': 'non-play'},
#   {'exp': "Location remains at Mrs. Lynde's.", 'story_type': 'non-play'},
#   {'exp': "Location remains at Mrs. Lynde's.", 'story_type': 'non-play'},
#   {'exp': 'Location changes back to Green Gables.', 'story_type': 'non-play'},
#   {'exp': 'Location remains at Green Gables.', 'story_type': 'non-play'},
#   {'exp': 'Location remains at Green Gables.', 'story_type': 'non-play'},
#   {'exp': 'Location remains at Green Gables.', 'story_type': 'non-play'},
#   {'exp': 'Location remains at Green Gables.', 'story_type': 'non-play'},
#   {'exp': 'Location remains at Green Gables.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location remains at Green Gables.', 'story_type': 'non-play'},
#   {'exp': 'Still at Green Gables, but a new day.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to the manse.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to Barry garden.', 'story_type': 'non-play'},
#   {'exp': 'The dare is proposed.', 'story_type': 'non-play'},
#   {'exp': 'Anne climbs the roof.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to the orchard.', 'story_type': 'non-play'},
#   {'exp': "Marilla's emotional response.", 'story_type': 'non-play'},
#   {'exp': 'Location changes to inside the house.', 'story_type': 'non-play'},
#   {'exp': 'Anne is in bed after the accident.', 'story_type': 'non-play'},
#   {'exp': "Anne's recovery period.", 'story_type': 'non-play'},
#   {'exp': 'Discussion about school activities.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': "Location remains the same, but focus shifts to Anne's feelings about Miss Stacy.",
#    'story_type': 'non-play'},
#   {'exp': "Continues in the same location but shifts to Anne's recitation experience.",
#    'story_type': 'non-play'},
#   {'exp': 'New focus on the concert project introduced by Miss Stacy.',
#    'story_type': 'non-play'},
#   {'exp': 'Change of location to the backyard.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to Carmody.', 'story_type': 'non-play'},
#   {'exp': 'Location remains in the store.', 'story_type': 'non-play'},
#   {'exp': 'Location changes back to Green Gables.', 'story_type': 'non-play'},
#   {'exp': 'Location remains at Green Gables.', 'story_type': 'non-play'},
#   {'exp': 'Location remains at Green Gables.', 'story_type': 'non-play'},
#   {'exp': 'Location remains in Avonlea.', 'story_type': 'non-play'},
#   {'exp': 'Location remains at Green Gables.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Change of location to the Birch Path.', 'story_type': 'non-play'},
#   {'exp': 'Change of focus to storytelling.', 'story_type': 'non-play'},
#   {'exp': 'Change of focus to the story club and its activities.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': "Location changes to Marilla's kitchen.", 'story_type': 'non-play'},
#   {'exp': 'Continues in the kitchen with Matthew.', 'story_type': 'non-play'},
#   {'exp': 'Anne enters the scene in the kitchen.', 'story_type': 'non-play'},
#   {'exp': "Discussion about Anne's hair takes place in the bedroom.",
#    'story_type': 'non-play'},
#   {'exp': 'Continues in the bedroom.', 'story_type': 'non-play'},
#   {'exp': 'Still in the bedroom.', 'story_type': 'non-play'},
#   {'exp': 'Continues in the bedroom.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to the kitchen.', 'story_type': 'non-play'},
#   {'exp': 'Still in the kitchen.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to school.', 'story_type': 'non-play'},
#   {'exp': 'Back at home, in the living area.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'The scene shifts to the preparation for the play.',
#    'story_type': 'non-play'},
#   {'exp': 'The location changes as Anne drifts down the pond.',
#    'story_type': 'non-play'},
#   {'exp': 'The scene shifts to the rescue.', 'story_type': 'non-play'},
#   {'exp': 'The location changes as Anne returns home.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to the Barry field.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to the maple tree.', 'story_type': 'non-play'},
#   {'exp': "Location changes to Anne's home.", 'story_type': 'non-play'},
#   {'exp': 'Location changes to Beechwood.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to the Exhibition grounds.',
#    'story_type': 'non-play'},
#   {'exp': 'Location changes to the Academy of Music.',
#    'story_type': 'non-play'},
#   {'exp': 'Location changes back to Green Gables.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Anne begins to talk about her day.', 'story_type': 'non-play'},
#   {'exp': "Discussion shifts to Miss Stacy's intentions.",
#    'story_type': 'non-play'},
#   {'exp': 'Anne reacts to the news about the class.',
#    'story_type': 'non-play'},
#   {'exp': "Focus shifts to Anne's classmates.", 'story_type': 'non-play'},
#   {'exp': 'Discussion of rivalry and feelings.', 'story_type': 'non-play'},
#   {'exp': 'Transition to the end of the school year.',
#    'story_type': 'non-play'},
#   {'exp': 'Discussion of summer activities.', 'story_type': 'non-play'},
#   {'exp': "Shift to Marilla's conversation with Rachel.",
#    'story_type': 'non-play'},
#   {'exp': "Final conversation about Anne's development.",
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Change in focus to school life.', 'story_type': 'non-play'},
#   {'exp': 'Shift to winter school activities.', 'story_type': 'non-play'},
#   {'exp': "Focus on Anne's physical and emotional changes.",
#    'story_type': 'non-play'},
#   {'exp': "Discussion about the Entrance exams and Anne's anxieties.",
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Change of location to Beechwood.', 'story_type': 'non-play'},
#   {'exp': 'Change of location back to Green Gables.',
#    'story_type': 'non-play'},
#   {'exp': 'Change of location to the post office.', 'story_type': 'non-play'},
#   {'exp': 'Change of location back to Green Gables.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to outside on the road.',
#    'story_type': 'non-play'},
#   {'exp': 'Location changes to the concert hall.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to outside after the concert.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Change of location to town.', 'story_type': 'non-play'},
#   {'exp': 'Change of location to the Academy.', 'story_type': 'non-play'},
#   {'exp': 'Change of location to boarding house.', 'story_type': 'non-play'},
#   {'exp': "Change of location to Anne's room with friends.",
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to the Academy.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to Charlottetown.', 'story_type': 'non-play'},
#   {'exp': 'Location remains in Charlottetown.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': "Location changes to inside Queen's.", 'story_type': 'non-play'},
#   {'exp': 'Location changes to Avonlea.', 'story_type': 'non-play'},
#   {'exp': "Location changes to Anne's room.", 'story_type': 'non-play'},
#   {'exp': 'Location changes to breakfast table.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to outdoors.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to the funeral setting.',
#    'story_type': 'non-play'},
#   {'exp': "Location changes to Anne's room.", 'story_type': 'non-play'},
#   {'exp': "Location remains in Anne's room.", 'story_type': 'non-play'},
#   {'exp': 'Location changes to the community and daily life.',
#    'story_type': 'non-play'},
#   {'exp': 'Location remains in the community.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to the graveyard.', 'story_type': 'non-play'},
#   {'exp': 'Location changes back to Green Gables.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': "Location changes to Anne's room.", 'story_type': 'non-play'},
#   {'exp': 'Location changes to the living room.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to the front door.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to the graveyard.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to the hill.', 'story_type': 'non-play'},
#   {'exp': 'Location changes back to the kitchen.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same, discussing war factors.',
#    'story_type': 'non-play'},
#   {'exp': 'Continues in the same location discussing victory.',
#    'story_type': 'non-play'},
#   {'exp': 'Still in the same location, focusing on counsel.',
#    'story_type': 'non-play'},
#   {'exp': 'Same location, discussing strategies of deception.',
#    'story_type': 'non-play'},
#   {'exp': 'Final thoughts in the same location.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': "Change in focus to Sun Tzŭ's teachings.", 'story_type': 'non-play'},
#   {'exp': 'Shift to discussing the effects of prolonged warfare.',
#    'story_type': 'non-play'},
#   {'exp': 'Shift to strategies for managing resources.',
#    'story_type': 'non-play'},
#   {'exp': 'Change in focus to economic impacts.', 'story_type': 'non-play'},
#   {'exp': 'Focus on the impact of war on the populace.',
#    'story_type': 'non-play'},
#   {'exp': 'Shift to strategies for winning battles.',
#    'story_type': 'non-play'},
#   {'exp': "Conclusion on the leader's impact on the nation.",
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same throughout the discussion.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Change in focus to principles of engagement.',
#    'story_type': 'non-play'},
#   {'exp': 'Change in focus to specific strategies.', 'story_type': 'non-play'},
#   {'exp': 'Change in focus to understanding the enemy.',
#    'story_type': 'non-play'},
#   {'exp': 'Change in focus to concentration of forces.',
#    'story_type': 'non-play'},
#   {'exp': 'Change in focus to the conclusion on strategy.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Shift in focus to tactics.', 'story_type': 'non-play'},
#   {'exp': 'Focus on advantages of maneuvering.', 'story_type': 'non-play'},
#   {'exp': 'Shift to logistics and supplies.', 'story_type': 'non-play'},
#   {'exp': 'Focus on terrain knowledge.', 'story_type': 'non-play'},
#   {'exp': 'Shift to tactics of deception.', 'story_type': 'non-play'},
#   {'exp': 'Focus on resource management.', 'story_type': 'non-play'},
#   {'exp': 'Shift to planning.', 'story_type': 'non-play'},
#   {'exp': 'Discussion of the principles of war.', 'story_type': 'non-play'},
#   {'exp': 'Transition to specific considerations.', 'story_type': 'non-play'},
#   {'exp': 'Focus on the importance of counsel.', 'story_type': 'non-play'},
#   {'exp': 'Introduction of deception as a strategy.',
#    'story_type': 'non-play'},
#   {'exp': "Focus on the general's preparations.", 'story_type': 'non-play'},
#   {'exp': 'Transition to military conditions.', 'story_type': 'non-play'},
#   {'exp': 'Discussion on the dangers of prolonged warfare.',
#    'story_type': 'non-play'},
#   {'exp': 'Focus on logistics and supply.', 'story_type': 'non-play'},
#   {'exp': 'Transition to morale and rewards.', 'story_type': 'non-play'},
#   {'exp': 'Final thoughts on leadership.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Change in focus to mountain warfare.', 'story_type': 'non-play'},
#   {'exp': 'Change in focus to river warfare.', 'story_type': 'non-play'},
#   {'exp': 'Change in focus to salt-marsh operations.',
#    'story_type': 'non-play'},
#   {'exp': 'Change in focus to flat country.', 'story_type': 'non-play'},
#   {'exp': 'Change in focus to military knowledge.', 'story_type': 'non-play'},
#   {'exp': 'Change in focus to high ground.', 'story_type': 'non-play'},
#   {'exp': 'Change in focus to environmental conditions.',
#    'story_type': 'non-play'},
#   {'exp': 'Change in focus to enemy signs.', 'story_type': 'non-play'},
#   {'exp': 'Change in focus to dust and camp behavior.',
#    'story_type': 'non-play'},
#   {'exp': 'Change in focus to enemy intentions.', 'story_type': 'non-play'},
#   {'exp': 'Change in focus to discipline and command.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'New topic introduced.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same, focusing on strategies.',
#    'story_type': 'non-play'},
#   {'exp': 'Continuation of strategic discussion.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'llm'},
#   {'exp': 'Mr. Thompson enters the bookstore.', 'story_type': 'llm'},
#   {'exp': 'Mrs. Jenkins enters the bookstore.', 'story_type': 'llm'},
#   {'exp': 'A new character enters the bookstore.', 'story_type': 'llm'},
#   {'exp': 'A delivery person enters the bookstore.', 'story_type': 'llm'},
#   {'exp': 'Emma continues her reflections after the delivery.',
#    'story_type': 'llm'},
#   {'exp': 'Start of chapter.', 'story_type': 'llm'},
#   {'exp': 'Start of chapter.', 'story_type': 'llm'},
#   {'exp': 'Emma continues reading the first manuscript.', 'story_type': 'llm'},
#   {'exp': 'Emma picks up a new manuscript about Lily.', 'story_type': 'llm'},
#   {'exp': 'Emma opens the final manuscript about Sarah.', 'story_type': 'llm'},
#   {'exp': 'Start of chapter.', 'story_type': 'llm'},
#   {'exp': 'Lily arrives at the bookstore.', 'story_type': 'llm'},
#   {'exp': 'The conversation deepens as they sit down.', 'story_type': 'llm'},
#   {'exp': 'Start of chapter.', 'story_type': 'llm'},
#   {'exp': 'Start of chapter.', 'story_type': 'llm'},
#   {'exp': 'Location changes to the community center.', 'story_type': 'llm'},
#   {'exp': "Location changes to Sarah's kitchen.", 'story_type': 'llm'},
#   {'exp': 'Start of chapter.', 'story_type': 'llm'},
#   {'exp': 'Location changes as townspeople enter.', 'story_type': 'llm'},
#   {'exp': "Location changes with Mr. Thompson's entrance.",
#    'story_type': 'llm'},
#   {'exp': 'Emma begins her presentation.', 'story_type': 'llm'},
#   {'exp': "Mr. Thompson's challenge changes the dynamic.",
#    'story_type': 'llm'},
#   {'exp': 'The meeting progresses with community engagement.',
#    'story_type': 'llm'},
#   {'exp': 'Start of chapter.', 'story_type': 'llm'},
#   {'exp': 'Start of chapter.', 'story_type': 'llm'},
#   {'exp': 'Location changes to downtown.', 'story_type': 'llm'},
#   {'exp': 'Location changes back to the bookstore.', 'story_type': 'llm'},
#   {'exp': 'Location remains at the bookstore.', 'story_type': 'llm'},
#   {'exp': 'Location changes to Town Hall.', 'story_type': 'llm'},
#   {'exp': 'Start of chapter.', 'story_type': 'llm'},
#   {'exp': 'Location changes to the Festival Grounds.', 'story_type': 'llm'},
#   {'exp': 'Location remains at the Festival Grounds.', 'story_type': 'llm'},
#   {'exp': 'Location remains at the Festival Grounds.', 'story_type': 'llm'},
#   {'exp': 'Location remains at the Festival Grounds.', 'story_type': 'llm'},
#   {'exp': 'Location remains at the Festival Grounds.', 'story_type': 'llm'},
#   {'exp': 'Location remains at the Festival Grounds.', 'story_type': 'llm'},
#   {'exp': 'Start of chapter.', 'story_type': 'llm'},
#   {'exp': 'Start of chapter.', 'story_type': 'llm'},
#   {'exp': 'The location shifts to the festival grounds.', 'story_type': 'llm'},
#   {'exp': 'Back at the bookstore after the festival.', 'story_type': 'llm'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Cunegonde leaves the castle to the park.',
#    'story_type': 'non-play'},
#   {'exp': 'Scene shifts to behind the screen in the castle.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to the inn.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to the military camp.', 'story_type': 'non-play'},
#   {'exp': 'Continues in the military camp.', 'story_type': 'non-play'},
#   {'exp': 'Still in the military camp.', 'story_type': 'non-play'},
#   {'exp': "Location changes to the King's presence.",
#    'story_type': 'non-play'},
#   {'exp': 'Location changes to the battlefield.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to a neighboring village.',
#    'story_type': 'non-play'},
#   {'exp': 'Location changes to Holland.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to a public area in Holland.',
#    'story_type': 'non-play'},
#   {'exp': 'Location remains the same, but a new character is introduced.',
#    'story_type': 'non-play'},
#   {'exp': 'Location remains the same, but the focus shifts to a new character.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location changes as they board the ship.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location remains in Lisbon, but the focus shifts to a conversation.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter', 'story_type': 'non-play'},
#   {'exp': "Change in focus to Candide's reflections after the ceremony.",
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location changes as they leave the initial house.',
#    'story_type': 'non-play'},
#   {'exp': 'Location changes as they enter the new apartment.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': "Location changes to Cunegonde's quarters.",
#    'story_type': 'non-play'},
#   {'exp': "Location changes to the Inquisitor's palace.",
#    'story_type': 'non-play'},
#   {'exp': 'Location changes to the supper table.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': "The location changes to the Inquisitor's entrance.",
#    'story_type': 'non-play'},
#   {'exp': "The focus shifts to Candide's internal conflict.",
#    'story_type': 'non-play'},
#   {'exp': 'The conversation shifts to planning their escape.',
#    'story_type': 'non-play'},
#   {'exp': 'The location changes as they reach Avacena.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to the inn.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to the ship.', 'story_type': 'non-play'},
#   {'exp': 'Location remains on the ship.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same, but the focus shifts to her engagement.',
#    'story_type': 'non-play'},
#   {'exp': 'Change in location as they arrive in Morocco.',
#    'story_type': 'non-play'},
#   {'exp': 'Change in location as the battle occurs in Morocco.',
#    'story_type': 'non-play'},
#   {'exp': 'Change in focus as she moves from the battle to her personal experience.',
#    'story_type': 'non-play'},
#   {'exp': 'Location changes to Algiers.', 'story_type': 'non-play'},
#   {'exp': 'Location changes as she is sold to different merchants.',
#    'story_type': 'non-play'},
#   {'exp': 'Location changes to the ship where they are conversing.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to Buenos Ayres.', 'story_type': 'non-play'},
#   {'exp': 'Location remains in Buenos Ayres.', 'story_type': 'non-play'},
#   {'exp': 'Location remains in Buenos Ayres.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to Paraguay.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Change of location to the Jesuit setting.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to the wood where they are captured.',
#    'story_type': 'non-play'},
#   {'exp': "Location changes back to the Oreillons' territory after their release.",
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Change in location as they begin their journey.',
#    'story_type': 'non-play'},
#   {'exp': 'Change in location as they travel down the river.',
#    'story_type': 'non-play'},
#   {'exp': 'Change in location as they reach the village.',
#    'story_type': 'non-play'},
#   {'exp': 'Change in location as they interact with the village children.',
#    'story_type': 'non-play'},
#   {'exp': 'Change in location as they go into the public house.',
#    'story_type': 'non-play'},
#   {'exp': 'Change in location as they engage with the villagers.',
#    'story_type': 'non-play'},
#   {'exp': 'Change in location as they contemplate their experiences.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': "Location changes to the old man's house.",
#    'story_type': 'non-play'},
#   {'exp': 'Continued conversation in the same location.',
#    'story_type': 'non-play'},
#   {'exp': "Location changes to the King's palace.", 'story_type': 'non-play'},
#   {'exp': "Continued in the King's palace.", 'story_type': 'non-play'},
#   {'exp': "Still in the King's palace, but exploring the city.",
#    'story_type': 'non-play'},
#   {'exp': "Still in the King's palace.", 'story_type': 'non-play'},
#   {'exp': "Still in the King's palace.", 'story_type': 'non-play'},
#   {'exp': "Still in the King's palace.", 'story_type': 'non-play'},
#   {'exp': "Still in the King's palace.", 'story_type': 'non-play'},
#   {'exp': 'Final departure from the kingdom.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Change of location to Surinam.', 'story_type': 'non-play'},
#   {'exp': 'Change of location to a public-house.', 'story_type': 'non-play'},
#   {'exp': "Change of location to Candide's waiting area.",
#    'story_type': 'non-play'},
#   {'exp': "Change of location to the magistrate's office.",
#    'story_type': 'non-play'},
#   {'exp': "Change of location to Candide's inn.", 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location remains on the ship.', 'story_type': 'non-play'},
#   {'exp': 'The scene shifts to observing the battle.',
#    'story_type': 'non-play'},
#   {'exp': 'The focus shifts to the aftermath of the battle.',
#    'story_type': 'non-play'},
#   {'exp': 'Discussion continues on the ship.', 'story_type': 'non-play'},
#   {'exp': 'They are still on the ship, continuing their journey.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to Paris.', 'story_type': 'non-play'},
#   {'exp': 'Location remains in the inn in Paris.', 'story_type': 'non-play'},
#   {'exp': 'Location remains in Paris.', 'story_type': 'non-play'},
#   {'exp': "Location changes to the Marchioness's house.",
#    'story_type': 'non-play'},
#   {'exp': 'Location remains at the supper.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to the boudoir.', 'story_type': 'non-play'},
#   {'exp': 'Location remains in the boudoir.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to the street.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to Portsmouth.', 'story_type': 'non-play'},
#   {'exp': 'Location changes as they travel to Venice.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': "Location changes to St. Mark's Piazza.", 'story_type': 'non-play'},
#   {'exp': "Location changes to Candide's apartment.",
#    'story_type': 'non-play'},
#   {'exp': "Location remains in Candide's apartment.",
#    'story_type': 'non-play'},
#   {'exp': "Location remains in Candide's apartment.",
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same, but the conversation shifts.',
#    'story_type': 'non-play'},
#   {'exp': 'Still in the palace, but the activity changes.',
#    'story_type': 'non-play'},
#   {'exp': 'Still in the palace, but moving to a different room.',
#    'story_type': 'non-play'},
#   {'exp': 'Change of location to the garden.', 'story_type': 'non-play'},
#   {'exp': 'Still in the garden, but the focus shifts to their thoughts.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Cacambo approaches Candide during supper.',
#    'story_type': 'non-play'},
#   {'exp': 'The conversation shifts to the identities of the guests.',
#    'story_type': 'non-play'},
#   {'exp': "The scene concludes with the kings' reactions and Candide's thoughts.",
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to the ship.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to the galley.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': "Location changes to Pangloss's recounting of events.",
#    'story_type': 'non-play'},
#   {'exp': 'Location remains the same but shifts to a philosophical discussion.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same, discussing their life.',
#    'story_type': 'non-play'},
#   {'exp': 'New characters arrive, changing the dynamic.',
#    'story_type': 'non-play'},
#   {'exp': "Change of location to the Dervish's place.",
#    'story_type': 'non-play'},
#   {'exp': 'They return to the farm after the consultation.',
#    'story_type': 'non-play'},
#   {'exp': 'Discussion continues at the farm, reflecting on life.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'llm'},
#   {'exp': 'Lila moves to her art studio.', 'story_type': 'llm'},
#   {'exp': 'Lila starts painting in her studio.', 'story_type': 'llm'},
#   {'exp': 'Lila falls asleep and dreams.', 'story_type': 'llm'},
#   {'exp': 'Lila wakes up after her dream.', 'story_type': 'llm'},
#   {'exp': 'Start of chapter.', 'story_type': 'llm'},
#   {'exp': 'Location changes to the alley.', 'story_type': 'llm'},
#   {'exp': 'Start of chapter.', 'story_type': 'llm'},
#   {'exp': 'Location changes to the Hidden Realm.', 'story_type': 'llm'},
#   {'exp': 'Start of chapter.', 'story_type': 'llm'},
#   {'exp': 'Location changes to the large circular room.', 'story_type': 'llm'},
#   {'exp': 'Location changes to the center of the circular room.',
#    'story_type': 'llm'},
#   {'exp': 'Location changes to the council chamber.', 'story_type': 'llm'},
#   {'exp': 'Start of chapter.', 'story_type': 'llm'},
#   {'exp': "Location changes to inside Malachai's lair.", 'story_type': 'llm'},
#   {'exp': 'Location changes to the Hall of Stolen Colors.',
#    'story_type': 'llm'},
#   {'exp': 'The confrontation escalates into a battle.', 'story_type': 'llm'},
#   {'exp': 'They escape the lair after the battle.', 'story_type': 'llm'},
#   {'exp': 'Start of chapter.', 'story_type': 'llm'},
#   {'exp': 'Lila meets the Brave Warrior near the oak tree.',
#    'story_type': 'llm'},
#   {'exp': 'Finn appears, changing the dynamic of the scene.',
#    'story_type': 'llm'},
#   {'exp': 'The scene concludes with their agreement to work together.',
#    'story_type': 'llm'},
#   {'exp': 'Start of chapter.', 'story_type': 'llm'},
#   {'exp': 'Location changes to the battlefield.', 'story_type': 'llm'},
#   {'exp': 'Location remains on the battlefield.', 'story_type': 'llm'},
#   {'exp': 'Location remains on the battlefield.', 'story_type': 'llm'},
#   {'exp': 'Location remains on the battlefield.', 'story_type': 'llm'},
#   {'exp': 'Location remains on the battlefield.', 'story_type': 'llm'},
#   {'exp': 'Location remains on the battlefield.', 'story_type': 'llm'},
#   {'exp': 'Start of chapter.', 'story_type': 'llm'},
#   {'exp': 'Location changes to the clearing with the crystal.',
#    'story_type': 'llm'},
#   {'exp': 'Location changes as they interact with the Guardian.',
#    'story_type': 'llm'},
#   {'exp': "Location remains the same but the focus shifts to Malachai's story.",
#    'story_type': 'llm'},
#   {'exp': 'Location remains the same as they prepare for action.',
#    'story_type': 'llm'},
#   {'exp': 'Start of chapter.', 'story_type': 'llm'},
#   {'exp': 'Start of chapter.', 'story_type': 'llm'},
#   {'exp': "Location changes to Malachai's lair.", 'story_type': 'llm'},
#   {'exp': 'Location changes to Monochrome Town.', 'story_type': 'llm'},
#   {'exp': 'Start of chapter.', 'story_type': 'llm'},
#   {'exp': 'Change of location to the Hidden Realm.', 'story_type': 'llm'},
#   {'exp': 'Change of location to the art studio.', 'story_type': 'llm'},
#   {'exp': 'Start of chapter.', 'story_type': 'llm'},
#   {'exp': 'Location changes to the art studio.', 'story_type': 'llm'},
#   {'exp': 'Location changes to the gallery.', 'story_type': 'llm'},
#   {'exp': "Location changes to Lila's porch.", 'story_type': 'llm'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
# ...
#   {'exp': 'Sancho reacts to the story.', 'story_type': 'non-play'},
#   {'exp': 'Sancho expresses his thoughts.', 'story_type': 'non-play'},
#   {'exp': "Sancho's comments provoke Don Quixote.", 'story_type': 'non-play'},
#   {'exp': 'The location changes as they encounter Gines.',
#    'story_type': 'non-play'},
#   {'exp': 'The group discusses the story.', 'story_type': 'non-play'},
#   {'exp': 'Don Quixote shifts focus to Dulcinea.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to the spring where they stop to drink.',
#    'story_type': 'non-play'},
#   {'exp': 'Location changes to the inn.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Anselmo decides to marry Camilla.', 'story_type': 'non-play'},
#   {'exp': "Lothario's visits change after Anselmo's marriage.",
#    'story_type': 'non-play'},
#   {'exp': 'Anselmo confronts Lothario about his visits.',
#    'story_type': 'non-play'},
#   {'exp': 'Anselmo confides in Lothario about his doubts.',
#    'story_type': 'non-play'},
#   {'exp': "Lothario argues against Anselmo's plan.", 'story_type': 'non-play'},
#   {'exp': "Anselmo remains resolute despite Lothario's warnings.",
#    'story_type': 'non-play'},
#   {'exp': 'They finalize the details of the test.', 'story_type': 'non-play'},
#   {'exp': "Anselmo's absence sets the stage for Lothario's visit.",
#    'story_type': 'non-play'},
#   {'exp': "Lothario's internal conflict grows during his visits.",
#    'story_type': 'non-play'},
#   {'exp': 'Lothario finally acts on his feelings for Camilla.',
#    'story_type': 'non-play'},
#   {'exp': 'Anselmo returns home.', 'story_type': 'non-play'},
#   {'exp': 'Camilla confides in Leonela.', 'story_type': 'non-play'},
#   {'exp': "Lothario's jealousy leads to a plan.", 'story_type': 'non-play'},
#   {'exp': 'Camilla decides on her course of action.',
#    'story_type': 'non-play'},
#   {'exp': 'Camilla prepares to confront Lothario.', 'story_type': 'non-play'},
#   {'exp': "The aftermath of Camilla's confrontation.",
#    'story_type': 'non-play'},
#   {'exp': "Anselmo's ignorance leads to tragedy.", 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'The location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'The location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'The location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'The location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'The location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'The location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'The location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'The location remains the same.', 'story_type': 'non-play'},
#   {'exp': "The location changes to Anselmo's house.",
#    'story_type': 'non-play'},
#   {'exp': 'The location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'The location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'The location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'The scene shifts as the guests enter the inn.',
#    'story_type': 'non-play'},
#   {'exp': "The focus shifts to the curate's curiosity.",
#    'story_type': 'non-play'},
#   {'exp': 'The scene changes as Dorothea approaches the woman.',
#    'story_type': 'non-play'},
#   {'exp': 'The tension escalates with the recognition.',
#    'story_type': 'non-play'},
#   {'exp': "The emotional focus shifts to Dorothea's plea.",
#    'story_type': 'non-play'},
#   {'exp': 'The scene concludes with resolution among the characters.',
#    'story_type': 'non-play'},
#   {'exp': 'The location remains the same as they recount their histories.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': "The conversation shifts to the curate's explanation.",
#    'story_type': 'non-play'},
#   {'exp': 'Discussion of plans indicates a new scene.',
#    'story_type': 'non-play'},
#   {'exp': "Shift in focus to Dorothea's response.", 'story_type': 'non-play'},
#   {'exp': "Sancho's defense creates a new dynamic.", 'story_type': 'non-play'},
#   {'exp': 'Transition to evening plans indicates a new scene.',
#    'story_type': 'non-play'},
#   {'exp': 'New characters enter, changing the scene.',
#    'story_type': 'non-play'},
#   {'exp': 'Focus shifts to the new characters and their interactions.',
#    'story_type': 'non-play'},
#   {'exp': 'Transition to dinner preparations indicates a new scene.',
#    'story_type': 'non-play'},
#   {'exp': "Don Quixote's speech marks a significant shift in focus.",
#    'story_type': 'non-play'},
#   {'exp': "The captive's story begins a new narrative thread.",
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': "The location changes as the sons leave their father's house.",
#    'story_type': 'non-play'},
#   {'exp': 'The location changes as the narrator is taken prisoner.',
#    'story_type': 'non-play'},
#   {'exp': 'The location changes as the narrator discusses his captivity.',
#    'story_type': 'non-play'},
#   {'exp': 'The location changes as the focus shifts to the battle events.',
#    'story_type': 'non-play'},
#   {'exp': "The location changes as the narrative shifts to Don Pedro's story.",
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': "Location changes to the captive's narrative.",
#    'story_type': 'non-play'},
#   {'exp': 'Location changes to the terrace of the prison.',
#    'story_type': 'non-play'},
#   {'exp': "Location changes to the renegade's involvement.",
#    'story_type': 'non-play'},
#   {'exp': "Location changes to Zoraida's correspondence.",
#    'story_type': 'non-play'},
#   {'exp': 'Location changes to the final arrangements for escape.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': "Location changes to Zoraida's garden.", 'story_type': 'non-play'},
#   {'exp': "Location changes to the renegade's vessel.",
#    'story_type': 'non-play'},
#   {'exp': 'Location changes as they encounter the corsairs.',
#    'story_type': 'non-play'},
#   {'exp': 'Location changes to the Spanish shore.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'New location: the inn.', 'story_type': 'non-play'},
#   {'exp': 'New location: the inn.', 'story_type': 'non-play'},
#   {'exp': 'New location: the dining area.', 'story_type': 'non-play'},
#   {'exp': 'New location: the dining area.', 'story_type': 'non-play'},
#   {'exp': 'New location: the inn.', 'story_type': 'non-play'},
#   {'exp': 'New location: outside the inn.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Clara wakes up in the inn.', 'story_type': 'non-play'},
#   {'exp': 'Clara shares her story about the musician.',
#    'story_type': 'non-play'},
#   {'exp': "Discussion about Clara's love and future.",
#    'story_type': 'non-play'},
#   {'exp': "Shift to Don Quixote's perspective outside.",
#    'story_type': 'non-play'},
#   {'exp': 'The girls play a trick on Don Quixote.', 'story_type': 'non-play'},
#   {'exp': 'New day brings new characters to the inn.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'The focus shifts to the search for Don Luis.',
#    'story_type': 'non-play'},
#   {'exp': "The scene changes to Don Luis's conversation with his servant.",
#    'story_type': 'non-play'},
#   {'exp': "The location shifts to the Judge's private conversation with Don Luis.",
#    'story_type': 'non-play'},
#   {'exp': "The scene changes as the focus shifts back to the inn's commotion.",
#    'story_type': 'non-play'},
#   {'exp': 'The location changes to the argument involving Sancho and the barber.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': "The location shifts to the inn's chaos.", 'story_type': 'non-play'},
#   {'exp': 'The scene changes as they prepare to transport Don Quixote.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Conversation continues in the same location.',
#    'story_type': 'non-play'},
#   {'exp': 'The scene shifts as they prepare to leave.',
#    'story_type': 'non-play'},
#   {'exp': 'The group begins their journey.', 'story_type': 'non-play'},
#   {'exp': "A new location is introduced with the canon's arrival.",
#    'story_type': 'non-play'},
#   {'exp': 'Sancho speaks up in the same location.', 'story_type': 'non-play'},
#   {'exp': 'The conversation continues in the same location.',
#    'story_type': 'non-play'},
#   {'exp': 'The discussion shifts to a new topic.', 'story_type': 'non-play'},
#   {'exp': 'The conversation continues in the same location.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to a valley where they rest.',
#    'story_type': 'non-play'},
#   {'exp': 'Location changes to where Don Quixote is caged.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to where the curate is.',
#    'story_type': 'non-play'},
#   {'exp': 'Location changes to the area where Don Quixote is released.',
#    'story_type': 'non-play'},
#   {'exp': 'Location remains the same but the focus shifts to a new conversation.',
#    'story_type': 'non-play'},
#   {'exp': 'Continuation of the conversation with a new argument.',
#    'story_type': 'non-play'},
#   {'exp': 'Continuation of the discussion with a new perspective.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to a discussion between Sancho and the canon.',
#    'story_type': 'non-play'},
#   {'exp': 'Location changes to the meadow where the goatherd appears.',
#    'story_type': 'non-play'},
#   {'exp': 'Location changes as the goatherd begins his tale.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Introduction of Vicente de la Roca.', 'story_type': 'non-play'},
#   {'exp': "Change of location to Leandra's escape.", 'story_type': 'non-play'},
#   {'exp': "Change of location to the village after Leandra's return.",
#    'story_type': 'non-play'},
#   {'exp': 'Change of location to the valley where they mourn.',
#    'story_type': 'non-play'},
#   {'exp': 'Change of location to the valley where the procession occurs.',
#    'story_type': 'non-play'},
#   {'exp': "Change of location back to Don Quixote's village.",
#    'story_type': 'non-play'},
#   {'exp': 'Final thoughts and conclusion of the chapter.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': "Change in focus to Miss Taylor's wedding.",
#    'story_type': 'non-play'},
#   {'exp': 'Location remains at Hartfield, but the focus shifts to dinner.',
#    'story_type': 'non-play'},
#   {'exp': 'Introduction of a new character and conversation.',
#    'story_type': 'non-play'},
#   {'exp': 'Continued conversation at Hartfield.', 'story_type': 'non-play'},
#   {'exp': "Shift in conversation to Mr. Elton's matchmaking.",
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': "Change in focus to Miss Churchill's marriage.",
#    'story_type': 'non-play'},
#   {'exp': 'Shift to Captain Weston’s life post-marriage.',
#    'story_type': 'non-play'},
#   {'exp': 'Change in focus to Frank Churchill.', 'story_type': 'non-play'},
#   {'exp': 'Shift to Mrs. Weston’s perspective and feelings.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': "Change of focus to Emma's interaction with Mrs. Goddard.",
#    'story_type': 'non-play'},
#   {'exp': 'Introduction of Harriet Smith and her relationship with Emma.',
#    'story_type': 'non-play'},
#   {'exp': 'Shift to the evening gathering at Hartfield.',
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': "Emma discusses Harriet's parentage and her past.",
#    'story_type': 'non-play'},
#   {'exp': 'Harriet talks about her time at Abbey-Mill Farm.',
#    'story_type': 'non-play'},
#   {'exp': "Emma expresses her concerns about Harriet's social standing.",
#    'story_type': 'non-play'},
#   {'exp': 'The location changes as they walk on the Donwell road.',
#    'story_type': 'non-play'},
#   {'exp': "Emma reflects on Mr. Martin's demeanor after meeting him.",
#    'story_type': 'non-play'},
#   {'exp': 'Discussion shifts to comparing Mr. Martin with other men.',
#    'story_type': 'non-play'},
#   {'exp': "Emma formulates a plan for Harriet's future.",
#    'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': "Change of topic to Emma's future.", 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Location remains the same.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Emma and Harriet are still at Hartfield.',
#    'story_type': 'non-play'},
#   {'exp': 'The conversation continues at Hartfield.',
#    'story_type': 'non-play'},
#   {'exp': "Still at Hartfield, but a shift in Harriet's decision.",
#    'story_type': 'non-play'},
#   {'exp': 'Continuing the discussion at Hartfield.', 'story_type': 'non-play'},
#   {'exp': 'Still at Hartfield, reflecting on the situation.',
#    'story_type': 'non-play'},
#   {'exp': 'The conversation wraps up at Hartfield.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location remains at Hartfield.', 'story_type': 'non-play'},
#   {'exp': 'Location remains at Hartfield.', 'story_type': 'non-play'},
#   {'exp': 'Location remains at Hartfield.', 'story_type': 'non-play'},
#   {'exp': 'Location remains at Hartfield.', 'story_type': 'non-play'},
#   {'exp': 'Location remains at Hartfield.', 'story_type': 'non-play'},
#   {'exp': "Harriet's return marks a new scene.", 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to the sitting-room.', 'story_type': 'non-play'},
#   {'exp': 'Location remains in the sitting-room.', 'story_type': 'non-play'},
#   {'exp': 'Location remains in the sitting-room.', 'story_type': 'non-play'},
#   {'exp': 'Location remains in the sitting-room.', 'story_type': 'non-play'},
#   {'exp': 'Location remains in the sitting-room.', 'story_type': 'non-play'},
#   {'exp': 'Location remains in the sitting-room.', 'story_type': 'non-play'},
#   {'exp': 'Location remains in the sitting-room.', 'story_type': 'non-play'},
#   {'exp': 'Location remains in the sitting-room.', 'story_type': 'non-play'},
#   {'exp': 'Location remains in the sitting-room.', 'story_type': 'non-play'},
#   {'exp': 'Location remains in the sitting-room.', 'story_type': 'non-play'},
#   {'exp': 'Location remains in the sitting-room.', 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to the lane.', 'story_type': 'non-play'},
#   {'exp': "Location changes to Mr. Elton's house.", 'story_type': 'non-play'},
#   {'exp': 'Start of chapter.', 'story_type': 'non-play'},
#   {'exp': 'Location changes to Hartfield.', 'story_type': 'non-play'},
#   {'exp': 'Location remains at Hartfield.', 'story_type': 'non-play'},
#   {'exp': 'Location remains at Hartfield.', 'story_type': 'non-play'},
#   {'exp': 'Location remains at Hartfield.', 'story_type': 'non-play'},
#   {'exp': 'Location remains at Hartfield.', 'story_type': 'non-play'},
#   {'exp': 'Location remains at Hartfield.', 'story_type': 'non-play'},
#   {'exp': 'Location remains at Hartfield.', 'story_type': 'non-play'},
#   ...])

# %%
# create dataframe
scene_df = pd.DataFrame(scene_divisions)

print(f"Number of scenes: {len(scene_df)}")

scene_df.head()
# Out:
# Number of scenes: 4633
#                                     exp story_type
# 0                     Start of chapter.   non-play
# 1  Location changes to the rabbit hole.   non-play
# 2         Location changes to the hall.   non-play
# 3        Location remains at the table.   non-play
# 4        Location remains at the table.   non-play

# %%
# filter out rows containing 'start of chapter' or 'end of chapter'
filter_words = ["start of chapter", "end of chapter", "final", "ends", "conclud", "conclus", "wrap"]
scene_df = scene_df[~scene_df["exp"].str.lower().str.contains("|".join(filter_words))]

print(f"Number of scenes: {len(scene_df)}")

scene_df.head()
# Out:
# Number of scenes: 3796
#                                     exp story_type  location  char_change  \
# 1  Location changes to the rabbit hole.   non-play      True        False
# 2         Location changes to the hall.   non-play      True        False
# 3        Location remains at the table.   non-play      True        False
# 4        Location remains at the table.   non-play      True        False
# 5        Location remains at the table.   non-play      True        False
#
#    time_change  focus_change  continue
# 1        False         False     False
# 2        False         False     False
# 3        False         False     False
# 4        False         False     False
# 5        False         False     False

# %%
# tag scenes that mention location
location_words = ["location", "still", "setting", "scene shifts", "escape", "back", "transition to the", "moves", "now in", "same", "return to", "continues in", "continues at", "inside", " at ", "place"]
scene_df["location"] = scene_df["exp"].str.lower().str.contains("|".join(location_words))

scene_df.head()
# Out:
#                                     exp story_type  location  char_change  \
# 1  Location changes to the rabbit hole.   non-play      True        False
# 2         Location changes to the hall.   non-play      True        False
# 3        Location remains at the table.   non-play      True        False
# 4        Location remains at the table.   non-play      True        False
# 5        Location remains at the table.   non-play      True        False
#
#    time_change  focus_change  continue
# 1        False         False     False
# 2        False         False     False
# 3        False         False     False
# 4        False         False     False
# 5        False         False     False

# %%
# tag scenes about characters entering/leaving
enter_words = ["enter", "leave", "arriv", "appear", "exit", "step", "meet", "is called", "move to", "change in", "change to", "change of", "introduction of", "depart", "new character", "different character"]
scene_df["char_change"] = scene_df["exp"].str.lower().str.contains("|".join(enter_words)) & ~scene_df["location"]

scene_df.head()
# Out:
#                                     exp story_type  location  char_change  \
# 1  Location changes to the rabbit hole.   non-play      True        False
# 2         Location changes to the hall.   non-play      True        False
# 3        Location remains at the table.   non-play      True        False
# 4        Location remains at the table.   non-play      True        False
# 5        Location remains at the table.   non-play      True        False
#
#    time_change  focus_change  continue
# 1        False         False     False
# 2        False         False     False
# 3        False         False     False
# 4        False         False     False
# 5        False         False     False

# %%
# tag scenes about change of time
time_words = ["time", "night", "morning", "evening", "noon", "midnight", "after", "next", "event", "continu"]
scene_df["time_change"] = scene_df["exp"].str.lower().str.contains("|".join(time_words)) & ~scene_df["location"] & ~scene_df["char_change"]

scene_df.head()
# Out:
#                                     exp story_type  location  char_change  \
# 1  Location changes to the rabbit hole.   non-play      True        False
# 2         Location changes to the hall.   non-play      True        False
# 3        Location remains at the table.   non-play      True        False
# 4        Location remains at the table.   non-play      True        False
# 5        Location remains at the table.   non-play      True        False
#
#    time_change  focus_change  continue  category
# 1        False         False     False  location
# 2        False         False     False  location
# 3        False         False     False  location
# 4        False         False     False  location
# 5        False         False     False  location

# %%
# tag scenes about focus change
focus_words = ["focus", "shift", "conversation", "discussion", "topic", "transition", "chang", "start", "new scene", "conflict", "tension", "a new", "impact", "affect", "decision", "explor", "begin", "emotion", "climax", "new activity", "new plan"]
# Compile the focus word pattern
focus_pattern = re.compile("|".join(focus_words))

def detect_focus_change(row):
    exp = row["exp"].lower()
    contains_focus_word = bool(focus_pattern.search(exp))
    matches_is_ed = bool(re.search(r"\sis\s\w+ed\b", exp))
    return (
        (contains_focus_word or matches_is_ed) and
        not row["location"] and
        not row["char_change"] and
        not row["time_change"]
    )

scene_df["focus_change"] = scene_df.apply(detect_focus_change, axis=1)

scene_df.head()
# Out:
#                                     exp story_type  location  char_change  \
# 1  Location changes to the rabbit hole.   non-play      True        False
# 2         Location changes to the hall.   non-play      True        False
# 3        Location remains at the table.   non-play      True        False
# 4        Location remains at the table.   non-play      True        False
# 5        Location remains at the table.   non-play      True        False
#
#    time_change  focus_change  continue  category
# 1        False         False     False  location
# 2        False         False     False  location
# 3        False         False     False  location
# 4        False         False     False  location
# 5        False         False     False  location

# %%
continue_words = ["continu"]
scene_df["continue"] = scene_df["exp"].str.lower().str.contains("|".join(continue_words)) & ~scene_df["location"] & ~scene_df["char_change"] & ~scene_df["time_change"] & ~scene_df["focus_change"]

scene_df.head()
# Out:
#                                     exp story_type  location  char_change  \
# 1  Location changes to the rabbit hole.   non-play      True        False
# 2         Location changes to the hall.   non-play      True        False
# 3        Location remains at the table.   non-play      True        False
# 4        Location remains at the table.   non-play      True        False
# 5        Location remains at the table.   non-play      True        False
#
#    time_change  focus_change  continue  category
# 1        False         False     False  location
# 2        False         False     False  location
# 3        False         False     False  location
# 4        False         False     False  location
# 5        False         False     False  location

# %%
# count by story_type
scene_df.groupby(["story_type", "location"]).size()
# Out:
# story_type  location
# llm         False         29
#             True         177
# non-play    False        985
#             True        2496
# play        False         23
#             True          86
# dtype: int64

# %%
# count by story_type
scene_df.groupby(["story_type", "char_change"]).size()
# Out:
# story_type  char_change
# llm         False           195
#             True             11
# non-play    False          3106
#             True            375
# play        False            92
#             True             17
# dtype: int64

# %%
# count by story_type
scene_df.groupby(["story_type", "time_change"]).size()
# Out:
# story_type  time_change
# llm         False           200
#             True              6
# non-play    False          3402
#             True             79
# play        False           109
# dtype: int64

# %%
# count by story_type
scene_df.groupby(["story_type", "focus_change"]).size()
# Out:
# story_type  focus_change
# llm         False            197
#             True               9
# non-play    False           3093
#             True             388
# play        False            106
#             True               3
# dtype: int64

# %%
scene_df.groupby(["story_type", "continue"]).size()
# Out:
# story_type  continue
# llm         False        206
# non-play    False       3481
# play        False        109
# dtype: int64

# %%
# print llm & not change
llm_char_change = scene_df[(scene_df["story_type"] == "llm") & ~scene_df["char_change"] &  ~scene_df["location"] & ~scene_df["time_change"] & ~scene_df["focus_change"] & ~scene_df["continue"]]
llm_char_change
# Out:
#                                              exp story_type  location  \
# 599                Lila falls asleep and dreams.        llm     False
# 612   The confrontation escalates into a battle.        llm     False
# 3955            Elara prepares to make a choice.        llm     False
#
#       char_change  time_change  focus_change  continue     category
# 599         False        False         False     False  char_action
# 612         False        False         False     False  char_action
# 3955        False        False         False     False  char_action

# %%
# print play & location = False & char_change = False
play_char_change = scene_df[(scene_df["story_type"] == "play") & ~scene_df["char_change"] &  ~scene_df["location"] & ~scene_df["time_change"] & ~scene_df["focus_change"] & ~scene_df["continue"]]
play_char_change
# Out:
#                                                    exp story_type  location  \
# 3262       Higgins decides to take on the flower girl.       play     False
# 3264  Doolittle discusses his intentions with Higgins.       play     False
# 3277              Doolittle discusses his predicament.       play     False
#
#       char_change  time_change  focus_change  continue     category
# 3262        False        False         False     False  char_action
# 3264        False        False         False     False  char_action
# 3277        False        False         False     False  char_action

# %%
# non-play & location = False & char_change = False
non_play_no_location = scene_df[(scene_df["story_type"] == "non-play") & (scene_df["location"] == False) &  (scene_df["char_change"] == False) & (scene_df["time_change"] == False) & (scene_df["focus_change"] == False) & (scene_df["continue"] == False)]
non_play_no_location
# Out:
#                                                     exp story_type  location  \
# 10            The Dodo introduces the idea of the race.   non-play     False
# 16    Alice drinks from the bottle in the Rabbit's h...   non-play     False
# 47                Alice's perspective in the courtroom.   non-play     False
# 185                               Anne climbs the roof.   non-play     False
# 190                             Anne's recovery period.   non-play     False
# ...                                                 ...        ...       ...
# 4398         Pierre decides to join the risky behavior.   non-play     False
# 4455  Princess Mary interacts with Mademoiselle Bour...   non-play     False
# 4533       Dorothy expresses her desire to return home.   non-play     False
# 4534                       The Witch provides guidance.   non-play     False
# 4571                      Dorothy is taken to her room.   non-play     False
#
#       char_change  time_change  focus_change  continue     category
# 10          False        False         False     False  char_action
# 16          False        False         False     False  char_action
# 47          False        False         False     False  char_action
# 185         False        False         False     False  char_action
# 190         False        False         False     False  char_action
# ...           ...          ...           ...       ...          ...
# 4398        False        False         False     False  char_action
# 4455        False        False         False     False  char_action
# 4533        False        False         False     False  char_action
# 4534        False        False         False     False  char_action
# 4571        False        False         False     False  char_action
#
# [143 rows x 8 columns]

# %%
list_val = non_play_no_location["exp"].values.tolist()

list_val
# Out:
# ['The Dodo introduces the idea of the race.',
#  "Alice drinks from the bottle in the Rabbit's house.",
#  "Alice's perspective in the courtroom.",
#  'Anne climbs the roof.',
#  "Anne's recovery period.",
#  'Anne reacts to the news about the class.',
#  'Cacambo approaches Candide during supper.',
#  'Sancho offers his perspective.',
#  'Sancho expresses concern.',
#  'Sancho seeks clarity.',
#  'Sancho expresses concern for his master.',
#  "Sancho observes Don Quixote's antics.",
#  'Sancho embarks on his journey.',
#  'They stop to listen to the singer.',
#  'They encounter Cardenio in the mountains.',
#  'The woman reveals herself.',
#  'Dorothea describes the proposal.',
#  'Dorothea recounts the betrayal.',
#  'Planning the rescue and roles.',
#  "Don Quixote reacts to Dorothea's story.",
#  'Sancho reacts to the story.',
#  'Sancho expresses his thoughts.',
#  "Sancho's comments provoke Don Quixote.",
#  'The group discusses the story.',
#  'Anselmo decides to marry Camilla.',
#  'Anselmo confronts Lothario about his visits.',
#  'Anselmo confides in Lothario about his doubts.',
#  "Lothario argues against Anselmo's plan.",
#  "Anselmo remains resolute despite Lothario's warnings.",
#  "Anselmo's absence sets the stage for Lothario's visit.",
#  'Anselmo returns home.',
#  'Camilla confides in Leonela.',
#  "Lothario's jealousy leads to a plan.",
#  'Camilla decides on her course of action.',
#  'Camilla prepares to confront Lothario.',
#  "Anselmo's ignorance leads to tragedy.",
#  'Clara wakes up in the inn.',
#  'Clara shares her story about the musician.',
#  'The girls play a trick on Don Quixote.',
#  "Emma discusses Harriet's parentage and her past.",
#  "Emma expresses her concerns about Harriet's social standing.",
#  "Emma formulates a plan for Harriet's future.",
#  'The creature remains in the hovel, observing the cottagers.',
#  'The creature hides during the day.',
#  "The creature's situation worsens.",
#  'The creature acts on his revenge.',
#  'The creature interacts with humans.',
#  "The creature's anger intensifies.",
#  "The creature's desperation leads to violence.",
#  "The creature's plea for companionship.",
#  "Victor responds to the creature's arguments.",
#  'They are driving to the city.',
#  'They are driving through Central Park.',
#  "Pip's thoughts on Christmas Eve.",
#  'Pip sneaks into the pantry.',
#  'Pip is in his room, reflecting on the day.',
#  'Pip goes to town to prepare for his new life.',
#  'Pip visits Miss Havisham to say goodbye.',
#  'Joe shares his errand from Miss Havisham.',
#  'Joe says goodbye to Pip.',
#  'The protagonist returns to the chambers.',
#  'Hector speaks to both armies.',
#  'Agamemnon takes charge on the battlefield.',
#  'Achilles speaks in response to the ambassadors.',
#  'Agamemnon decides to consult Nestor.',
#  'Nestor takes action to gather the chiefs.',
#  "Hector's leadership and the battle's intensity escalate.",
#  'The battle escalates with both sides engaged.',
#  "Hector's determination to lead despite omens.",
#  'The intensity of the battle increases with significant losses.',
#  "The battle intensifies with Hector's fall.",
#  'Achilles is alone on the beach.',
#  'Priam is in his court.',
#  'Priam discusses with Hecuba.',
#  'Priam prepares his chariot.',
#  'Priam is on his way to Achilles.',
#  "Priam reaches Achilles' tent.",
#  'They move deeper into the orchard.',
#  'Jo is outside in the garden.',
#  "Jo is in Laurie's room.",
#  'Jo returns home.',
#  'Jo is now reading letters.',
#  'Jo and Laurie have a private moment of concern.',
#  'Meg reveals her secret.',
#  "Jo seeks to address Laurie's mischief.",
#  'Jo is alone with Beth, leading to her observations.',
#  "Jo and her mother are alone, discussing Jo's plans.",
#  "Jo goes to the editor's office.",
#  "Jo returns to the editor's office.",
#  'Jo contemplates her writing choices.',
#  "Jo is walking towards Meg's and thinking about her interactions with Bhaer.",
#  'They are outside in the rain, sharing a moment.',
#  "Miller's interaction with the servant reveals the truth.",
#  "Clara's action leads to a critical moment.",
#  'Ellis is now walking home.',
#  "Ellis notices the men as he nears Mr. Delamere's house.",
#  'Miller interacts with Sally.',
#  'Miller encounters white men in the street.',
#  'Miller reaches the house where he hopes to find his family.',
#  'Miller opens the door to Mrs. Carteret.',
#  'Janet resolves to help despite her anger.',
#  'Gilbert and Joyce are in the dining room.',
#  'The family discusses evacuation plans.',
#  'Joyce makes a choice about her safety.',
#  'Joyce prepares the house for potential danger.',
#  'Telemachus asks Nestor about Ulysses.',
#  'Nestor gives advice to Telemachus.',
#  'Nestor conducts a sacrifice.',
#  "Mercury travels to Calypso's island.",
#  'Ulysses struggles in the storm.',
#  'Ulysses hears the noise from the girls.',
#  'Ulysses approaches Nausicaa.',
#  'Ulysses speaks to the royal couple.',
#  'Alcinous proposes to Ulysses.',
#  'Ulysses recounts his journey.',
#  'The men encounter danger.',
#  'Ulysses addresses his men.',
#  'Eurylochus recounts the fate of the men.',
#  'Ulysses receives guidance from Mercury.',
#  'Ulysses stands up to Circe.',
#  'Ulysses discusses his journey with Circe.',
#  'Anticlea shares news about his family.',
#  'Ulysses questions the female ghosts.',
#  'Ulysses speaks to Alcinous.',
#  'Ulysses witnesses the torments of various souls.',
#  "Penelope questions Euryclea's news.",
#  'Penelope and Ulysses discuss their past.',
#  'Ulysses discusses future actions with Penelope.',
#  'Miss Bingley speaks to Mr. Darcy.',
#  "Shih-yin's dream introduces the priests and their plans.",
#  'Chin Jung returns home and ponders.',
#  'Widow Chin worries about the consequences.',
#  'Mrs. Huang decides to take action.',
#  "Lady Feng goes to visit Mrs. Ch'in.",
#  'Lady Feng returns home.',
#  'The narrator reaches Grassdale.',
#  "K. reacts to the woman's offer.",
#  'Dólokhov climbs out the window.',
#  'Pierre decides to join the risky behavior.',
#  'Princess Mary interacts with Mademoiselle Bourienne.',
#  'Dorothy expresses her desire to return home.',
#  'The Witch provides guidance.',
#  'Dorothy is taken to her room.']

# %%
# find all lines with " is " followed by a word that ends in "ed" with regex
# subset_val = [val for val in list_val if re.search(r"\sis\s\w+ed\b", val)]
subset_val  = [val for val in list_val if "climax" in val.lower()]

subset_val
# Out:
# []

# %%
# compile all categories in one column
scene_df["category"] = "char_action"
scene_df.loc[scene_df["location"], "category"] = "location"
scene_df.loc[scene_df["char_change"], "category"] = "char_change"
scene_df.loc[scene_df["time_change"], "category"] = "time_change"
scene_df.loc[scene_df["focus_change"], "category"] = "focus_change"
scene_df.loc[scene_df["continue"], "category"] = "continue"

scene_df.head()
# Out:
#                                     exp story_type  location  char_change  \
# 1  Location changes to the rabbit hole.   non-play      True        False
# 2         Location changes to the hall.   non-play      True        False
# 3        Location remains at the table.   non-play      True        False
# 4        Location remains at the table.   non-play      True        False
# 5        Location remains at the table.   non-play      True        False
#
#    time_change  focus_change  continue  category
# 1        False         False     False  location
# 2        False         False     False  location
# 3        False         False     False  location
# 4        False         False     False  location
# 5        False         False     False  location

# %% [markdown]
# ### plot results

# %%
# print category counts
scene_df.groupby(["story_type", "category"]).size()
# Out:
# story_type  category
# llm         char_action        3
#             char_change       11
#             focus_change       9
#             location         177
#             time_change        6
# non-play    char_action      143
#             char_change      375
#             focus_change     388
#             location        2496
#             time_change       79
# play        char_action        3
#             char_change       17
#             focus_change       3
#             location          86
# dtype: int64

# %%
counts = scene_df.groupby(['story_type', 'category']).size().reset_index(name='count')
counts['proportion'] = counts.groupby('story_type')['count'].transform(lambda x: x / x.sum())

counts
# Out:
#    story_type      category  count  proportion
# 0         llm   char_action      3    0.014563
# 1         llm   char_change     11    0.053398
# 2         llm  focus_change      9    0.043689
# 3         llm      location    177    0.859223
# 4         llm   time_change      6    0.029126
# 5    non-play   char_action    143    0.041080
# 6    non-play   char_change    375    0.107728
# 7    non-play  focus_change    388    0.111462
# 8    non-play      location   2496    0.717035
# 9    non-play   time_change     79    0.022695
# 10       play   char_action      3    0.027523
# 11       play   char_change     17    0.155963
# 12       play  focus_change      3    0.027523
# 13       play      location     86    0.788991

# %%
# overall averages for each category
overall_avg = scene_df.groupby("category").size() / len(scene_df)
overall_avg
# Out:
# category
# char_action     0.039252
# char_change     0.106164
# focus_change    0.105374
# location        0.726818
# time_change     0.022392
# dtype: float64

# %%
# see examples of each category
scene_df[scene_df["category"] == "time_change"].sample(10)["exp"].values
# Out:
# array(['Continuation of the conversation with a new argument.',
#        'Shift to reflections after the events.',
#        'Dorothea continues her tale.',
#        'The scene continues on the battlefield.',
#        'Shift to a specific event involving St. John.',
#        'Games begin after lunch.',
#        'K. returns to the office the next day.',
#        'Transition to morning after the night.',
#        'Continuation of their interaction in the garden.',
#        'The journey continues towards the cliffs.'], dtype=object)

# %%
# plot stacked bar chart
# Add custom label column
label_map = {
    'llm': 'LLM',
    'non-play': 'Non-play',
    'play': 'Play'
}
counts['story_type_label'] = counts['story_type'].map(label_map)

cat_label_map = {
    'char_action': 'Character Action',
    'char_change': 'Character Change',
    'focus_change': 'Focus Shift',
    'location': 'Location Change',
    'time_change': 'Time Change'
}
counts['category_label'] = counts['category'].map(cat_label_map)
                                                      
chart = alt.Chart(counts).mark_bar(opacity=0.5).encode(
    x=alt.X('proportion:Q', stack='normalize', title="Proportion of Scenes", axis=alt.Axis(grid=False, values=[0, 0.25, 0.5, 0.75, 1.0])),
    y=alt.Y('story_type_label:N', title=None, sort=['LLM', 'Non-play', 'Play']),
    color=alt.Color('category_label:N', scale=alt.Scale(domain=['Character Action', 'Character Change', 'Focus Shift', 'Location Change', 'Time Change'], 
                                                        range=[  "#6598DB", "#E56A8F","#64B24F","#9C85C0", "#FF9858", ]), title="Scene Division Type"),
    tooltip=['category:N', alt.Tooltip('proportion:Q', format='.2%')]
).properties(
    width=250,
    height=100
).configure_view(
    stroke=None
)

chart
# Out:
# alt.Chart(...)

# %% [markdown]
# ## plot study guide analysis results

# %%
# import from csv
df = pd.read_csv("data/study_guide_analysis.csv")

df.head()
# Out:
#           Detected by  Characters    Themes    Scenes
# 0                Both    0.377127  0.106286  0.822110
# 1     SparkNotes Only    0.015873  0.009009  0.128507
# 2  Story Ribbons Only    0.607000  0.884705  0.049383

# %%
# melt into long format
df_melt = df.melt(id_vars=["Detected by"], var_name="category", value_name="proportion")
df_melt = df_melt.rename(columns={'Detected by': 'source'})

df_melt.head()
# Out:
#                source    category  proportion
# 0                Both  Characters    0.377127
# 1     SparkNotes Only  Characters    0.015873
# 2  Story Ribbons Only  Characters    0.607000
# 3                Both      Themes    0.106286
# 4     SparkNotes Only      Themes    0.009009

# %%
df_melt.columns
# Out:
# Index(['source', 'category', 'proportion'], dtype='object')

# %%
# replace all source = "Story Ribbons Only" with "SR Only"
df_melt["source"] = df_melt["source"].replace("Story Ribbons Only", "Our Pipeline").replace("SparkNotes Only", "SparkNotes")

df_melt.head()
# Out:
#          source    category  proportion
# 0          Both  Characters    0.377127
# 1    SparkNotes  Characters    0.015873
# 2  Our Pipeline  Characters    0.607000
# 3          Both      Themes    0.106286
# 4    SparkNotes      Themes    0.009009

# %%
# rename all category = "Scenes" to "Events"
df_melt["category"] = df_melt["category"].replace("Scenes", "Events")

df_melt.head()
# Out:
#          source    category  proportion
# 0          Both  Characters    0.377127
# 1    SparkNotes  Characters    0.015873
# 2  Our Pipeline  Characters    0.607000
# 6          Both      Events    0.822110
# 7    SparkNotes      Events    0.128507

# %%
# Optional prettier labels
source_order = ['Both', 'SparkNotes', 'Our Pipeline']
category_order = ['Characters', 'Themes', 'Events']
source_colors = ['#6598DB', '#FF9858', '#E56A8F']

# Create a copy of your dataframe with an explicit order field
df_ordered = df_melt.copy()
df_ordered['source_order_value'] = df_ordered['source'].map({s: i for i, s in enumerate(source_order)})

chart = alt.Chart(df_ordered).mark_bar(opacity=0.5).encode(
    x=alt.X('proportion:Q', stack='normalize', title="Proportion of Story Elements Found", 
            axis=alt.Axis(grid=False, values=[0, 0.25, 0.5, 0.75, 1.0])),
    y=alt.Y('category:N', title=None, sort=category_order),
    color=alt.Color('source:N', 
        scale=alt.Scale(domain=source_order, range=source_colors),
        title="Detected by"),
    order=alt.Order('source_order_value:Q'),  # Use the numeric field for ordering
    tooltip=['source:N', 'proportion:Q']
).properties(
    width=250,
    height=100
).configure_view(
    stroke=None
)

chart
# Out:
# alt.Chart(...)

# %%
# filter out Our Pipeline from df, only keep Both and SparkNotes
df_both_sparknotes = df_melt[df_melt["source"] != "Our Pipeline"]

df_both_sparknotes
# Out:
#        source    category  proportion
# 0        Both  Characters    0.377127
# 1  SparkNotes  Characters    0.015873
# 6        Both      Events    0.822110
# 7  SparkNotes      Events    0.128507
# 3        Both      Themes    0.106286
# 4  SparkNotes      Themes    0.009009

# %%
# recompute proportion so that it sums to 1 for each category
df_both_sparknotes.loc[:, "proportion"] = df_both_sparknotes.groupby("category")["proportion"].transform(lambda x: x / x.sum())

df_both_sparknotes
# Out:
#        source    category  proportion
# 0        Both  Characters    0.959611
# 1  SparkNotes  Characters    0.040389
# 6        Both      Events    0.864817
# 7  SparkNotes      Events    0.135183
# 3        Both      Themes    0.921861
# 4  SparkNotes      Themes    0.078139

# %%
# replot chart
# Optional prettier labels
source_order = ['Both', 'SparkNotes']
category_order = ['Characters', 'Themes', 'Events']
source_colors = ['#6598DB',  '#E56A8F']

# Create a copy of your dataframe with an explicit order field
df_ordered = df_both_sparknotes.copy()
df_ordered['source_order_value'] = df_ordered['source'].map({s: i for i, s in enumerate(source_order)})

chart = alt.Chart(df_ordered).mark_bar(opacity=0.5).encode(
    x=alt.X('proportion:Q', stack='normalize', title="Proportion of Story Elements Found", 
            axis=alt.Axis(grid=False, values=[0, 0.25, 0.5, 0.75, 1.0])),
    y=alt.Y('category:N', title=None, sort=category_order),
    color=alt.Color('source:N', 
        scale=alt.Scale(domain=source_order, range=source_colors),
        title="Detected by"),
    order=alt.Order('source_order_value:Q'),  # Use the numeric field for ordering
    tooltip=['source:N', 'proportion:Q']
).properties(
    width=250,
    height=100
).configure_view(
    stroke=None
)

chart
# Out:
# alt.Chart(...)
